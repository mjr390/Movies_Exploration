# %%
import pandas as pd

# %%
#brings in the dfs, cleans them, and runs vader
import pandas as pd
string_lists = pd.read_csv("tmdb_5000_movies.csv")
string_lists = pd.DataFrame(string_lists)
clean_df = string_lists.loc[string_lists["vote_count"]>100]
clean_df = clean_df.loc[clean_df["production_companies"] != "[]"]
clean_df = clean_df.loc[clean_df["genres"] != "[]"]
clean_df1 = clean_df[["budget", "genres", "original_title", "popularity", "production_companies",
                      "release_date", "revenue", "runtime", "vote_average", "vote_count", "overview"]]
clean_df1 = clean_df1.reset_index(drop=True)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
compund = []

for index, row in clean_df1.iterrows():
    results = analyzer.polarity_scores(clean_df1["overview"][index])

    comp = results["compound"]
    compund.append(comp)
clean_df1["compound_score"] = compund   
clean_df1.head()

print(len(clean_df1))
clean_df1
# Out:
# 3142
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13    255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14    225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 18    225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 19    250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20    215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 21    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 22    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 23    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 3112     250000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 3113     250000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3114          0  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...
# 3115     250000  [{"id": 28, "name": "Action"}, {"id": 14, "nam...
# 3116     230000  [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 3117     400000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 3118     200000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 3119     200000                    [{"id": 37, "name": "Western"}]
# 3120          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3121     180000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3122       8000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3123     100000  [{"id": 18, "name": "Drama"}, {"id": 878, "nam...
# 3124     160000  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# 3125          0  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 3126          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3127     125000  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3128    8500000                      [{"id": 18, "name": "Drama"}]
# 3129     100000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 3130      10000  [{"id": 18, "name": "Drama"}, {"id": 14, "name...
# 3131          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 3132          0                [{"id": 99, "name": "Documentary"}]
# 3133      60000  [{"id": 9648, "name": "Mystery"}, {"id": 18, "...
# 3134      65000  [{"id": 99, "name": "Documentary"}, {"id": 35,...
# 3135      70000  [{"id": 9648, "name": "Mystery"}, {"id": 27, "...
# 3136    4000000  [{"id": 53, "name": "Thriller"}, {"id": 878, "...
# 3137      27000                     [{"id": 35, "name": "Comedy"}]
# 3138          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 3139      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 3140       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3141     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                    original_title  popularity  \
# 0                                          Avatar  150.437577
# 1        Pirates of the Caribbean: At World's End  139.082615
# 2                                         Spectre  107.376788
# 3                           The Dark Knight Rises  112.312950
# 4                                     John Carter   43.926995
# 5                                    Spider-Man 3  115.699814
# 6                                         Tangled   48.681969
# 7                         Avengers: Age of Ultron  134.279229
# 8          Harry Potter and the Half-Blood Prince   98.885637
# 9              Batman v Superman: Dawn of Justice  155.790452
# 10                               Superman Returns   57.925623
# 11                              Quantum of Solace  107.928811
# 12     Pirates of the Caribbean: Dead Man's Chest  145.847379
# 13                                The Lone Ranger   49.046956
# 14                                   Man of Steel   99.398009
# 15       The Chronicles of Narnia: Prince Caspian   53.978602
# 16                                   The Avengers  144.448633
# 17    Pirates of the Caribbean: On Stranger Tides  135.413856
# 18                                 Men in Black 3   52.035179
# 19      The Hobbit: The Battle of the Five Armies  120.965743
# 20                         The Amazing Spider-Man   89.866276
# 21                                     Robin Hood   37.668301
# 22            The Hobbit: The Desolation of Smaug   94.370564
# 23                             The Golden Compass   42.990906
# 24                                      King Kong   61.226010
# 25                                        Titanic  100.025899
# 26                     Captain America: Civil War  198.372395
# 27                                     Battleship   64.928382
# 28                                 Jurassic World  418.708552
# 29                                        Skyfall   93.004993
# ...                                           ...         ...
# 3112                                         Cube   44.656151
# 3113                                   Like Crazy   21.825564
# 3114                                         Exam   20.265518
# 3115                                          Ink    5.217002
# 3116                                      Bronson   18.450613
# 3117                                      Mad Max   33.142185
# 3118                                     Swingers   13.971674
# 3119                      Per un pugno di dollari   38.771062
# 3120                           The Man from Earth   31.339015
# 3121                                بچه‌های آسمان    7.072118
# 3122                                      Weekend    1.041254
# 3123                                Another Earth   25.402697
# 3124                                         Once   19.052179
# 3125                    A Charlie Brown Christmas    8.701183
# 3126                            Sound of My Voice    6.192383
# 3127                         Your Sister's Sister   12.833247
# 3128                        The Birth of a Nation    9.452808
# 3129                                  The Gallows   18.045782
# 3130                                   Eraserhead   20.399578
# 3131                                Cheap Thrills   10.826253
# 3132                        Indie Game: The Movie    7.676677
# 3133                                           Pi   27.788067
# 3134                                Super Size Me   10.400603
# 3135                                     Absentia    6.328665
# 3136                                   The Signal   27.662696
# 3137                                       Clerks   19.748658
# 3138                                      Rampage    7.101197
# 3139                               Pink Flamingos    4.553644
# 3140                                       Primer   23.307949
# 3141                                  El Mariachi   14.269792
#
#                                    production_companies release_date  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...   2007-05-19
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...   2015-10-26
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...   2012-07-16
# 4           [{"name": "Walt Disney Pictures", "id": 2}]   2012-03-07
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...   2007-05-01
# 6     [{"name": "Walt Disney Pictures", "id": 2}, {"...   2010-11-24
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...   2015-04-22
# 8     [{"name": "Warner Bros.", "id": 6194}, {"name"...   2009-07-07
# 9     [{"name": "DC Comics", "id": 429}, {"name": "A...   2016-03-23
# 10    [{"name": "DC Comics", "id": 429}, {"name": "L...   2006-06-28
# 11            [{"name": "Eon Productions", "id": 7576}]   2008-10-30
# 12    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2006-06-20
# 13    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2013-07-03
# 14    [{"name": "Legendary Pictures", "id": 923}, {"...   2013-06-12
# 15    [{"name": "Walt Disney", "id": 5888}, {"name":...   2008-05-15
# 16    [{"name": "Paramount Pictures", "id": 4}, {"na...   2012-04-25
# 17    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2011-05-14
# 18    [{"name": "Amblin Entertainment", "id": 56}, {...   2012-05-23
# 19    [{"name": "WingNut Films", "id": 11}, {"name":...   2014-12-10
# 20    [{"name": "Columbia Pictures", "id": 5}, {"nam...   2012-06-27
# 21    [{"name": "Imagine Entertainment", "id": 23}, ...   2010-05-12
# 22    [{"name": "WingNut Films", "id": 11}, {"name":...   2013-12-11
# 23    [{"name": "New Line Cinema", "id": 12}, {"name...   2007-12-04
# 24    [{"name": "WingNut Films", "id": 11}, {"name":...   2005-12-14
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...   1997-11-18
# 26    [{"name": "Studio Babelsberg", "id": 264}, {"n...   2016-04-27
# 27    [{"name": "Universal Pictures", "id": 33}, {"n...   2012-04-11
# 28    [{"name": "Universal Studios", "id": 13}, {"na...   2015-06-09
# 29             [{"name": "Columbia Pictures", "id": 5}]   2012-10-25
# ...                                                 ...          ...
# 3112  [{"name": "T\u00e9l\u00e9film Canada", "id": 8...   1997-09-09
# 3113  [{"name": "Paramount Vantage", "id": 838}, {"n...   2011-10-28
# 3114  [{"name": "Hazeldine Films", "id": 5004}, {"na...   2009-06-19
# 3115       [{"name": "Double Edge Films", "id": 21733}]   2009-01-23
# 3116  [{"name": "EM Media", "id": 1917}, {"name": "A...   2008-10-09
# 3117  [{"name": "Kennedy Miller Productions", "id": ...   1979-04-12
# 3118  [{"name": "Miramax Films", "id": 14}, {"name":...   1996-10-18
# 3119  [{"name": "United Artists", "id": 60}, {"name"...   1964-09-12
# 3120  [{"name": "Falling Sky Entertainment", "id": 2...   2007-06-10
# 3121  [{"name": "The Institute for the Intellectual ...   1997-08-01
# 3122  [{"name": "EM Media", "id": 1917}, {"name": "T...   2011-09-22
# 3123    [{"name": "Artists Public Domain", "id": 8145}]   2011-07-22
# 3124  [{"name": "Summit Entertainment", "id": 491}, ...   2007-03-23
# 3125  [{"name": "Warner Bros. Home Video", "id": 5173}]   1965-12-09
# 3126        [{"name": "Skyscraper Films", "id": 26197}]   2011-01-22
# 3127                [{"name": "Ada Films", "id": 1424}]   2011-09-11
# 3128  [{"name": "Phantom Four", "id": 423}, {"name":...   2016-09-09
# 3129  [{"name": "New Line Cinema", "id": 12}, {"name...   2015-07-10
# 3130  [{"name": "American Film Institute (AFI)", "id...   1977-03-19
# 3131  [{"name": "New Artists Alliance", "id": 5124},...   2013-03-08
# 3132        [{"name": "BlinkWorks Media", "id": 84489}]   2012-05-18
# 3133  [{"name": "Truth and Soul Pictures Inc", "id":...   1998-07-10
# 3134         [{"name": "Kathbur Pictures", "id": 8735}]   2004-01-17
# 3135  [{"name": "Blue Dot Productions", "id": 24562}...   2011-03-03
# 3136  [{"name": "Automatik Entertainment", "id": 281...   2014-03-15
# 3137  [{"name": "Miramax Films", "id": 14}, {"name":...   1994-09-13
# 3138  [{"name": "Boll Kino Beteiligungs GmbH & Co. K...   2009-08-14
# 3139     [{"name": "Dreamland Productions", "id": 407}]   1972-03-12
# 3140                 [{"name": "Thinkfilm", "id": 446}]   2004-10-08
# 3141           [{"name": "Columbia Pictures", "id": 5}]   1992-09-04
#
#          revenue  runtime  vote_average  vote_count  \
# 0     2787965087    162.0           7.2       11800
# 1      961000000    169.0           6.9        4500
# 2      880674609    148.0           6.3        4466
# 3     1084939099    165.0           7.6        9106
# 4      284139100    132.0           6.1        2124
# 5      890871626    139.0           5.9        3576
# 6      591794936    100.0           7.4        3330
# 7     1405403694    141.0           7.3        6767
# 8      933959197    153.0           7.4        5293
# 9      873260194    151.0           5.7        7004
# 10     391081192    154.0           5.4        1400
# 11     586090727    106.0           6.1        2965
# 12    1065659812    151.0           7.0        5246
# 13      89289910    149.0           5.9        2311
# 14     662845518    143.0           6.5        6359
# 15     419651413    150.0           6.3        1630
# 16    1519557910    143.0           7.4       11776
# 17    1045713802    136.0           6.4        4948
# 18     624026776    106.0           6.2        4160
# 19     956019788    144.0           7.1        4760
# 20     752215857    136.0           6.5        6586
# 21     310669540    140.0           6.2        1398
# 22     958400000    161.0           7.6        4524
# 23     372234864    113.0           5.8        1303
# 24     550000000    187.0           6.6        2337
# 25    1845034188    194.0           7.5        7562
# 26    1153304495    147.0           7.1        7241
# 27     303025485    131.0           5.5        2114
# 28    1513528810    124.0           6.5        8662
# 29    1108561013    143.0           6.9        7604
# ...          ...      ...           ...         ...
# 3112      501818     90.0           6.9        1069
# 3113     3542353     90.0           6.4         381
# 3114           0    101.0           6.6         523
# 3115           0    106.0           6.4         101
# 3116     2260712     92.0           6.9         733
# 3117   100000000     93.0           6.6        1213
# 3118     4505922     94.0           6.8         253
# 3119    14500000     99.0           7.6         883
# 3120           0     87.0           7.7         687
# 3121      900000     89.0           7.8         112
# 3122      469947     96.0           7.4         163
# 3123     1776935     92.0           6.8         527
# 3124    20710513     85.0           7.3         453
# 3125           0     25.0           7.5         153
# 3126           0     85.0           6.3         108
# 3127     3200000     90.0           6.5         137
# 3128    15861566    120.0           6.5         178
# 3129    42664410     87.0           4.9         361
# 3130     7000000     89.0           7.5         485
# 3131           0     85.0           6.3         155
# 3132           0     96.0           7.4         203
# 3133     3221152     84.0           7.1         586
# 3134    28575078    100.0           6.6         506
# 3135           0     92.0           5.8         121
# 3136      600896     95.0           5.8         631
# 3137     3151130     92.0           7.4         755
# 3138           0     85.0           6.0         131
# 3139     6000000     93.0           6.2         110
# 3140      424760     77.0           6.9         658
# 3141     2040920     81.0           6.6         238
#
#                                                overview  compound_score
# 0     In the 22nd century, a paraplegic Marine is di...         -0.3612
# 1     Captain Barbossa, long believed to be dead, ha...         -0.3919
# 2     A cryptic message from Bond’s past sends him o...         -0.8271
# 3     Following the death of District Attorney Harve...         -0.9136
# 4     John Carter is a war-weary, former military ca...         -0.7096
# 5     The seemingly invincible Spider-Man goes up ag...          0.5859
# 6     When the kingdom's most wanted-and most charmi...          0.4215
# 7     When Tony Stark tries to jumpstart a dormant p...         -0.3182
# 8     As Harry begins his sixth year at Hogwarts, he...          0.0000
# 9     Fearing the actions of a god-like Super Hero l...          0.3612
# 10    Superman returns to discover his 5-year absenc...         -0.7579
# 11    Quantum of Solace continues the adventures of ...          0.0609
# 12    Captain Jack Sparrow works his way out of a bl...         -0.8074
# 13    The Texas Rangers chase down a gang of outlaws...          0.1901
# 14    A young boy learns that he has extraordinary p...          0.9331
# 15    One year after their incredible adventures in ...         -0.4939
# 16    When an unexpected enemy emerges and threatens...         -0.6696
# 17    Captain Jack Sparrow crosses paths with a woma...         -0.2411
# 18    Agents J (Will Smith) and K (Tommy Lee Jones) ...          0.6486
# 19    Immediately after the events of The Desolation...          0.2500
# 20    Peter Parker is an outcast high schooler aband...          0.1531
# 21    When soldier Robin happens upon the dying Robe...          0.5994
# 22    The Dwarves, Bilbo and Gandalf have successful...          0.7003
# 23    After overhearing a shocking secret, precociou...          0.1280
# 24    In 1933 New York, an overly ambitious movie pr...          0.4767
# 25    84 years later, a 101-year-old woman named Ros...          0.8074
# 26    Following the events of Age of Ultron, the col...         -0.3818
# 27    When mankind beams a radio signal into space, ...          0.6486
# 28    Twenty-two years after the events of Jurassic ...          0.0000
# 29    When Bond's latest assignment goes gravely wro...         -0.0516
# ...                                                 ...             ...
# 3112  Seven strangers are taken out of their daily l...          0.3612
# 3113  A British college student falls for an America...         -0.4588
# 3114  The final candidates for a highly desirable co...         -0.2193
# 3115  Invisible forces exert power over us in our sl...         -0.2263
# 3116  A young man who was sentenced to 7 years in pr...         -0.5267
# 3117  In a dystopian future Australia, a vicious bik...         -0.8442
# 3118  This is a story about Mike, a guy who left his...          0.7133
# 3119  The Man With No Name enters the Mexican villag...         -0.7506
# 3120  An impromptu goodbye party for Professor John ...          0.4019
# 3121  Zohre's shoes are gone; her older brother Ali ...         -0.6597
# 3122  After a drunken house party with his straight ...          0.7050
# 3123  On the night of the discovery of a duplicate E...         -0.0258
# 3124  A vacuum repairman moonlights as a street musi...          0.7906
# 3125  When Charlie Brown complains about the overwhe...         -0.5023
# 3126  A journalist and his girlfriend get pulled in ...          0.0000
# 3127  Iris invites her friend Jack to stay at her fa...         -0.1779
# 3128  Nat Turner, a former slave in America, leads a...         -0.1531
# 3129  20 years after a horrific accident during a sm...         -0.5346
# 3130  Henry Spencer tries to survive his industrial ...         -0.6705
# 3131  Recently fired and facing eviction, a new dad ...         -0.3716
# 3132  Indie Game: The Movie is a feature documentary...          0.9517
# 3133  The debut film from Darren Aronofsky in which ...          0.0000
# 3134  Morgan Spurlock subjects himself to a diet bas...         -0.4939
# 3135  Tricia's husband Daniel has been missing for s...         -0.9676
# 3136  Three college students on a road trip across t...         -0.7184
# 3137  Convenience and video store clerks Dante and R...          0.4588
# 3138  The boredom of small town life is eating Bill ...         -0.9287
# 3139  Notorious Baltimore criminal and underground f...         -0.4215
# 3140  Friends/fledgling entrepreneurs invent a devic...          0.6124
# 3141  El Mariachi just wants to play his guitar and ...         -0.9493
#
# [3142 rows x 12 columns]

# %%
#show the dtypes
clean_df1.dtypes
# Out:
# budget                    int64
# genres                   object
# original_title           object
# popularity              float64
# production_companies     object
# release_date             object
# revenue                   int64
# runtime                 float64
# vote_average            float64
# vote_count                int64
# overview                 object
# compound_score          float64
# dtype: object

# %%
#Unique list
import json
unique_genres = []

for row in clean_df1["genres"]:
    jdata = json.loads(row)
    for d in jdata:
        if d["name"] not in unique_genres:
            unique_genres.append(d['name'])
unique_genres  = [w.replace(" ", "_") for w in unique_genres]  
# words = [w.replace('[br]', '<br />') for w in words]
unique_genres
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Science_Fiction',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Animation',
#  'Family',
#  'Western',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Mystery',
#  'History',
#  'War',
#  'Music',
#  'Documentary',
#  'TV_Movie']

# %%
##THIS BLOCK IS NOT BEING USED

#after single code is complete, create a loop for each genre and a master blank list to append each genre name and avg value to
#create a df with that list to use to plot the data
import statistics
count = 0
Action = []
checks = []
for index,row in clean_df1.iterrows():
    #print(row)
    
    lista = []
    jdata = json.loads(clean_df1["genres"][index])
#     Action.append(jdata)
#     print("Hi")
#     print(len(Action))
#     break
    for d in jdata:
#         if d["name"] == "Action":
#             act = clean_df1["vote_average"]
        if d["name"] not in lista:
            lista.append(d['name'])
#         Action.append(act)
#         break    
            
#             Action.append(d['name'])
#     clean_df1.set_value(index, "genres", lista)        
#             count += 1
#     print(lista)
# Action_df = clean_df1.loc[clean_df1["genres"] == "Action"]
    if "Action" in lista:
#         Action.append(clean_df1["vote_average"]) #use a loc, this line is the issue
        check= clean_df1["revenue"]
        act = clean_df1["vote_average"]
        name1 = "Action"
#         print(act)
#         print(name1)
        Action.append({"genre":name1,"Voter Avg":act, "Revenue":check})
# #     check= clean_df1.loc[clean_df1["genres"]]        
        break
        
        
# df.set_value('index pos', 'column', value to put in)        
        
# ActionAvg = statistics.mean(Action)
# Action2 = pd.DataFrame.from_dict(Action)
# Action = Action.transpose()
print(Action)
# ActionAvg = Action.mean(axis=1)
# checks.append(ActionAvg)
# checks
# clean_df1.head()
# print(lista)
# Out:
# [{'genre': 'Action', 'Voter Avg': 0       7.2
# 1       6.9
# 2       6.3
# 3       7.6
# 4       6.1
# 5       5.9
# 6       7.4
# 7       7.3
# 8       7.4
# 9       5.7
# 10      5.4
# 11      6.1
# 12      7.0
# 13      5.9
# 14      6.5
# 15      6.3
# 16      7.4
# 17      6.4
# 18      6.2
# 19      7.1
# 20      6.5
# 21      6.2
# 22      7.6
# 23      5.8
# 24      6.6
# 25      7.5
# 26      7.1
# 27      5.5
# 28      6.5
# 29      6.9
#        ...
# 3112    6.9
# 3113    6.4
# 3114    6.6
# 3115    6.4
# 3116    6.9
# 3117    6.6
# 3118    6.8
# 3119    7.6
# 3120    7.7
# 3121    7.8
# 3122    7.4
# 3123    6.8
# 3124    7.3
# 3125    7.5
# 3126    6.3
# 3127    6.5
# 3128    6.5
# 3129    4.9
# 3130    7.5
# 3131    6.3
# 3132    7.4
# 3133    7.1
# 3134    6.6
# 3135    5.8
# 3136    5.8
# 3137    7.4
# 3138    6.0
# 3139    6.2
# 3140    6.9
# 3141    6.6
# Name: vote_average, Length: 3142, dtype: float64, 'Revenue': 0       2787965087
# 1        961000000
# 2        880674609
# 3       1084939099
# 4        284139100
# 5        890871626
# 6        591794936
# 7       1405403694
# 8        933959197
# 9        873260194
# 10       391081192
# 11       586090727
# 12      1065659812
# 13        89289910
# 14       662845518
# 15       419651413
# 16      1519557910
# 17      1045713802
# 18       624026776
# 19       956019788
# 20       752215857
# 21       310669540
# 22       958400000
# 23       372234864
# 24       550000000
# 25      1845034188
# 26      1153304495
# 27       303025485
# 28      1513528810
# 29      1108561013
#            ...
# 3112        501818
# 3113       3542353
# 3114             0
# 3115             0
# 3116       2260712
# 3117     100000000
# 3118       4505922
# 3119      14500000
# 3120             0
# 3121        900000
# 3122        469947
# 3123       1776935
# 3124      20710513
# 3125             0
# 3126             0
# 3127       3200000
# 3128      15861566
# 3129      42664410
# 3130       7000000
# 3131             0
# 3132             0
# 3133       3221152
# 3134      28575078
# 3135             0
# 3136        600896
# 3137       3151130
# 3138             0
# 3139       6000000
# 3140        424760
# 3141       2040920
# Name: revenue, Length: 3142, dtype: int64}]

# %%
for n in unique_genres:
    globals()[n] = []
    print(n)
# Out:
# Action
# Adventure
# Fantasy
# Science_Fiction
# Crime
# Drama
# Thriller
# Animation
# Family
# Western
# Comedy
# Romance
# Horror
# Mystery
# History
# War
# Music
# Documentary
# TV_Movie

# %%
#genres code
import statistics

# Action = []
# Adventure = []
# Fantasy = []
# Science_Fiction = []
# Crime = []
# Drama = []
# Thriller = []
# Animation = []
# Family = []
# Western = []
# Comedy = []
# Romance = []
# Horror = []
# Mystery = []
# History = []
# War = []
# Music = []
# Documentary = []
# TV_Movie = []


for n in unique_genres:
    globals()[n] = []



for index,row in clean_df1.iterrows():
    
    jdata = json.loads(clean_df1["genres"][index])

    for d in jdata:

        if d["name"] == "Action":
            Action.append(row)
            
        if d["name"] == "Adventure":
            Adventure.append(row) 
        
        if d["name"] == "Fantasy":
            Fantasy.append(row)  
            
        if d["name"] == "Science Fiction":
            Science_Fiction.append(row)  
            
        if d["name"] == "Crime":
            Crime.append(row)  
            
        if d["name"] == "Drama":
            Drama.append(row)  
            
        if d["name"] == "Thriller":
            Thriller.append(row)  
            
        if d["name"] == "Animation":
            Animation.append(row)  
        
        if d["name"] == "Family":
            Family.append(row)  
        
        if d["name"] == "Western":
            Western.append(row)  
            
        if d["name"] == "Comedy":
            Comedy.append(row)  
            
        if d["name"] == "Romance":
            Romance.append(row)  
            
        if d["name"] == "Horror":
            Horror.append(row)  
         
        if d["name"] == "Mystery":
            Mystery.append(row)  
            
        if d["name"] == "History":
            History.append(row)  
            
        if d["name"] == "War":
            War.append(row)  
            
        if d["name"] == "Music":
            Music.append(row)  
            
        if d["name"] == "Documentary":
            Documentary.append(row)  
            
        if d["name"] == "TV Movie":
            TV_Movie.append(row)      
        

Action_df = pd.DataFrame(Action)
Adventure_df = pd.DataFrame(Adventure)
Fantasy_df = pd.DataFrame(Fantasy)
Science_Fiction_df = pd.DataFrame(Science_Fiction)
Crime_df = pd.DataFrame(Crime)
Drama_df = pd.DataFrame(Drama)
Thriller_df = pd.DataFrame(Thriller)
Animation_df = pd.DataFrame(Animation)
Family_df = pd.DataFrame(Family)
Western_df = pd.DataFrame(Western)
Comedy_df = pd.DataFrame(Comedy)
Romance_df = pd.DataFrame(Romance)
Horror_df = pd.DataFrame(Horror)
Mystery_df = pd.DataFrame(Mystery)
History_df = pd.DataFrame(History)
War_df = pd.DataFrame(War)
Music_df = pd.DataFrame(Music)
Documentary_df = pd.DataFrame(Documentary)
TV_Movie_df = pd.DataFrame(TV_Movie)


##The code under here works to be used elsewhere
# sums = []
# for index,row in Adventure_df.iterrows():
#     sums.append(Adventure_df["vote_average"][index])
# averages = (sum(sums)/len(sums)).round(2)    
# averages
##The code above works to be used elsewhere

# %%
len(Science_Fiction_df)
# Out:
# 441

# %%
#company code NOT FINISHED
un_co_df = clean_df1.loc[clean_df1["vote_count"]>7000]
unique_companies = []
unique_companies_to_list=[]
for row in un_co_df["production_companies"]:
    jdata = json.loads(row)
    for d in jdata:
        if d["name"] not in unique_companies:
            unique_companies.append(d['name'])
            unique_companies_to_list.append(d['name'])
for n in unique_companies_to_list:
    globals()[n] = []

# %%
#used to create empty lists out of each element in a list
# yup = ['a', 'b', 'c']
# for n in yup:
#     globals()[n] = []
# un_co_df = clean_df1.loc[clean_df1["vote_count"]>2000]

unique_companies_to_list = [w.replace(" ", "_") for w in unique_companies_to_list]
unique_companies = [w.replace(" ", "_") for w in unique_companies]
len(unique_companies)
# Out:
# 60

# %%
unique_companies
# Out:
# ['Ingenious_Film_Partners',
#  'Twentieth_Century_Fox_Film_Corporation',
#  'Dune_Entertainment',
#  'Lightstorm_Entertainment',
#  'Walt_Disney_Pictures',
#  'Jerry_Bruckheimer_Films',
#  'Second_Mate_Productions',
#  'Columbia_Pictures',
#  'Danjaq',
#  'B24',
#  'Legendary_Pictures',
#  'Warner_Bros.',
#  'DC_Entertainment',
#  'Syncopy',
#  'Laura_Ziskin_Productions',
#  'Marvel_Enterprises',
#  'Walt_Disney_Animation_Studios',
#  'Marvel_Studios',
#  'Prime_Focus',
#  'Revolution_Sun_Studios',
#  'Heyday_Films',
#  'DC_Comics',
#  'Atlas_Entertainment',
#  'Cruel_&_Unusual_Films',
#  'RatPac-Dune_Entertainment',
#  'Bad_Hat_Harry_Productions',
#  'Eon_Productions',
#  'Infinitum_Nihil',
#  'Silver_Bullet_Productions_(II)',
#  'Blind_Wink_Productions',
#  'Classic_Media',
#  'Cruel_and_Unusual_Films',
#  'Walt_Disney',
#  'Walden_Media',
#  'Stillking_Films',
#  'Ozumi_Films',
#  'Propeler',
#  'Silverbell_Films',
#  'Paramount_Pictures',
#  'Moving_Picture_Company_(MPC)',
#  'Amblin_Entertainment',
#  'Media_Magik_Entertainment',
#  'Imagenation_Abu_Dhabi_FZ',
#  'Hemisphere_Media_Capital',
#  'Parkes/MacDonald_Productions',
#  'WingNut_Films',
#  'New_Line_Cinema',
#  'Warner_Bros._Pictures',
#  '3Foot7',
#  'Metro-Goldwyn-Mayer_(MGM)',
#  'Marvel_Entertainment',
#  'Imagine_Entertainment',
#  'Universal_Pictures',
#  'Scott_Free_Productions',
#  'Relativity_Media',
#  'Depth_of_Field',
#  'Scholastic_Productions',
#  'Big_Primate_Pictures',
#  'MFPV_Film',
#  'Studio_Babelsberg',
#  'Walt_Disney_Studios_Motion_Pictures',
#  'Vita-Ray_Dutch_Productions_(III)',
#  'Deluxe_Digital_Studios',
#  'Hasbro',
#  'Bluegrass_Films',
#  'Film_44',
#  'Universal_Studios',
#  'Fuji_Television_Network',
#  'Dentsu',
#  'Team_Todd',
#  'Tim_Burton_Productions',
#  'Roth_Films',
#  'Zanuck_Company,_The',
#  "Donners'_Company",
#  'Major_Studio_Partners',
#  'thinkfilm',
#  'X3_Canada_Productions',
#  'X3US_Productions',
#  'XM3_Service',
#  'Pixar_Animation_Studios',
#  'DreamWorks_SKG',
#  'Di_Bonaventura_Pictures',
#  'Platinum_Dunes',
#  'Hasbro_Studios',
#  'China_Movie_Channel',
#  'Ian_Bryce_Productions',
#  'Avi_Arad_Productions',
#  'Matt_Tolmach_Productions',
#  'LivePlanet',
#  'Prana_Studios',
#  'Sean_Bailey_Productions',
#  'Kontsept_Film_Company',
#  'De_Line_Pictures',
#  'The_Halcyon_Company',
#  'Wonderland_Sound_and_Vision',
#  'Original_Film',
#  'One_Race_Films',
#  'China_Film_Co.',
#  'Québec_Production_Services_Tax_Credit',
#  'Media_Rights_Capital_(MRC)',
#  'Abu_Dhabi_Film_Commission',
#  'Colorado_Office_of_Film,_Television_&_Media',
#  'GK_Films',
#  'Skydance_Productions',
#  'Apparatus_Productions',
#  'Latina_Pictures',
#  '2DUX²',
#  'TSG_Entertainment',
#  'Down_Productions',
#  'Bad_Robot',
#  'Kurtzman/Orci',
#  'Big_Kid_Pictures',
#  'Village_Roadshow_Pictures',
#  'Bazmark_Films',
#  'A&E_Television_Networks',
#  'Red_Wagon_Entertainment',
#  'Spectrum_Films',
#  'Disney_Double_Dare_You_(DDY)',
#  'Indochina_Productions',
#  'Lucasfilm',
#  'Perfect_Storm_Entertainment',
#  'Alibaba_Pictures_Group',
#  'Skydance_Media',
#  'Sneaky_Shark',
#  'Huahua_Media',
#  'FortyFour_Studios',
#  'Centropolis_Entertainment',
#  'The_Mark_Gordon_Company',
#  'Farewell_Productions',
#  'ImageMovers',
#  'Anarchos_Productions',
#  'Dark_Horse_Entertainment',
#  'Jerry_Weintraub_Productions',
#  'Beagle_Pug_Films',
#  'Riche_Productions',
#  'Village_Roadshow_Films_North_America',
#  'Kinberg_Genre',
#  'DreamWorks_Animation',
#  'Todman,_Simon,_LeMasters_Productions',
#  'Peters_Entertainment',
#  'Sonnenfeld_Josephson_Worldwide_Entertainment',
#  'China_Film_Co-Production_Corporation',
#  'Alphaville_Films',
#  'Sommers_Company,_The',
#  'Spyglass_Entertainment',
#  'Shady_Acres_Entertainment',
#  'Playtone',
#  'Viz_Media',
#  'Province_of_British_Columbia_Production_Services_Tax_Credit',
#  '3_Arts_Entertainment',
#  'Gordon_Company',
#  'Davis_Entertainment',
#  'Licht/Mueller_Film_Corporation',
#  'Fairview_Entertainment',
#  'Ingenious_Media',
#  'Chernin_Entertainment',
#  'Mid_Atlantic_Films',
#  'Stuber_Productions',
#  'Universal',
#  'H2F_Entertainment',
#  'Babieka',
#  'A113',
#  'Golden_Mean',
#  'Stereo_D',
#  'Vertigo_Entertainment',
#  'Mad_Hatter_Entertainment',
#  'Intermedia_Films',
#  'C-2_Pictures',
#  'IMF_Internationale_Medien_und_Film_GmbH_&_Co._3._Produktions_KG',
#  'Mostow/Lieberman_Productions',
#  'Bulletproof_Cupid',
#  'Lynda_Obst_Productions',
#  'Cine_Bazar',
#  'Toho_Pictures',
#  'Ardustry_Entertainment',
#  'Mediastream_Film_GmbH_&_Co._Productions_KG',
#  'Kennedy/Marshall_Company,_The',
#  'Dune_Entertainment_III',
#  'Big_Screen_Productions',
#  'Lionsgate',
#  'Color_Force',
#  'Saturn_Films',
#  'Broken_Road_Productions',
#  'Junction_Entertainment',
#  'Virtual_Studios',
#  'Next_Entertainment',
#  'Irwin_Allen_Productions',
#  'Radiant_Productions',
#  'Synthesis_Entertainment',
#  'Legend3D',
#  'Blizzard_Entertainment',
#  'Annapurna_Pictures',
#  'Fox_2000_Pictures',
#  'Touchstone_Pictures',
#  'SprocketHeads',
#  'France_3_Cinéma',
#  'Pathé_Renn_Productions',
#  'Egmond_Film_&_Television',
#  'Pacifica_Film',
#  'WR_Universal_Group',
#  'Patalex_IV_Productions_Limited',
#  'Weed_Road_Pictures',
#  'Forward_Pass',
#  'Overbrook_Entertainment',
#  'Blue_Light',
#  'GH_Three',
#  'The_Zanuck_Company',
#  'Plan_B_Entertainment',
#  'Theobald_Film_Productions',
#  'Patalex_III_Productions_Limited',
#  '1492_Pictures',
#  '21_Laps_Entertainment',
#  'Museum_Canada_Productions',
#  'Seed_Productions',
#  'NPV_Entertainment',
#  'Silver_Pictures',
#  'Heineken_Branded_Entertainment',
#  'Kennedy_Miller_Productions',
#  'Panorama_Films',
#  'Skylark_Productions',
#  'Whamaphram_Productions',
#  'Thunder_Road_Pictures',
#  'Cott_Productions',
#  'Furia_de_Titanes_II,_A.I.E.',
#  'Dan_Curtis_Productions',
#  'TC_Productions',
#  'Odin',
#  'Pacific_Data_Images_(PDI)',
#  'Columbus_81_Productions',
#  'Nickelodeon_Movies',
#  'Industrial_Light_&_Magic_(ILM)',
#  'Blinding_Edge_Pictures',
#  'Cruise/Wagner_Productions',
#  'MI_3_Film',
#  'China_Film_Group_Corporation_(CFGC)',
#  'The_Fourth_Production_Company_Film_Group',
#  'Iron_Horse_Entertainment_(II)',
#  'Mythology_Entertainment_(II)',
#  'Aardman_Animations',
#  'Berlanti_Productions',
#  'Classic_Media_Productions',
#  'Bullwinkle_Studios',
#  'Nimar_Studios',
#  'Helena_Productions',
#  'Montecito_Picture_Company,_The',
#  'LStar_Capital',
#  'Feigco_Entertainment',
#  'Pascal_Pictures',
#  'Ghostcorps',
#  'Valhalla_Motion_Pictures',
#  'Columbia_Pictures_Corporation',
#  'Parkes+MacDonald_Image_Nation',
#  'Shangri-La_Entertainment',
#  'Paramount_Animation',
#  'Oriental_DreamWorks',
#  'JC_23_Entertainment',
#  'Radar_Pictures',
#  'Bedford_Falls_Company,_The',
#  'Volcano_Films',
#  'MavroCine_Pictures_GmbH_&_Co._KG',
#  'Summit_Entertainment',
#  'Mystery_Clock_Cinema',
#  'TIK_Films',
#  'Pyramania',
#  'Phoenix_Pictures',
#  'AFG_Talons_Productions',
#  'Lawrence_Gordon_Productions',
#  'Donner/Shuler-Donner_Productions',
#  'Good_Machine',
#  'Saints_LA',
#  'Bristol_Bay_Productions',
#  'Baldwin_Entertainment_Group',
#  'Desertlands_Entertainment',
#  'Mace_Neufeld_Productions',
#  'Kanzaman',
#  'J.K._Livin_Productions',
#  'Moguletta',
#  'Sahara_Productions',
#  'Babelsberg_Film',
#  'Square_USA',
#  'Chris_Lee_Productions',
#  'Samuel_Goldwyn_Films',
#  'Miramax',
#  'Sunswept_Entertainment',
#  'Temple_Hill_Entertainment',
#  'Dr_D_Studios',
#  'Kennedy_Miller_Mitchell',
#  'MVL_Incredible_Productions',
#  'Reliance_Entertainment',
#  'Regency_Enterprises',
#  'Appian_Way',
#  'CatchPlay',
#  'Anonymous_Content',
#  'New_Regency_Pictures',
#  'Hong_Kong_Alpha_Motion_Pictures_Co.',
#  'RatPac_Entertainment',
#  'M_Productions',
#  'Monarchy_Enterprises_S.a.r.l.',
#  'Blind_Wink',
#  'The_Kennedy/Marshall_Company',
#  'Ludlum_Entertainment',
#  'Motion_Picture_BETA_Produktionsgesellschaft',
#  'Bourne_Again',
#  'Don_Simpson/Jerry_Bruckheimer_Films',
#  'DreamWorks',
#  'Wintergreen_Productions',
#  'Protozoa_Pictures',
#  'Disruption_Entertainment',
#  'Heyday_films',
#  'ScreenWest',
#  'Walt_Disney_Feature_Animation',
#  'Government_of_Malta',
#  'Blue_Sky_Studios',
#  'Twentieth_Century_Fox_Animation',
#  'XM2_Productions',
#  'XF2_Canada_Productions',
#  'One_Race_Productions',
#  'Lin_Pictures',
#  'Wigram_Productions',
#  'TriStar_Pictures',
#  'Carolco_Pictures',
#  'Carolco_International_N.V.',
#  'Captivate_Entertainment',
#  'PolyGram_Filmed_Entertainment',
#  'Lions_Gate_Films',
#  'Mark_Gordon_Productions',
#  "Mel's_Cite_du_Cinema",
#  'Munich_Film_Partners_&_Company_(MFP)_MI2_Productions',
#  'Baltimore_Spring_Creek_Productions',
#  'Constantin_Film_Produktion',
#  'Bernd_Eichinger_Productions',
#  'Haishang_Films',
#  'Michael_De_Luca_Productions',
#  'Crystal_Sky_Pictures',
#  'GH_One',
#  'Vengeance_Productions_Pty._Ltd.',
#  'Pearl_Street_Films',
#  'Double_Negative',
#  'Perfect_World_(Beijing)_Pictures_Co.',
#  'Tall_Trees_Productions',
#  'Flower_Films_(II)',
#  'Brandywine_Productions',
#  'Sony_Pictures_Entertainment',
#  'Media_Rights_Capital',
#  'Sony_Pictures_Entertainment_(SPE)',
#  'QED_International',
#  'Alpha_Core',
#  'Genre_Films',
#  'Simon_Kinberg_Productions',
#  'Strike_Entertainment',
#  'Velocity_Productions',
#  'Gracie_Films',
#  'Road_Rebel',
#  'Tree_Line_Films',
#  'Pink_Machine',
#  'Monolith_Pictures_(III)',
#  'Radical_Studios',
#  'Constantin_Film',
#  'TF1_Films_Productions',
#  'La_Petite_Reine',
#  'Tri_Pictures',
#  'Sorolla_Films',
#  'Novo_RPI',
#  'Canal+',
#  'uFilm',
#  'Canal+_España',
#  'Le_Tax_Shelter_du_Gouvernement_Fédéral_de_Belgique',
#  'Les_Editions_Albert_René',
#  'Lion_Rock_Productions',
#  'Perfect_World_Pictures',
#  'Esperanto_Filmoj',
#  'Pacific_Western',
#  '5150_Action',
#  'Gama_Entertainment_Partners',
#  'Marv_Films',
#  'Constantin_Film.',
#  'Flynn_Picture_Company',
#  'Mutual_Film_Company',
#  'Global_Entertainment_Productions_GmbH_&_Company_Medien_KG',
#  'Section_Eight',
#  'WV_Films_III',
#  'Epsilon_Motion_Pictures',
#  'Mandeville_Films',
#  'NeoReel',
#  'Miramax_Films',
#  'Cappa_Productions',
#  'Initial_Entertainment_Group_(IEG)',
#  'Reliance_BIG_Entertainment',
#  'Hollywood_Gang_Productions',
#  'Atmosphere_Entertainment_MM',
#  'Sony_Pictures_Animation',
#  'Kerner_Entertainment_Company',
#  'Angry_Films',
#  'Wardour_Street_Pictures',
#  'Blue_Tulip_Productions',
#  'Chartoff_Productions',
#  'Odd_Lot_Entertainment',
#  'K/O_Paper_Products',
#  'Digital_Domain',
#  'Taleswapper',
#  'Cheyenne_Enterprises',
#  'The_Saul_Zaentz_Company',
#  '80_Days_Productions',
#  'Spanknyce_Films',
#  'Fitzwilliam_Productions',
#  'Laurence_Mark_Productions',
#  'Mediastream_Vierte_Film_GmbH_&_Co._Vermarktungs_KG',
#  'Canlaws_Productions',
#  'Dune_Films',
#  'BK',
#  'KOH',
#  'Reino_del_Cielo',
#  'Inside_Track_3',
#  'Calle_Cruzada',
#  'Global_Medien_KG',
#  'Franklin/Waterman_Productions',
#  'International_Traders',
#  'Mill_Film',
#  'C_&_L',
#  'Dawliz',
#  'Ronald_Shusett/Gary_Goldman',
#  'Digital_Image_Associates',
#  'T2_Productions',
#  'Tribeca_Productions',
#  'Misher_Films',
#  'Film_Rites',
#  'Escape_Artists',
#  'Everyman_Pictures',
#  'Dreamworks_Pictures',
#  'Gary_Sanchez_Productions',
#  'Kopelson_Entertainment',
#  'The_Weinstein_Company',
#  'Nu_Image_Films',
#  'Millennium_Films',
#  'Wild_Things_Productions',
#  'Peninsula_Films',
#  'StudioCanal',
#  'Sony_Pictures_Releasing',
#  'Sony_Pictures_Worldwide_Acquisitions_(SPWA)',
#  'Italian_Tax_Credit',
#  'Birnbaum/Barber',
#  'Cineroma_SRL',
#  'French_Tax_Credit',
#  'Beacon_Communications',
#  'Bedford_Falls_Productions',
#  'Lonely_Film_Productions_GmbH_&_Co._KG.',
#  'Spring_Creek_Productions',
#  'Liberty_Pictures',
#  'EMJAG_Productions',
#  'Red_Granite_Pictures',
#  'Sikelia_Productions',
#  'Polygram_Filmed_Entertainment',
#  'Big_Bug_Pictures',
#  'X-Filme_Creative_Pool',
#  'Ascension_Pictures',
#  'ARD_Degeto_Film',
#  'Cloud_Atlas_Productions',
#  'Five_Drops',
#  'Media_Asia_Group',
#  'Dreams_of_Dragon_Picture',
#  'Animal_Logic',
#  'DiNovi_Pictures',
#  'Frantic_Films',
#  'Maple_Shade_Films',
#  'Catwoman_Films',
#  'Mosaic_Media_Group',
#  'Sid_&_Marty_Krofft_Pictures',
#  'Davis-Films',
#  'LionsGate',
#  'Ex3_Productions',
#  'Fipex_Holding',
#  'Alcon_Entertainment',
#  'DMG_Entertainment',
#  'Ehman_Productions',
#  'Pathé_Distribution',
#  'K._JAM_Media',
#  'Surf_Film',
#  'Enelmar_Productions,_A.I.E.',
#  'Castle_Rock_Entertainment',
#  'Working_Title_Films',
#  'Imhotep_Productions',
#  'Alberto_Grimaldi_Productions',
#  'Beijing_New_Picture_Film_Co._Ltd.',
#  'EDKO_Film',
#  'New_Picture_Company',
#  'DreamWorks_Pictures',
#  'Revolution_Studios',
#  'Location_Gourmet',
#  'Gaumont',
#  'Home_Box_Office_(HBO)',
#  'HBO_Films',
#  'Allison_Shearmur_Productions',
#  'Key_Creatives',
#  'Film4',
#  'Goldcrest_Pictures',
#  'New_Zealand_Large_Budget_Screen_Production_Grant',
#  'Outlaw_Sinema',
#  'Pendle_Mountain_Productions',
#  'Toho-Towa',
#  'British_Broadcasting_Corporation_(BBC)',
#  'Marubeni',
#  'Eidos_Interactive',
#  'Straight_Up_Films',
#  'Giant_Pictures',
#  'Origo_Film_Group',
#  'Le_Studio_Canal+',
#  'TCF_Vancouver_Productions',
#  'Firm_Films',
#  'Prospect_Park',
#  'Millbrook_Farm_Productions',
#  'Red_Hour_Films',
#  'Media_Asia_Films',
#  'Internationale_Filmproduktion_Stella-del-Sud_Second',
#  'Scott_Rudin_Productions',
#  'Yellow_Bird',
#  'Ground_Control',
#  'Cinergi_Pictures_Entertainment',
#  'Internationale_Filmproduktion_Blackbird_Dritte',
#  'Sean_Daniel_Company',
#  'LightWorkers_Media',
#  'Bagdasarian_Productions',
#  'United_Artists',
#  'Achte_Babelsberg_Film',
#  'Happy_Madison_Productions',
#  'Stanley_Kubrick_Productions',
#  'Gunn_Films',
#  'Doom_Buggy_Productions',
#  'South_Side_Amusement_Company',
#  'Mirage_Enterprises',
#  'Motion_Picture_JOTA_Produktions',
#  'October_Pictures',
#  'Rysher_Entertainment',
#  'Metropolitan_Filmexport',
#  'Red_Wagon_Productions',
#  'Kalima_Productions_GmbH_&_Co._KG',
#  'The_Jacobson_Company',
#  'Red_Horizon_Productions',
#  'National_Geographic_Society',
#  'Palomar_Pictures_(II)',
#  'First_Light_Production',
#  'Dino_De_Laurentiis_Company',
#  'Parkway_Pictures_(I)',
#  'Constant_c_Productions',
#  'Hypnotic',
#  'Motion_Picture_THETA_Produktionsgesellschaft',
#  'WV_Films_II',
#  'Impact_Pictures',
#  'Nouvelles_Éditions_de_Films_(NEF)',
#  'New_Legacy',
#  'Josephson_Entertainment',
#  'Andalasia_Productions',
#  'Right_Coast_Productions',
#  'Cruella_Productions',
#  'Image_Entertainment',
#  'Rat_Entertainment',
#  'Waverly_Films',
#  'No_Such_Productions',
#  'Swanford_Films',
#  'Mandalay_Pictures',
#  'Little_Bird',
#  'KC_Medien',
#  'Reperage',
#  'DOS',
#  'MP_Film_Management',
#  'WWE_Studios',
#  'IM3_Entertainment',
#  'Oak_Productions',
#  'City_Light_Films',
#  'David_Foster_Productions',
#  'Bel_Air_Entertainment',
#  'Hacienda_Productions',
#  'Yucaipa_Films',
#  'Goldmann_Pictures',
#  'Misha_Films',
#  'Marc_Platt_Productions',
#  'Horsepower_Films',
#  'Core_Productions',
#  'Munich_Film_Partners_New_Century_&_Company_(MFP)_Core_Productions',
#  'DNA_Films',
#  'IM_Global',
#  'Rena_Film',
#  'Peach_Trees',
#  'Creepshow_Films_Inc.',
#  'Laurel_Entertainment_Inc.',
#  'Internationale_Filmproduktion_Eagle',
#  'Pit_Bull_Productions',
#  'Living_Films',
#  'Green_Hat_Films',
#  'Zanuck/Brown_Productions',
#  'Manhattan_Project',
#  'MTV_Films',
#  'Callahan_Filmworks',
#  'Mad_Chance',
#  'WV_Films_IV',
#  'Type_A_Films',
#  'Ott_Medien',
#  'Wild_West_Picture_Show_Productions',
#  'Permut_Presentations',
#  'WCG_Entertainment_Productions',
#  'Douglas/Reuther_Productions',
#  'Krane_Entertainment',
#  'Kouf/Bigelow_Productions',
#  'Hiett_Designs_of_Las_Vegas',
#  'Runway_Pictures_Inc',
#  'KMP_Film_Invest',
#  'Castel_Film_Romania',
#  'Bona_Fide_Productions',
#  'Cattleya',
#  'Great_Oaks_Entertainment',
#  'Roth-Arnold_Productions',
#  'Warner_Bros._Family_Entertainment',
#  'Northern_Lights_Entertainment',
#  'Courtside_Seats_Productions',
#  'International_Production_Company',
#  'The_Montecito_Picture_Company',
#  'Robert_Simonds_Productions',
#  'Earth_Canada_Productions',
#  'Hammerhead_Productions',
#  'Crave_Films',
#  'Huayi_Brothers_Media',
#  'Le_Grisbi_Productions',
#  'Caravan_Pictures',
#  'Roger_Birnbaum_Productions',
#  'Warner_Bros._Animation',
#  'Rhythm_and_Hues',
#  'Picnic_Basket',
#  'Zookeeper_Productions',
#  'Hey_Eddie',
#  'Prelude_Pictures',
#  'Saltire_Entertainment',
#  'Clinica_Estetico',
#  'RKO_Pictures',
#  'Jonathan_Krane_Group',
#  'Avery_Pix',
#  'Reforma_Films',
#  'Dimension_Films',
#  'Art_Linson_Productions',
#  'Top_Shelf_Productions',
#  'Tig_Productions',
#  'BBC_Worldwide',
#  'BBC_Earth',
#  'Evergreen_Films',
#  'BBC_Earth_MD_(WWD)',
#  'Evergreen_MD',
#  'Franchise_Pictures',
#  'JTP_Films',
#  'Morgan_Creek_Productions',
#  'Battlefield_Productions',
#  'Warner_Bros._Feature_Animation',
#  'Cobalt_Media_Group',
#  'Artists_Production_Group_(APG)',
#  'Aperture_Entertainment',
#  'The_Canton_Company',
#  'Mars_Production_Pty._Ltd.',
#  'Canal_Plus',
#  'Sofica_Europacorp',
#  'Avalanche_Productions',
#  'EuropaCorp',
#  'Pathé_Films',
#  'TPS_Star',
#  'Participant_Media',
#  'France_Télévision',
#  'France_2_Cinéma',
#  'France_3_Cinema',
#  'Centre_National_de_la_Cinématographie_(CNC)',
#  'Conseil_Régional_du_Calvados',
#  'Région_Bretagne',
#  'Ministère_du_Développement_Durable_et_de_la_Mer',
#  'JMH-TSR',
#  'HH_Sheikha_Salama_bint_Hamdan_Al_Nahyan',
#  "Conseil_Général_des_Côtes_d'Armor",
#  'Conseil_Général_du_Morbihan',
#  'Région_Basse-Normandie',
#  'Dante_Entertainment',
#  'Crusader_Entertainment',
#  'ETIC_Films',
#  'Forge',
#  'QI_Quality_International_GmbH_Co._KG',
#  'Signature_Pictures',
#  'ApolloMedia_Distribution',
#  'Coco',
#  'Film_111',
#  'Jericho_Productions_Ltd.',
#  'MFF_(Sound_of_Thunder)',
#  'Matrix_Film_Finance',
#  'Scenario_Lane_Productions',
#  'Don_Carmody_Productions',
#  'FilmDistrict',
#  'Constantin_Film_International',
#  'Contrafilm',
#  'Sony',
#  'Casey_Silver_Productions',
#  'Mikona_Productions_GmbH_&_Co._KG',
#  'Onyx_Films',
#  'NetFlix',
#  'Orange_Studios',
#  'CityMation',
#  'On_Entertainment',
#  'Zippcast_Films',
#  'Illumination_Entertainment',
#  'JD_Productions',
#  'Mediastream_Dritte_Film_GmbH_&_Co._Beteiligungs_KG',
#  'Hit_&_Run_Productions',
#  'Springwood_Productions',
#  'Genetics_Productions',
#  'Bazelevs_Production',
#  'Kickstart_Productions',
#  'Top_Cow_Productions',
#  'Ringerike_Zweite_Filmproduktion',
#  'Hollywood_Pictures',
#  'Offspring_Entertainment',
#  'Zadan_/_Meron_Productions',
#  'Dominion_Productions',
#  'DiC_Entertainment',
#  'SOIXAN7E_QUIN5E',
#  'See_Me_Louisiana',
#  'Participant_Productions',
#  'Playtone_Production',
#  'Double_Feature_Films',
#  'Jersey_Films',
#  'Nina_Saxon_Film_Design',
#  'Alliance_Atlantis_Communications',
#  'Barry_Mendel_Productions',
#  'Michael_Lobell_Productions',
#  'Katalyst_Films',
#  'Aversano_Films',
#  'Empire_Pictures',
#  'Hyde_Park_Entertainment',
#  'Lotus_Pictures',
#  'First_Knight_Productions',
#  'Virgin_Produced',
#  'Mark_Canton_Productions',
#  'Yari_Film_Group',
#  'Stratus_Film_Co.',
#  'Syndicate_Films_International',
#  'Equity_Pictures_Medienfonds_GmbH_&_Co._KG_II',
#  'Hostage_GmbH',
#  'David_Kirschner_Productions',
#  'Fox_Animation_Studios',
#  'Paramount_Vantage',
#  'Likely_Story',
#  'Ivy_Boy_Productions',
#  'This_Is_That_Productions',
#  'Aldrich_Group',
#  'Optional_Pictures',
#  'Limited_Edition_Productions_Inc.',
#  'Lennox_House_Films',
#  'DeBart',
#  'Punch_Productions',
#  'Baltimore_Pictures',
#  'Rovio_Entertainment',
#  'Sony_Pictures_Imageworks_(SPI)',
#  'Rovio_Mobile',
#  'Rovio_Animation',
#  'Apatow_Productions',
#  'Madison_23',
#  'FilmWorks',
#  'MDBF_Zweite_Filmgesellschaft',
#  'Joseph_M._Singer_Entertainment',
#  'Icon_Entertainment_International',
#  'The_Ladd_Company',
#  'B.H._Finance_C.V.',
#  'Neal_Street_Productions',
#  'Motion_Picture_KAPPA_Produktionsgesellschaft',
#  'Darkwoods_Productions',
#  'Trackform_Film_Productions',
#  'TF1_Films_Production',
#  'Pathe',
#  'Two_Brothers_Productions',
#  'Lakeshore_Entertainment',
#  'Interscope_Communications',
#  'Nickelodeon_Animation_Studios',
#  'United_Plankton_Pictures',
#  'Brian_Grazer/Scott_Rudin_Productions',
#  'A_Band_Apart',
#  'Zehnte_Babelsberg',
#  'Visiona_Romantica',
#  'Camelot_Pictures',
#  'Illusion_Entertainment',
#  'Cruise-Wagner_Productions',
#  'Vinyl_Films',
#  'Lonlink_Productions',
#  'Kut_Productions',
#  'Inside_Track_Films',
#  'Charenton_Productions_Limited',
#  'Wheelhouse_Entertainment',
#  'Motion_Picture_Production_GmbH_&_Co._Erste_KG',
#  'Jinks/Cohen_Company',
#  'Smokehouse_Pictures',
#  'Obelisk_Productions',
#  'Edward_R._Pressman_Film',
#  'Vaughn_Productions',
#  'Mandalay_Entertainment',
#  'Applecross',
#  'Reperage_&_Vanguard_Films',
#  'John_Wells_Productions',
#  'Reaper_Productions',
#  'Doom_Productions',
#  'Distant_Planet_Productions',
#  'Screen_Gems',
#  'Sketch_Films',
#  'UW4_Productions',
#  'Corner_Store_Entertainment',
#  'Material_Pictures',
#  'David_Ladd_Films',
#  'Current_Entertainment',
#  'Omnilab_Media',
#  'Ambience_Entertainment',
#  'Open_Road_Films',
#  'Sighvatsson_Films',
#  'Film_Victoria',
#  'Wales_Creative_IP_Fund',
#  'Yorktown_Productions',
#  'Helkon_Media_AG',
#  'Tele_München_Fernseh_Produktionsgesellschaft_(TMG)',
#  'UGC_PH',
#  'British_Broadcasting_Corporation_(BBC)_Television',
#  'Stargate_Studios',
#  'Conundrum_Entertainment',
#  'Natural_Nylon_Entertainment',
#  'Riff_Raff_Film_Productions',
#  'Filmauro',
#  'Blue_Flower_Productions',
#  'Brooklyn_Films_II',
#  'Emmett/Furla_Films',
#  'Envision_Entertainment',
#  'Boies_/_Schiller_Film_Group',
#  'Knightsbridge_Entertainment',
#  'MFP_Munich_Film_Partners_GmbH_&_Company_I._Produktions_KG',
#  'S.O.A.F._Productions',
#  'Maverick_Films',
#  'Imprint_Entertainment',
#  'Horseshoe_Bay_Productions',
#  'Fuzzy_Door_Productions',
#  'Smart_Entertainment',
#  'Himenóptero',
#  'Telecinco_Cinema',
#  'Mod_Producciones',
#  'Instituto_de_la_Cinematografía_y_de_las_Artes_Audiovisuales_(ICAA)',
#  'Golar_Productions',
#  'Kaitz_Productions',
#  'Mann/Roth_Productions',
#  'Whitaker_Entertainment',
#  'Bergsten_Music',
#  'Red_Hawk_Entertainment',
#  'Abraham_Productions',
#  'Fountainbridge_Films',
#  'Ten_Thirteen_Productions',
#  'Quinta_Communications',
#  'Zephyr_Films',
#  'Bandito_Brothers',
#  'Electronic_Arts',
#  'Wind_Dancer_Productions',
#  'Kasdan_Pictures',
#  'Groucho_II_Film_Partnership',
#  'Outlaw_Productions',
#  'Boxing_Cat_Films',
#  'CAMERON_MACKINTOSH',
#  'Jolie_Pas',
#  'Malpaso_Productions',
#  'Clipsal_Films',
#  'RCS_Video',
#  'Cliffhanger_Productions',
#  'Pioneer',
#  'Kernos_Filmproduktionsgesellschaft_&_Company',
#  'Hobby_Films',
#  'Pole_Star',
#  'Olive_Bridge_Entertainment',
#  'Marcy_Media',
#  'Kramer_&_Sigman_Films',
#  'Zaftig_Films',
#  'Overbrook_Films',
#  'Amen_Ra_Films',
#  'Shawn_Danielle_Productions_Ltd.',
#  'Imaginary_Forces',
#  'Peter_Frankfurt_Productions',
#  'Valkyrie_Films',
#  'Scion_Films',
#  'H2S2_Filmproduktionsgesellschaft',
#  'The_Steve_Tisch_Company',
#  'Teitler_Film',
#  'Taurus_Film',
#  'Linson_Films',
#  'Atman_Entertainment',
#  'Knickerbocker_Films',
#  'Sidney_Kimmel_Entertainment',
#  'Hopscotch_Films',
#  'R.P._Productions',
#  'Runteam_III_Ltd.',
#  'Elektra_Productions',
#  'SAI_Productions',
#  'Troublemaker_Studios',
#  'AR_Films',
#  'Aldamisa_Entertainment',
#  'Demarest_Films',
#  'Solipsist_Film',
#  'Residaco',
#  'Cross_Creek_Pictures',
#  'Free_State_Pictures',
#  'RVK_Studios',
#  'Rising_Star',
#  'VIP_Medienfonds_4',
#  'Ikiru_Films',
#  'Castelao_Producciones',
#  "Eric's_Boy",
#  'Moving_Pictures',
#  'Gratitude_International',
#  'Tezuka_Production_Company_Ltd.',
#  'Imagi_Animation_Studios',
#  'Paragon_Entertainment_Corp.',
#  'Shanghai_Film_Group',
#  'Jackie_&_JJ_Production',
#  'Sparkle_Roll_Media',
#  'Home_Media_&_Entertainment_Fund',
#  'Tencent_Video',
#  'China_Film_&_TV_Capital',
#  'Visualizer_Film_Company',
#  'Wayans_Bros._Entertainment',
#  'Internationale_Filmproduktion',
#  'FilmColony',
#  'Wild_Hogs_Productions',
#  'Pacific_Standard',
#  'Artemple_-_Hollywood',
#  'Neufeld_Rehme_Productions',
#  'Envision_Entertainment_Corporation',
#  'Zide-Perry_Productions',
#  'BenderSpink',
#  'Fortis_Films',
#  'Dozen_Canada_Productions',
#  'Gotham_Group',
#  'Red_Om_Films',
#  'Ixtlan',
#  'Wildwood_Enterprises',
#  'Edge_City',
#  'World_Wrestling_Entertainment_(WWE)',
#  'Beacon_Pictures',
#  'Fantail_Films_Inc.',
#  'Riche-Ludwig_Productions',
#  'Groucho_III_Film_Partnership',
#  'Focus_Features',
#  'Laika_Entertainment',
#  'UTV_Motion_Pictures',
#  'AR-TL',
#  'Starlite_Films',
#  'Province_of_British_Columbia_Film_Incentive_BC',
#  'Solomon/Hackett_Productions',
#  'Larger_Than_Life_Productions',
#  'Blue_Train_Productions',
#  'Seagal/Nasso_Productions',
#  'Victor_Company_of_Japan_(JVC)',
#  'Cutting_Edge_Films',
#  'Etalon_film',
#  'Buckaroo_Entertainment',
#  'LHF_Film',
#  'Gerard_Butler_Alan_Siegel_Entertainment',
#  'Nu_Boyana_Film_Studios',
#  'Grosvenor_Park_Impact_Productions',
#  'LEGO',
#  'Warner_Animation_Group',
#  'World_2000_Entertainment',
#  'Tripod_Entertainment',
#  'Langley_Park_Production',
#  'Ocean_Pictures',
#  'Revelations_Entertainment',
#  'Liberty_Pictures_(II)',
#  'Andell_Entertainment',
#  'Laura_Bickford_Productions',
#  'Medienproduktion_Poseidon_Filmgesellschaft',
#  'Sentinel_Productions',
#  'Furthur_Films',
#  'Ilion_Animation_Studios',
#  'Hand_Made_Films',
#  'Mike_Zoss_Productions',
#  'Alphaville_Productions',
#  'Icon_Productions',
#  'BBC_Films',
#  'Baltimore_Spring_Creek_Pictures',
#  'Face_Productions',
#  'Grosvenor_Park_Media_Ltd.',
#  'InVenture_Entertainment',
#  'Nu-Image_Films',
#  'Krasnoff_Foster_Productions',
#  'Allied_Filmmakers',
#  'Stars_Road_Entertainment',
#  'TOKYOPOP',
#  'Gran_Via_Productions',
#  'NDE_Productions',
#  'Linson_Entertainment',
#  'Equity_Pictures_Medienfonds_GmbH_&_Co._KG_III',
#  'Nu_Image_Entertainment_GmbH',
#  'Electric_Entertainment',
#  'Flyboys_Films',
#  'Screenland_Pictures',
#  'Unique_Features',
#  'Mr._Smith_Productions',
#  'Guy_Walks_into_a_Bar_Productions',
#  'Deep_River_Productions',
#  'Friendly_Films_(II)',
#  'Post_No_Bills_Films',
#  'Pandemonium_Productions',
#  ...]

# %%
#example code NOT USED
l={1:"one",2:"two"}
print(l)
for k,v in l.items():
    print(k)
# Out:
# {1: 'one', 2: 'two'}
# 1
# 2

# %%
#2017 names
test_text = pd.read_csv('Names_2017.csv')
test_text = pd.DataFrame(test_text)
test_text.head()
# Out:
#          Opening  Opening.1                   Title
# 0  J A N U A R Y          6  Underworld: Blood Wars
# 1  J A N U A R Y          6                 Arsenal
# 2  J A N U A R Y          6              Between Us
# 3  J A N U A R Y         13          Monster Trucks
# 4  J A N U A R Y         13         The Bye Bye Man

# %%
for movie in test_text["Title"]:
    print(movie)
# Out:
# Underworld: Blood Wars
# Arsenal
# Between Us
# Monster Trucks
# The Bye Bye Man
# Sleepless
# 100 Streets
# The Book of Love
# Split
# xXx: Return of Xander Cage
# The Resurrection of Gavin Stone
# Trespass Against Us
# Sophie and the Rising Sun
# A Dog's Purpose
# Resident Evil: The Final Chapter
# Lost in Florence
# I Am Michael
# iBoy
# Rings
# The Space Between Us
# Youth in Oregon
# I Am Not Your Negro
# Growing Up Smith
# The Lego Batman Movie
# Fifty Shades Darker
# John Wick: Chapter 2
# Bornless Ones
# The Great Wall
# A Cure for Wellness
# Fist Fight
# American Fable
# XX
# Lovesong
# Get Out
# Rock Dog
# Collide
# The Girl with All the Gifts
# I Don't Feel at Home in This World Anymore
# Contemporary Color
# Logan
# The Shack
# Before I Fall
# Table 19
# The Last Word
# Catfight
# Donald Cried
# Kong: Skull Island
# Burning Sands
# Beauty and the Beast
# The Belko Experiment
# Song to Song
# Atomica
# All Nighter
# The Devil's Candy
# Power Rangers
# Life
# CHiPs
# Wilson
# Victor
# Car Dogs
# Walk of Fame
# Ghost in the Shell
# The Boss Baby
# The Zookeeper's Wife
# The Blackcoat's Daughter
# The Discovery
# Carrie Pilby
# The Case for Christ
# Smurfs: The Lost Village
# Going in Style
# Colossal
# Gifted
# Aftermath
# The Fate of the Furious
# Spark
# The Lost City of Z
# My Entire High School Sinking Into the Sea
# The Outcasts
# Born in China
# Unforgettable
# The Promise
# The Circle
# How to Be a Latin Lover
# Sleight
# Guardians of the Galaxy Vol. 2
# The Lovers
# 3 Generations
# King Arthur: Legend of the Sword
# Snatched
# Lowriders
# The Wall
# Paris Can Wait
# Alien: Covenant
# Diary of a Wimpy Kid: The Long Haul
# Everything, Everything
# Wakefield
# Baywatch
# Pirates of the Caribbean: Dead Men Tell No Tales
# Buena Vista Social Club: Adios
# War Machine
# Wonder Woman
# Captain Underpants: The First Epic Movie
# Dean
# The Mummy
# It Comes at Night
# My Cousin Rachel
# Megan Leavey
# Beatriz at Dinner
# Cars 3
# Rough Night
# All Eyez on Me
# 47 Meters Down
# The Book of Henry
# Transformers: The Last Knight
# The Beguiled
# The Big Sick
# The Bad Batch
# Baby Driver
# Okja
# Despicable Me 3
# The House
# The Little Hours
# Inconceivable
# 2:22
# A Ghost Story
# Spider-Man: Homecoming
# War for the Planet of the Apes
# Wish Upon
# Valerian and the City of a Thousand Planets
# Girls Trip
# First Kill
# The Emoji Movie
# An Inconvenient Sequel: Truth to Power
# Detroit
# Brigsby Bear
# Menashe
# The Dark Tower
# Kidnap
# Step
# Wind River
# Armed Response
# Annabelle: Creation
# The Glass Castle
# The Nut Job 2: Nutty by Nature
# Good Time
# Ingrid Goes West
# The Only Living Boy in New York
# The Hitman's Bodyguard
# Logan Lucky
# Patti Cake$
# All Saints
# Served Like A Girl
# Beach Rats
# Tulip Fever
# Unlocked
# It
# Home Again
# 11-Sep
# The Good Catholic
# Gun Shy
# American Assassin
# Mother!
# Brad's Status
# Kingsman: The Golden Circle
# The Lego Ninjago Movie
# Stronger
# Battle of the Sexes
# Woodshock
# Victoria & Abdul
# Jeepers Creepers 3
# American Made
# Flatliners
# Mark Felt: The Man Who Brought Down the White House
# Blade Runner 2049
# The Mountain Between Us
# My Little Pony: The Movie
# The Florida Project
# Brawl in Cell Block 99
# Happy Death Day
# Marshall
# Breathe
# Goodbye Christopher Robin
# Professor Marston and the Wonder Women
# Blood Money
# Geostorm
# Only the Brave
# Boo 2! A Madea Halloween
# Same Kind of Different as Me
# Leatherface
# Wonderstruck
# The Killing of a Sacred Deer
# Thank You for Your Service
# Suburbicon
# Jigsaw
# Novitiate
# All I See Is You
# Amityville: The Awakening
# Thor: Ragnarok
# A Bad Moms Christmas
# Last Flag Flying
# Lady Bird
# Murder on the Orient Express
# Daddy's Home 2
# LBJ
# Three Billboards Outside Ebbing, Missouri
# Mayhem
# Justice League
# The Star
# Wonder
# Cook Off!
# Mr. Roosevelt
# Roman J. Israel, Esq.
# Coco
# Darkest Hour
# The Man Who Invented Christmas
# Call Me by Your Name
# The Disaster Artist
# The Shape of Water
# Wonder Wheel
# I, Tonya
# Just Getting Started
# Star Wars: The Last Jedi
# Ferdinand
# Beyond Skyline
# Jumanji: Welcome to the Jungle
# The Greatest Showman
# Pitch Perfect 3
# Downsizing
# Father Figures
# The Post
# Bright
# Crooked House
# Hostiles
# All the Money in the World
# Molly's Game
# Phantom Thread

# %%
#zip genre and codes
unique_genres = []
g_codes = []
for row in clean_df1["genres"]:
    jdata = json.loads(row)
    for d in jdata:
        if d["name"] not in unique_genres:
            unique_genres.append(d['name'])
            g_codes.append(d['id'])
zipped = zip(g_codes, unique_genres)  
list(zipped)
# Out:
# [(28, 'Action'),
#  (12, 'Adventure'),
#  (14, 'Fantasy'),
#  (878, 'Science Fiction'),
#  (80, 'Crime'),
#  (18, 'Drama'),
#  (53, 'Thriller'),
#  (16, 'Animation'),
#  (10751, 'Family'),
#  (37, 'Western'),
#  (35, 'Comedy'),
#  (10749, 'Romance'),
#  (27, 'Horror'),
#  (9648, 'Mystery'),
#  (36, 'History'),
#  (10752, 'War'),
#  (10402, 'Music'),
#  (99, 'Documentary'),
#  (10770, 'TV Movie')]

# %%
#vader code was written here and copy/pasted to the top
# from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# analyzer = SentimentIntensityAnalyzer()
# compund = []

# for index, row in clean_df1.iterrows():
#     results = analyzer.polarity_scores(clean_df1["overview"][index])

#     comp = results["compound"]
#     compund.append(comp)
# clean_df1["compound_score"] = compund   
# clean_df1.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
# 2                                   Spectre  107.376788
# 3                     The Dark Knight Rises  112.312950
# 4                               John Carter   43.926995
#
#                                 production_companies release_date     revenue  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10  2787965087
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   2007-05-19   961000000
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...   2015-10-26   880674609
# 3  [{"name": "Legendary Pictures", "id": 923}, {"...   2012-07-16  1084939099
# 4        [{"name": "Walt Disney Pictures", "id": 2}]   2012-03-07   284139100
#
#    runtime  vote_average  vote_count  \
# 0    162.0           7.2       11800
# 1    169.0           6.9        4500
# 2    148.0           6.3        4466
# 3    165.0           7.6        9106
# 4    132.0           6.1        2124
#
#                                             overview  compound_score
# 0  In the 22nd century, a paraplegic Marine is di...         -0.3612
# 1  Captain Barbossa, long believed to be dead, ha...         -0.3919
# 2  A cryptic message from Bond’s past sends him o...         -0.8271
# 3  Following the death of District Attorney Harve...         -0.9136
# 4  John Carter is a war-weary, former military ca...         -0.7096

# %%
import pandas as pd
import numpy as np
import json
from ast import literal_eval
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#brings in the dfs, cleans them

df1 = pd.read_csv("tmdb_5000_movies.csv")
df1['release_date'] = pd.to_datetime(df1['release_date']).apply(lambda x: x.date())
json_columns = ['genres', 'keywords', 'production_countries', 'production_companies', 'spoken_languages']
for column in json_columns:
    df1[column] = df1[column].apply(json.loads)
df1 = df1[["budget", "genres", "original_title", "popularity", "production_companies",
                      "release_date", "revenue", "runtime", "vote_average", "vote_count", "overview"]]
df1 = df1.reset_index(drop=True)

for index, row in df1.iterrows():
    g=[]
    for i in range(len(df1["genres"][index])):
        g.append(df1["genres"][index][i].get("name"))
    df1.at[index, 'genres'] =g
           
for index, row in df1.iterrows():
    c=[]
    for i in range(len(df1["production_companies"][index])):
        c.append(df1["production_companies"][index][i].get("name"))
    df1.at[index, 'production_companies'] =c
    
df2 = pd.read_csv("2017_movie_info.csv")
df2['release_date'] = pd.to_datetime(df2['release_date']).apply(lambda x: x.date())
df2["genres"] = df2["genres"].apply(literal_eval)
df2["production_companies"] = df2["production_companies"].apply(literal_eval)
df2.drop('id', axis=1, inplace=True)
df2 = df2.reset_index(drop=True)

df = pd.concat([df1,df2],axis=0, join='outer',ignore_index=True)

#clean_df = df.loc[df["budget"] != 0]
#clean_df = df.loc[df["revenue"] != 0]
clean_df = df.loc[df["vote_count"]>100]
#clean_df = df.loc[df["production_companies"] != []]
#clean_df = df.loc[df["genres"] != []]

len(clean_df)
# Out:
# 3490
