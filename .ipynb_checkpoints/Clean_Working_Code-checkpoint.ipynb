# %%
#import dependencies
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
import json
import statistics
import matplotlib.pyplot as plt
import numpy as np
import requests
from pprint import pprint
from time import sleep

# %%
#make api requests for more data
url = "https://api.themoviedb.org/3/discover/movie?api_key=947778a6875678206b391f256e04d8a7&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&primary_release_year=2017&vote_count.gte=100&page="
fresponse=[]
json=[]
for i in range (1,19):
    furl=url+"%d"%i
    response = requests.get(furl).json()

    for item in response["results"]:
        fresponse.append(item)

# print(len(fresponse))

movie_id_list=[]
for i in range (len(fresponse)):
    movie_id_list.append(fresponse[i]["id"])

# len(movie_id_list)

df = pd.DataFrame({"id":movie_id_list})
df["budget"]=""   
df["genres"]=""     
df["original_title"]=""    
df["popularity"]=""    
df["production_companies"]=""    
df["release_date"]=""    
df["revenue"]=""    
df["runtime"]=""    
df["vote_average"]=""    
df["vote_count"]=""
df["overview"] =""
# df.head()

for index, row in df.iterrows():
    movie_id = row['id']
    url=f"https://api.themoviedb.org/3/movie/{movie_id}?api_key=947778a6875678206b391f256e04d8a7&language=en-US"
    response = requests.get(url).json()
    df.loc[index, 'budget'] = response['budget']
    df.at[index, 'genres'] = response['genres']
    df.loc[index, 'original_title'] = response['original_title']
    df.loc[index, 'popularity'] = response['popularity']
    df.at[index, 'production_companies'] = response['production_companies']
    df.loc[index, 'release_date'] = response['release_date']
    df.loc[index, 'revenue'] = response['revenue']
    df.loc[index, 'runtime'] = response['runtime']
    df.loc[index, 'vote_average'] = response['vote_average']
    df.loc[index, 'vote_count'] = response['vote_count']
    df.loc[index, 'overview'] = response['overview']
    sleep(0.3)
    
df.to_csv("2017_movie_info.csv", index=False, header=True)
df.head()
# Out:
#        id     budget                                             genres  \
# 0  284053  180000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1  274855  120000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2  181808  200000000  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 3  281338  150000000  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 4  263115   97000000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#                    original_title popularity  \
# 0                  Thor: Ragnarok    109.022
# 1                        Geostorm    53.5538
# 2        Star Wars: The Last Jedi    52.7981
# 3  War for the Planet of the Apes    51.3844
# 4                           Logan     44.214
#
#                                 production_companies release_date     revenue  \
# 0  [{'id': 420, 'logo_path': '/hUzeosd33nzE5MCNsZ...   2017-10-25   853977000
# 1  [{'id': 101832, 'logo_path': '/vO7CKIeogFxphT1...   2017-10-13   221600160
# 2  [{'id': 1, 'logo_path': '/o86DbpburjxrqAzEDhXZ...   2017-12-13  1332459537
# 3  [{'id': 22213, 'logo_path': '/qx9K6bFWJupwde0x...   2017-07-11   488533726
# 4  [{'id': 431, 'logo_path': None, 'name': 'The D...   2017-02-28   616801808
#
#   runtime vote_average  vote_count  \
# 0     130          7.5        7007
# 1     109          5.8        1493
# 2     152          7.1        5847
# 3     140          6.9        3950
# 4     137          7.7        9458
#
#                                             overview
# 0  Thor is on the other side of the universe and ...
# 1  After an unprecedented series of natural disas...
# 2  Rey develops her newly discovered abilities wi...
# 3  Caesar and his apes are forced into a deadly c...
# 4  In the near future, a weary Logan cares for an...

# %%
#read the created data from a csv to avoid re-running the api calls every time the notebook is opened
api_df = pd.read_csv("2017_movie_info.csv")
api_df = pd.DataFrame(api_df)
api_df

#edit the text in certain columns to be used later, they need double quotes instead of single
#create an empty list to put the new text into
text_edit_list=[]
#go through each row for the needed column
for row in api_df["genres"]:
    #replace the characters
    jrow=row.replace("'", '\"')
#     print(jrow)
    #append the replaced string to a list
    text_edit_list.append(jrow)
#change the genres column to the new text    
api_df["genres"] = text_edit_list 

#repeat for the production_compaines column
text_edit_list_2 = []
for row in api_df["production_companies"]:
    
    jrow2=row.replace("'", "\"")
    text_edit_list_2.append(jrow2)
api_df["production_companies"] = text_edit_list_2    

#run vader on the overviews to get the overall sentiment of the movie description
compund = []
for index, row in api_df.iterrows():

    try:
        results = analyzer.polarity_scores(api_df["overview"][index])
        comp = results["compound"]  
  
    except:
        comp= results["compound"]

    compund.append(comp)
#add the column to the data frame    
api_df["compound_score"] = compund  
api_df
# Out:
#          id     budget                                             genres  \
# 0    284053  180000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1    274855  120000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 2    181808  200000000  [{"id": 14, "name": "Fantasy"}, {"id": 12, "na...
# 3    281338  150000000  [{"id": 18, "name": "Drama"}, {"id": 878, "nam...
# 4    263115   97000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 5    297762  149000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 6    141052  500000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 7    283995  200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8    381288    9000000  [{"id": 27, "name": "Horror"}, {"id": 53, "nam...
# 9    335984  150000000  [{"id": 9648, "name": "Mystery"}, {"id": 878, ...
# 10   166426  230000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 11   354912  175000000                  [{"id": 16, "name": "Animation"}]
# 12   341174   55000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 13   455656          0                     [{"id": 35, "name": "Comedy"}]
# 14   315635  175000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15   399055   19500000  [{"id": 18, "name": "Drama"}, {"id": 14, "name...
# 16   347882          0  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 17   406990          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 18   337339  250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 19   321612  160000000  [{"id": 10751, "name": "Family"}, {"id": 14, "...
# 20   343668  104000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 21   335988  217000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 22   324552   40000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 23   339403   34000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 24   359940   15000000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 25   353486   90000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 26   316029   84000000                      [{"id": 18, "name": "Drama"}]
# 27   374720  100000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 28    47971   85000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29   425336    4667008  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# ..      ...        ...                                                ...
# 311  426338          0  [{"id": 35, "name": "Comedy"}, {"id": 10402, "...
# 312  376134          0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 313  396810          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 314  432618          0                     [{"id": 35, "name": "Comedy"}]
# 315  483104          0                 [{"id": 10749, "name": "Romance"}]
# 316  306943          0                     [{"id": 35, "name": "Comedy"}]
# 317  425591          0  [{"id": 35, "name": "Comedy"}, {"id": 80, "nam...
# 318  412202    1050000                      [{"id": 18, "name": "Drama"}]
# 319  455551          0           [{"id": 878, "name": "Science Fiction"}]
# 320  317560          0                     [{"id": 35, "name": "Comedy"}]
# 321  336890          0                     [{"id": 35, "name": "Comedy"}]
# 322  469019          0                [{"id": 99, "name": "Documentary"}]
# 323  432616          0                      [{"id": 18, "name": "Drama"}]
# 324  439584          0  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 325  420950          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 326  426962          0                     [{"id": 35, "name": "Comedy"}]
# 327  440708          0                     [{"id": 35, "name": "Comedy"}]
# 328  468198          0                      [{"id": 18, "name": "Drama"}]
# 329  411019    1000000                [{"id": 99, "name": "Documentary"}]
# 330  406385          0  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 331  435921          0                     [{"id": 35, "name": "Comedy"}]
# 332  445793          0                     [{"id": 35, "name": "Comedy"}]
# 333  408381          0  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 334  419511          0  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 335  456508          0                [{"id": 99, "name": "Documentary"}]
# 336  444902          0  [{"id": 10402, "name": "Music"}, {"id": 18, "n...
# 337  431937          0  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 338  435707          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 339  437739          0  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 340  441614          0                 [{"id": 10749, "name": "Romance"}]
#
#                                        original_title  popularity  \
# 0                                      Thor: Ragnarok  109.021591
# 1                                            Geostorm   53.553775
# 2                            Star Wars: The Last Jedi   52.798146
# 3                      War for the Planet of the Apes   51.384361
# 4                                               Logan   44.214025
# 5                                        Wonder Woman   41.191891
# 6                                      Justice League   40.197749
# 7                      Guardians of the Galaxy Vol. 2   38.677640
# 8                                               Split   36.689713
# 9                                   Blade Runner 2049   35.933138
# 10   Pirates of the Caribbean: Dead Men Tell No Tales   35.895971
# 11                                               Coco   35.498505
# 12                                Fifty Shades Darker   35.418425
# 13                                       #realityhigh   35.302998
# 14                             Spider-Man: Homecoming   33.579675
# 15                                 The Shape of Water   33.374459
# 16                                            Sleight   32.739625
# 17                            What Happened to Monday   31.838451
# 18                            The Fate of the Furious   31.582150
# 19                               Beauty and the Beast   28.830286
# 20                        Kingsman: The Golden Circle   27.003633
# 21                      Transformers: The Last Knight   26.767255
# 22                               John Wick: Chapter 2   25.144600
# 23                                        Baby Driver   24.600449
# 24          Three Billboards Outside Ebbing, Missouri   23.981685
# 25                     Jumanji: Welcome to the Jungle   23.966828
# 26                               The Greatest Showman   23.952866
# 27                                            Dunkirk   23.743908
# 28                         xXx: Return of Xander Cage   23.563344
# 29                                       Loving Pablo   23.510748
# ..                                                ...         ...
# 311                                        La llamada    5.747685
# 312                                     The Discovery    5.739487
# 313                                     The Last Word    5.707971
# 314                                         Coexister    5.674529
# 315                                A Christmas Prince    5.626483
# 316                                      The Outcasts    5.615842
# 317        I Don't Feel at Home in This World Anymore    5.614355
# 318                                    Handsome Devil    5.593172
# 319                                        The Recall    5.557986
# 320                                      Carrie Pilby    5.303622
# 321                       Goon: Last of the Enforcers    5.303200
# 322                      Jim & Andy: The Great Beyond    5.279586
# 323                             La Promesse de l'aube    5.246042
# 324                 Smetto quando voglio - Ad honorem    5.201175
# 325                                             Seuls    5.114870
# 326                                 Sous le même toit    5.079043
# 327                                     Mamma o papà?    5.073153
# 328                                         The Place    4.931749
# 329                               I Am Not Your Negro    4.782047
# 330                Smetto quando voglio - Masterclass    4.749552
# 331                                      L'ora legale    4.658175
# 332                                   Moglie e marito    4.487730
# 333                                          Monolith    4.471734
# 334                                   Mister Felicità    4.435729
# 335                   Chris Brown: Welcome to My Life    4.387289
# 336                                     Dirty Dancing    4.276818
# 337                         Monsieur & Madame Adelman    4.252936
# 338                                            Pieles    4.019442
# 339                                         Le Manoir    3.846472
# 340                                              Amar    0.562015
#
#                                   production_companies release_date  \
# 0    [{"id": 420, "logo_path": "/hUzeosd33nzE5MCNsZ...   2017-10-25
# 1    [{"id": 101832, "logo_path": "/vO7CKIeogFxphT1...   2017-10-13
# 2    [{"id": 1, "logo_path": "/o86DbpburjxrqAzEDhXZ...   2017-12-13
# 3    [{"id": 22213, "logo_path": "/qx9K6bFWJupwde0x...   2017-07-11
# 4    [{"id": 431, "logo_path": None, "name": "The D...   2017-02-28
# 5    [{"id": 444, "logo_path": None, "name": "Dune ...   2017-05-30
# 6    [{"id": 429, "logo_path": "/2Tc1P3Ac8M479naPp1...   2017-11-15
# 7    [{"id": 420, "logo_path": "/hUzeosd33nzE5MCNsZ...   2017-04-19
# 8    [{"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKX...   2017-01-19
# 9    [{"id": 79529, "logo_path": "/gVN3k8emmKy4iV4K...   2017-10-04
# 10   [{"id": 2, "logo_path": "/4MbjW4f9bu6LvlDmyIvf...   2017-05-23
# 11   [{"id": 3, "logo_path": "/1TjvGVDMYsj6JBxOAkUH...   2017-10-27
# 12   [{"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKX...   2017-02-08
# 13   [{"id": 59811, "logo_path": "/wwemzKWzjKYJFfCe...   2017-07-17
# 14   [{"id": 420, "logo_path": "/hUzeosd33nzE5MCNsZ...   2017-07-05
# 15   [{"id": 101082, "logo_path": None, "name": "Do...   2017-12-01
# 16   [{"id": 57537, "logo_path": "/xDWgR9hco6pRM69A...   2017-04-28
# 17   [{"id": 7460, "logo_path": None, "name": "Vend...   2017-08-18
# 18   [{"id": 33, "logo_path": "/8lvHyhjr8oUKOOy2dKX...   2017-04-12
# 19   [{"id": 2, "logo_path": "/4MbjW4f9bu6LvlDmyIvf...   2017-03-16
# 20   [{"id": 22213, "logo_path": "/qx9K6bFWJupwde0x...   2017-09-20
# 21   [{"id": 38831, "logo_path": None, "name": "Tom...   2017-06-16
# 22   [{"id": 3528, "logo_path": "/mo2K3alhIGefuqxUn...   2017-02-08
# 23   [{"id": 559, "logo_path": "/rzgMLzPgJ2ZBYnlVwN...   2017-06-28
# 24   [{"id": 2376, "logo_path": "/yeNoWmSHZfvKsBYuL...   2017-11-10
# 25   [{"id": 350, "logo_path": None, "name": "Radar...   2017-12-09
# 26   [{"id": 7076, "logo_path": "/8BFxn9NUWSgp0ndih...   2017-12-20
# 27   [{"id": 41624, "logo_path": "/wzKxIeQKlMP0y5Ca...   2017-07-19
# 28   [{"id": 88943, "logo_path": None, "name": "Rox...   2017-01-13
# 29   [{"id": 97390, "logo_path": None, "name": "B2Y...   2017-10-12
# ..                                                 ...          ...
# 311  [{"id": 103, "logo_path": None, "name": "TVE",...   2017-09-29
# 312  [{"id": 20277, "logo_path": None, "name": "Pro...   2017-03-31
# 313  [{"id": 90445, "logo_path": None, "name": "Fra...   2017-03-03
# 314  [{"id": 85026, "logo_path": None, "name": "che...   2017-10-11
# 315  [{"id": 2090, "logo_path": "/iEFWMfcmFSyCYJCnH...   2017-11-17
# 316  [{"id": 10290, "logo_path": None, "name": "BCD...   2017-04-14
# 317  [{"id": 12142, "logo_path": "/rPnEeMwxjI6rYMGq...   2017-01-19
# 318  [{"id": 21872, "logo_path": None, "name": "Tre...   2017-02-15
# 319  [{"id": 23688, "logo_path": None, "name": "VMI...   2017-06-02
# 320  [{"id": 53002, "logo_path": None, "name": "Bra...   2017-03-31
# 321  [{"id": 6623, "logo_path": "/qvtEf5tM9IAEJUUhX...   2017-03-17
# 322  [{"id": 17209, "logo_path": None, "name": "Vic...   2017-09-05
# 323  [{"id": 7561, "logo_path": None, "name": "Nexu...   2017-12-20
# 324  [{"id": 86177, "logo_path": None, "name": "Gro...   2017-11-30
# 325  [{"id": 694, "logo_path": "/5LEHONGkZBIoWvp1yg...   2017-02-08
# 326  [{"id": 356, "logo_path": "/9tW5wZEGotn1Ei5pEr...   2017-04-19
# 327                                                 []   2017-02-14
# 328  [{"id": 32434, "logo_path": None, "name": "Lot...   2017-11-04
# 329  [{"id": 1030, "logo_path": None, "name": "Magn...   2017-02-03
# 330  [{"id": 2683, "logo_path": "/mOL2WcHtox2urbUf1...   2017-02-02
# 331  [{"id": 6246, "logo_path": None, "name": "Medu...   2017-01-19
# 332  [{"id": 86177, "logo_path": None, "name": "Gro...   2017-04-13
# 333  [{"id": 53597, "logo_path": None, "name": "Sky...   2017-04-20
# 334  [{"id": 10102, "logo_path": None, "name": "Cat...   2017-01-01
# 335  [{"id": 90025, "logo_path": None, "name": "RIV...   2017-06-08
# 336  [{"id": 28523, "logo_path": None, "name": "Lio...   2017-05-24
# 337  [{"id": 5125, "logo_path": "/t3oWTsVukmEzrZzvf...   2017-03-08
# 338  [{"id": 32485, "logo_path": None, "name": "Pok...   2017-04-15
# 339  [{"id": 13800, "logo_path": None, "name": "Gau...   2017-06-21
# 340  [{"id": 103, "logo_path": None, "name": "TVE",...   2017-04-21
#
#         revenue  runtime  vote_average  vote_count  \
# 0     853977000    130.0           7.5        7007
# 1     221600160    109.0           5.8        1493
# 2    1332459537    152.0           7.1        5847
# 3     488533726    140.0           6.9        3950
# 4     616801808    137.0           7.7        9458
# 5     821847012    141.0           7.2        9230
# 6     657924295    120.0           6.3        4881
# 7     863756051    137.0           7.6        8587
# 8     278304578    117.0           7.1        6820
# 9     259239658    163.0           7.3        4646
# 10    794191988    129.0           6.5        5042
# 11    800526015    105.0           7.9        4949
# 12    378827494    118.0           6.0        3438
# 13            0     99.0           6.4         287
# 14    880166924    133.0           7.3        7903
# 15    194989655    123.0           7.3        4303
# 16            0     89.0           5.2         327
# 17            0    123.0           7.2        2129
# 18   1238764765    136.0           6.8        5065
# 19   1263521126    129.0           6.8        8537
# 20    410902662    141.0           7.0        3711
# 21    605425157    149.0           6.0        2419
# 22    171539887    122.0           6.8        4228
# 23    226945087    113.0           7.4        5455
# 24    158526998    115.0           8.2        3207
# 25    962119864    119.0           6.6        4596
# 26    432844677    105.0           8.0        2621
# 27    525573161    107.0           7.4        6429
# 28    346147658    107.0           5.6        1973
# 29            0    123.0           6.2         138
# ..          ...      ...           ...         ...
# 311           0    108.0           7.2         147
# 312           0    102.0           6.2         514
# 313     1783421    108.0           6.4         120
# 314           0     90.0           6.1         123
# 315           0     92.0           6.5         361
# 316           0     95.0           6.5         243
# 317           0     96.0           6.6         403
# 318           0     95.0           7.2         193
# 319     1319566     91.0           4.0         121
# 320       18957     98.0           7.3         120
# 321           0    101.0           5.9         106
# 322           0     94.0           7.7         183
# 323           0    130.0           7.7         122
# 324           0     96.0           7.7         240
# 325           0     90.0           5.5         191
# 326           0     97.0           5.2         126
# 327           0    103.0           5.8         200
# 328           0    105.0           7.1         194
# 329     7123919     95.0           8.1         155
# 330           0    118.0           7.5         434
# 331           0     92.0           6.6         317
# 332      687505    100.0           6.7         112
# 333           0     81.0           5.1         164
# 334           0     94.0           6.3         147
# 335           0    110.0           6.3         216
# 336           0    130.0           5.2         152
# 337           0    120.0           7.6         119
# 338           0     78.0           6.7         147
# 339           0      NaN           5.2         131
# 340           0    105.0           4.5         193
#
#                                               overview  compound_score
# 0    Thor is on the other side of the universe and ...         -0.8519
# 1    After an unprecedented series of natural disas...         -0.8779
# 2    Rey develops her newly discovered abilities wi...          0.0772
# 3    Caesar and his apes are forced into a deadly c...         -0.8658
# 4    In the near future, a weary Logan cares for an...         -0.1531
# 5    An Amazon princess comes to the world of Man i...         -0.8910
# 6    Fuelled by his restored faith in humanity and ...          0.2023
# 7    The Guardians must fight to keep their newfoun...          0.0516
# 8    Though Kevin has evidenced 23 personalities to...          0.0516
# 9    Thirty years after the events of the first fil...         -0.7096
# 10   Thrust into an all-new adventure, a down-on-hi...          0.8199
# 11   Despite his family’s baffling generations-old ...          0.6369
# 12   When a wounded Christian Grey tries to entice ...          0.7003
# 13   When nerdy high schooler Dani finally attracts...          0.5994
# 14   Following the events of Captain America: Civil...         -0.9274
# 15   An other-worldly story, set against the backdr...          0.5719
# 16   A young street magician is left to take care o...          0.8860
# 17   In a world where families are limited to one c...         -0.7351
# 18   When a mysterious woman seduces Dom into the w...         -0.8074
# 19   A live-action adaptation of Disney's version o...          0.7579
# 20   When an attack on the Kingsman headquarters ta...         -0.7579
# 21   Autobots and Decepticons are at war, with huma...         -0.7717
# 22   John Wick is forced out of retirement by a for...         -0.9270
# 23   After being coerced into working for a crime b...         -0.9287
# 24   After seven months have passed without a culpr...         -0.8074
# 25   The tables are turned as four teenagers are su...         -0.1531
# 26   The story of American showman P.T. Barnum, fou...          0.0000
# 27   The story of the miraculous evacuation of Alli...         -0.7184
# 28   Extreme athlete turned government operative Xa...         -0.9524
# 29   The film chronicles the rise and fall of the w...         -0.4005
# ..                                                 ...             ...
# 311  María and Susana, two rebellious teens spend t...          0.8225
# 312  In the near future, due to a breakthrough scie...         -0.7096
# 313  A retired businesswoman – who tries to control...          0.6369
# 314  Under the pressure of his boss, a music produc...         -0.1531
# 315  When a reporter goes undercover as a nanny to ...          0.4404
# 316  After falling victim to a humiliating prank by...          0.4019
# 317  When a depressed woman is burglarized, she fin...         -0.9366
# 318  A music-mad 16-year-old outcast at a rugby-mad...          0.4404
# 319  When five friends vacation at a remote lake ho...         -0.4588
# 320  Awkward, isolated and disapproving of most of ...         -0.2500
# 321  During a pro lockout, Doug "The Thug" Glatt is...         -0.8519
# 322  Offbeat documentarian Chris Smith provides a b...          0.3818
# 323  From his childhood in Poland to his adolescenc...          0.7964
# 324  Has been an year since Pietro Zinni's gang got...         -0.7750
# 325  Five kids wake up in a world where everybody h...         -0.2263
# 326  Delphine and Yvan divorce. While his financial...         -0.1195
# 327  A divorced couple fights for the custody of th...         -0.4404
# 328  The fates of an apparently random group of str...          0.6369
# 329  Working from the text of James Baldwin’s unfin...          0.7351
# 330  Pietro Zinni is asked by the police to revive ...          0.6124
# 331  A small Sicilian town elects a new, honest maj...          0.0621
# 332  Married for ten years, in full crisis, thinkin...         -0.7906
# 333  A mother and her son plan a surprise visit to ...         -0.7717
# 334  Martino's sister, Caterina, can't work anymore...          0.0772
# 335  This compelling Documentary moves beyond the s...          0.8225
# 336  Spending the summer at a Catskills resort with...          0.5719
# 337  How did Sarah and Victor get along for more th...          0.6767
# 338  A story about four spanish people who see them...         -0.1027
# 339  A band of students comes to celebrate the New ...          0.4678
# 340  Laura and Carlos love each other as if every d...          0.8555
#
# [341 rows x 13 columns]

# %%
#create a data frame for the kaggle data from it's csv
string_lists = pd.read_csv("tmdb_5000_movies.csv")
string_lists = pd.DataFrame(string_lists)
string_lists
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13    255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14    225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 18    225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 19    250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20    215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 21    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 22    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 23    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4774      27000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4775          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4776          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4777          0                      [{"id": 18, "name": "Drama"}]
# 4778          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 4779          0                     [{"id": 35, "name": "Comedy"}]
# 4780          0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4781      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4782          0  [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 4783          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4784          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4785          0                      [{"id": 18, "name": "Drama"}]
# 4786          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4787          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4789          0                      [{"id": 18, "name": "Drama"}]
# 4790          0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4793          0                      [{"id": 18, "name": "Drama"}]
# 4794          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795          0                      [{"id": 18, "name": "Drama"}]
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# 5       http://www.sonypictures.com/movies/spider-man3/     559
# 6          http://disney.go.com/disneypictures/tangled/   38757
# 7     http://marvel.com/movies/movie/193/avengers_ag...   99861
# 8     http://harrypotter.warnerbros.com/harrypottera...     767
# 9          http://www.batmanvsupermandawnofjustice.com/  209112
# 10                              http://www.superman.com    1452
# 11    http://www.mgm.com/view/movie/234/Quantum-of-S...   10764
# 12         http://disney.go.com/disneypictures/pirates/      58
# 13                http://disney.go.com/the-lone-ranger/   57201
# 14                           http://www.manofsteel.com/   49521
# 15                                                  NaN    2454
# 16                    http://marvel.com/avengers_movie/   24428
# 17    http://disney.go.com/pirates/index-on-stranger...    1865
# 18      http://www.sonypictures.com/movies/meninblack3/   41154
# 19                            http://www.thehobbit.com/  122917
# 20                   http://www.theamazingspiderman.com    1930
# 21                    http://www.robinhoodthemovie.com/   20662
# 22                            http://www.thehobbit.com/   57158
# 23    http://www.goldencompassmovie.com/index_german...    2268
# 24                                                  NaN     254
# 25                          http://www.titanicmovie.com     597
# 26             http://marvel.com/captainamericapremiere  271110
# 27                                                  NaN   44833
# 28                        http://www.jurassicworld.com/  135397
# 29                         http://www.skyfall-movie.com   37724
# ...                                                 ...     ...
# 4773               http://www.miramax.com/movie/clerks/    2292
# 4774                                                NaN   42497
# 4775                                                NaN   33693
# 4776                                                NaN   14585
# 4777                                                NaN  185465
# 4778                                                NaN   38780
# 4779                                                NaN   14022
# 4780                                                NaN  366967
# 4781             https://www.facebook.com/DrySpellMovie  255266
# 4782                                                NaN   17345
# 4783                                                NaN  226458
# 4784                  http://www.thepuffychairmovie.com   24055
# 4785                                                NaN  287625
# 4786                                                NaN   44990
# 4787                                                NaN   86304
# 4788                                                NaN     692
# 4789                                                NaN   39851
# 4790                                                NaN   13898
# 4791                      http://tincanmanthemovie.com/  157185
# 4792                                                NaN   36095
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# 4796                         http://www.primermovie.com   14337
# 4797                                                NaN   67238
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 6     [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 7     [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8     [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 9     [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
# 10    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 11    [{"id": 627, "name": "killing"}, {"id": 1568, ...                en
# 12    [{"id": 616, "name": "witch"}, {"id": 663, "na...                en
# 13    [{"id": 1556, "name": "texas"}, {"id": 2673, "...                en
# 14    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 15    [{"id": 818, "name": "based on novel"}, {"id":...                en
# 16    [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 17    [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
# 18    [{"id": 4379, "name": "time travel"}, {"id": 5...                en
# 19    [{"id": 417, "name": "corruption"}, {"id": 603...                en
# 20    [{"id": 1872, "name": "loss of father"}, {"id"...                en
# 21    [{"id": 4147, "name": "robin hood"}, {"id": 43...                en
# 22    [{"id": 603, "name": "elves"}, {"id": 604, "na...                en
# 23    [{"id": 392, "name": "england"}, {"id": 1461, ...                en
# 24    [{"id": 774, "name": "film business"}, {"id": ...                en
# 25    [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 26    [{"id": 393, "name": "civil war"}, {"id": 6091...                en
# 27    [{"id": 1721, "name": "fight"}, {"id": 4410, "...                en
# 28    [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 29    [{"id": 470, "name": "spy"}, {"id": 4289, "nam...                en
# ...                                                 ...               ...
# 4773  [{"id": 1361, "name": "salesclerk"}, {"id": 30...                en
# 4774  [{"id": 1566, "name": "dream"}, {"id": 13059, ...                en
# 4775             [{"id": 171993, "name": "mumblecore"}]                en
# 4776  [{"id": 1438, "name": "office"}, {"id": 9673, ...                en
# 4777                                                 []                en
# 4778  [{"id": 10022, "name": "rampage"}, {"id": 1454...                en
# 4779  [{"id": 305, "name": "moon"}, {"id": 490, "nam...                en
# 4780                                                 []                en
# 4781  [{"id": 13043, "name": "dating"}, {"id": 15160...                en
# 4782  [{"id": 186, "name": "christianity"}, {"id": 4...                en
# 4783               [{"id": 9712, "name": "possession"}]                en
# 4784             [{"id": 171993, "name": "mumblecore"}]                en
# 4785                                                 []                en
# 4786        [{"id": 10183, "name": "independent film"}]                en
# 4787                [{"id": 9715, "name": "superhero"}]                en
# 4788  [{"id": 237, "name": "gay"}, {"id": 900, "name...                en
# 4789  [{"id": 6782, "name": "addiction"}, {"id": 155...                en
# 4790                                                 []                fa
# 4791           [{"id": 14903, "name": "home invasion"}]                en
# 4792  [{"id": 233, "name": "japan"}, {"id": 549, "na...                ja
# 4793  [{"id": 718, "name": "confession"}, {"id": 100...                en
# 4794                                                 []                en
# 4795  [{"id": 10726, "name": "gang"}, {"id": 33928, ...                en
# 4796  [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 4797                                                 []                en
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                    original_title  \
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# 11                              Quantum of Solace
# 12     Pirates of the Caribbean: Dead Man's Chest
# 13                                The Lone Ranger
# 14                                   Man of Steel
# 15       The Chronicles of Narnia: Prince Caspian
# 16                                   The Avengers
# 17    Pirates of the Caribbean: On Stranger Tides
# 18                                 Men in Black 3
# 19      The Hobbit: The Battle of the Five Armies
# 20                         The Amazing Spider-Man
# 21                                     Robin Hood
# 22            The Hobbit: The Desolation of Smaug
# 23                             The Golden Compass
# 24                                      King Kong
# 25                                        Titanic
# 26                     Captain America: Civil War
# 27                                     Battleship
# 28                                 Jurassic World
# 29                                        Skyfall
# ...                                           ...
# 4773                                       Clerks
# 4774                               Pink Narcissus
# 4775                                  Funny Ha Ha
# 4776                        In the Company of Men
# 4777                                       Manito
# 4778                                      Rampage
# 4779                                      Slacker
# 4780                                  Dutch Kills
# 4781                                    Dry Spell
# 4782                                     Flywheel
# 4783                                     Backmask
# 4784                              The Puffy Chair
# 4785                         Stories of Our Lives
# 4786                             Breaking Upwards
# 4787                     All Superheroes Must Die
# 4788                               Pink Flamingos
# 4789                                        Clean
# 4790                                        دایره
# 4791                                  Tin Can Man
# 4792                                          キュア
# 4793                               On The Downlow
# 4794                 Sanctuary: Quite a Conundrum
# 4795                                         Bang
# 4796                                       Primer
# 4797                                       Cavite
# 4798                                  El Mariachi
# 4799                                    Newlyweds
# 4800                    Signed, Sealed, Delivered
# 4801                             Shanghai Calling
# 4802                            My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# 5     The seemingly invincible Spider-Man goes up ag...  115.699814
# 6     When the kingdom's most wanted-and most charmi...   48.681969
# 7     When Tony Stark tries to jumpstart a dormant p...  134.279229
# 8     As Harry begins his sixth year at Hogwarts, he...   98.885637
# 9     Fearing the actions of a god-like Super Hero l...  155.790452
# 10    Superman returns to discover his 5-year absenc...   57.925623
# 11    Quantum of Solace continues the adventures of ...  107.928811
# 12    Captain Jack Sparrow works his way out of a bl...  145.847379
# 13    The Texas Rangers chase down a gang of outlaws...   49.046956
# 14    A young boy learns that he has extraordinary p...   99.398009
# 15    One year after their incredible adventures in ...   53.978602
# 16    When an unexpected enemy emerges and threatens...  144.448633
# 17    Captain Jack Sparrow crosses paths with a woma...  135.413856
# 18    Agents J (Will Smith) and K (Tommy Lee Jones) ...   52.035179
# 19    Immediately after the events of The Desolation...  120.965743
# 20    Peter Parker is an outcast high schooler aband...   89.866276
# 21    When soldier Robin happens upon the dying Robe...   37.668301
# 22    The Dwarves, Bilbo and Gandalf have successful...   94.370564
# 23    After overhearing a shocking secret, precociou...   42.990906
# 24    In 1933 New York, an overly ambitious movie pr...   61.226010
# 25    84 years later, a 101-year-old woman named Ros...  100.025899
# 26    Following the events of Age of Ultron, the col...  198.372395
# 27    When mankind beams a radio signal into space, ...   64.928382
# 28    Twenty-two years after the events of Jurassic ...  418.708552
# 29    When Bond's latest assignment goes gravely wro...   93.004993
# ...                                                 ...         ...
# 4773  Convenience and video store clerks Dante and R...   19.748658
# 4774  An erotic poem set in the fantasies of a young...    0.027811
# 4775  Unsure of what to do next, 23-year-old Marnie ...    0.362633
# 4776  Two business executives--one an avowed misogyn...    2.634007
# 4777  Fifteen years ago, their Washington Heights ne...    0.039264
# 4778  The boredom of small town life is eating Bill ...    7.101197
# 4779  Presents a day in the life in Austin, Texas am...    3.320622
# 4780  A desperate ex-con is forced to gather his old...    0.038143
# 4781  Sasha tries to get her soon-to-be ex husband K...    0.048948
# 4782  Jay Austin wants to sell you a used car, but w...    1.048524
# 4783  During an all-night, drug-fueled party at an a...    3.619167
# 4784  Josh's life is pretty much in the toilet. He's...    1.243955
# 4785  Created by the members of a Nairobi-based arts...    0.327794
# 4786  'Breaking Upwards' explores a young, real-life...    0.674570
# 4787  Masked vigilantes Charge (Jason Trost), Cutthr...    3.545991
# 4788  Notorious Baltimore criminal and underground f...    4.553644
# 4789  After losing her husband to a heroin overdose,...    1.464566
# 4790  Various women struggle to function in the oppr...    1.193779
# 4791  Recently dumped by his girlfirend for another ...    0.332679
# 4792  A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 4793  Isaac and Angel are two young Latinos involved...    0.029757
# 4794  It should have been just a normal day of sex, ...    0.166513
# 4795  A young woman in L.A. is having a bad day: she...    0.918116
# 4796  Friends/fledgling entrepreneurs invent a devic...   23.307949
# 4797  Adam, a security guard, travels from Californi...    0.022173
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 6     [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...
# 8     [{"name": "Warner Bros.", "id": 6194}, {"name"...
# 9     [{"name": "DC Comics", "id": 429}, {"name": "A...
# 10    [{"name": "DC Comics", "id": 429}, {"name": "L...
# 11            [{"name": "Eon Productions", "id": 7576}]
# 12    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 13    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 14    [{"name": "Legendary Pictures", "id": 923}, {"...
# 15    [{"name": "Walt Disney", "id": 5888}, {"name":...
# 16    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 17    [{"name": "Walt Disney Pictures", "id": 2}, {"...
# 18    [{"name": "Amblin Entertainment", "id": 56}, {...
# 19    [{"name": "WingNut Films", "id": 11}, {"name":...
# 20    [{"name": "Columbia Pictures", "id": 5}, {"nam...
# 21    [{"name": "Imagine Entertainment", "id": 23}, ...
# 22    [{"name": "WingNut Films", "id": 11}, {"name":...
# 23    [{"name": "New Line Cinema", "id": 12}, {"name...
# 24    [{"name": "WingNut Films", "id": 11}, {"name":...
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...
# 26    [{"name": "Studio Babelsberg", "id": 264}, {"n...
# 27    [{"name": "Universal Pictures", "id": 33}, {"n...
# 28    [{"name": "Universal Studios", "id": 13}, {"na...
# 29             [{"name": "Columbia Pictures", "id": 5}]
# ...                                                 ...
# 4773  [{"name": "Miramax Films", "id": 14}, {"name":...
# 4774         [{"name": "Strand Releasing", "id": 3923}]
# 4775                                                 []
# 4776  [{"name": "Alliance Atlantis Communications", ...
# 4777                                                 []
# 4778  [{"name": "Boll Kino Beteiligungs GmbH & Co. K...
# 4779                                                 []
# 4780                                                 []
# 4781                                                 []
# 4782                                                 []
# 4783  [{"name": "GO Productions", "id": 2943}, {"nam...
# 4784                                                 []
# 4785                                                 []
# 4786                                                 []
# 4787               [{"name": "Grindfest", "id": 18818}]
# 4788     [{"name": "Dreamland Productions", "id": 407}]
# 4789                                                 []
# 4790  [{"name": "Jafar Panahi Film Productions", "id...
# 4791  [{"name": "Park Films", "id": 21871}, {"name":...
# 4792             [{"name": "Daiei Studios", "id": 881}]
# 4793        [{"name": "Iconoclast Films", "id": 26677}]
# 4794  [{"name": "Gold Lion Films", "id": 37870}, {"n...
# 4795  [{"name": "Asylum Films", "id": 10571}, {"name...
# 4796                 [{"name": "Thinkfilm", "id": 446}]
# 4797                                                 []
# 4798           [{"name": "Columbia Pictures", "id": 5}]
# 4799                                                 []
# 4800  [{"name": "Front Street Pictures", "id": 3958}...
# 4801                                                 []
# 4802  [{"name": "rusty bear entertainment", "id": 87...
#
#                                    production_countries release_date  \
# 0     [{"iso_3166_1": "US", "name": "United States o...   2009-12-10
# 1     [{"iso_3166_1": "US", "name": "United States o...   2007-05-19
# 2     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2015-10-26
# 3     [{"iso_3166_1": "US", "name": "United States o...   2012-07-16
# 4     [{"iso_3166_1": "US", "name": "United States o...   2012-03-07
# 5     [{"iso_3166_1": "US", "name": "United States o...   2007-05-01
# 6     [{"iso_3166_1": "US", "name": "United States o...   2010-11-24
# 7     [{"iso_3166_1": "US", "name": "United States o...   2015-04-22
# 8     [{"iso_3166_1": "GB", "name": "United Kingdom"...   2009-07-07
# 9     [{"iso_3166_1": "US", "name": "United States o...   2016-03-23
# 10    [{"iso_3166_1": "US", "name": "United States o...   2006-06-28
# 11    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2008-10-30
# 12    [{"iso_3166_1": "JM", "name": "Jamaica"}, {"is...   2006-06-20
# 13    [{"iso_3166_1": "US", "name": "United States o...   2013-07-03
# 14    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2013-06-12
# 15    [{"iso_3166_1": "CZ", "name": "Czech Republic"...   2008-05-15
# 16    [{"iso_3166_1": "US", "name": "United States o...   2012-04-25
# 17    [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
# 18    [{"iso_3166_1": "US", "name": "United States o...   2012-05-23
# 19    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2014-12-10
# 20    [{"iso_3166_1": "US", "name": "United States o...   2012-06-27
# 21    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2010-05-12
# 22    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2013-12-11
# 23    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2007-12-04
# 24    [{"iso_3166_1": "NZ", "name": "New Zealand"}, ...   2005-12-14
# 25    [{"iso_3166_1": "US", "name": "United States o...   1997-11-18
# 26    [{"iso_3166_1": "US", "name": "United States o...   2016-04-27
# 27    [{"iso_3166_1": "US", "name": "United States o...   2012-04-11
# 28    [{"iso_3166_1": "US", "name": "United States o...   2015-06-09
# 29    [{"iso_3166_1": "GB", "name": "United Kingdom"...   2012-10-25
# ...                                                 ...          ...
# 4773  [{"iso_3166_1": "US", "name": "United States o...   1994-09-13
# 4774  [{"iso_3166_1": "US", "name": "United States o...   1971-01-01
# 4775  [{"iso_3166_1": "US", "name": "United States o...   2002-09-20
# 4776  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   1997-01-19
# 4777  [{"iso_3166_1": "US", "name": "United States o...   2002-01-15
# 4778  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   2009-08-14
# 4779  [{"iso_3166_1": "US", "name": "United States o...   1990-07-27
# 4780                                                 []   2015-10-02
# 4781  [{"iso_3166_1": "US", "name": "United States o...   2013-02-14
# 4782  [{"iso_3166_1": "US", "name": "United States o...   2003-01-01
# 4783  [{"iso_3166_1": "US", "name": "United States o...   2015-01-16
# 4784                                                 []   2005-01-17
# 4785            [{"iso_3166_1": "KE", "name": "Kenya"}]   2014-09-05
# 4786  [{"iso_3166_1": "US", "name": "United States o...   2009-03-14
# 4787                                                 []   2011-10-26
# 4788  [{"iso_3166_1": "US", "name": "United States o...   1972-03-12
# 4789  [{"iso_3166_1": "GB", "name": "United Kingdom"...   2004-09-01
# 4790             [{"iso_3166_1": "IR", "name": "Iran"}]   2000-09-08
# 4791          [{"iso_3166_1": "IE", "name": "Ireland"}]   2007-01-01
# 4792            [{"iso_3166_1": "JP", "name": "Japan"}]   1997-11-06
# 4793  [{"iso_3166_1": "US", "name": "United States o...   2004-04-11
# 4794  [{"iso_3166_1": "US", "name": "United States o...   2012-01-20
# 4795  [{"iso_3166_1": "US", "name": "United States o...   1995-09-09
# 4796  [{"iso_3166_1": "US", "name": "United States o...   2004-10-08
# 4797                                                 []   2005-03-12
# 4798  [{"iso_3166_1": "MX", "name": "Mexico"}, {"iso...   1992-09-04
# 4799                                                 []   2011-12-26
# 4800  [{"iso_3166_1": "US", "name": "United States o...   2013-10-13
# 4801  [{"iso_3166_1": "US", "name": "United States o...   2012-05-03
# 4802  [{"iso_3166_1": "US", "name": "United States o...   2005-08-05
#
#          revenue  runtime                                   spoken_languages  \
# 0     2787965087    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1      961000000    169.0           [{"iso_639_1": "en", "name": "English"}]
# 2      880674609    148.0  [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3     1084939099    165.0           [{"iso_639_1": "en", "name": "English"}]
# 4      284139100    132.0           [{"iso_639_1": "en", "name": "English"}]
# 5      890871626    139.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 6      591794936    100.0           [{"iso_639_1": "en", "name": "English"}]
# 7     1405403694    141.0           [{"iso_639_1": "en", "name": "English"}]
# 8      933959197    153.0           [{"iso_639_1": "en", "name": "English"}]
# 9      873260194    151.0           [{"iso_639_1": "en", "name": "English"}]
# 10     391081192    154.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 11     586090727    106.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 12    1065659812    151.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 13      89289910    149.0           [{"iso_639_1": "en", "name": "English"}]
# 14     662845518    143.0           [{"iso_639_1": "en", "name": "English"}]
# 15     419651413    150.0           [{"iso_639_1": "en", "name": "English"}]
# 16    1519557910    143.0           [{"iso_639_1": "en", "name": "English"}]
# 17    1045713802    136.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 18     624026776    106.0           [{"iso_639_1": "en", "name": "English"}]
# 19     956019788    144.0           [{"iso_639_1": "en", "name": "English"}]
# 20     752215857    136.0           [{"iso_639_1": "en", "name": "English"}]
# 21     310669540    140.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 22     958400000    161.0           [{"iso_639_1": "en", "name": "English"}]
# 23     372234864    113.0  [{"iso_639_1": "is", "name": "\u00cdslenska"},...
# 24     550000000    187.0           [{"iso_639_1": "en", "name": "English"}]
# 25    1845034188    194.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 26    1153304495    147.0  [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...
# 27     303025485    131.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 28    1513528810    124.0           [{"iso_639_1": "en", "name": "English"}]
# 29    1108561013    143.0           [{"iso_639_1": "en", "name": "English"}]
# ...          ...      ...                                                ...
# 4773     3151130     92.0           [{"iso_639_1": "en", "name": "English"}]
# 4774           0     64.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 4775       76901     85.0           [{"iso_639_1": "en", "name": "English"}]
# 4776           0     97.0           [{"iso_639_1": "en", "name": "English"}]
# 4777           0     78.0  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...
# 4778           0     85.0           [{"iso_639_1": "en", "name": "English"}]
# 4779           0     97.0           [{"iso_639_1": "en", "name": "English"}]
# 4780           0     90.0                                                 []
# 4781           0     90.0           [{"iso_639_1": "en", "name": "English"}]
# 4782           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4783           0     91.0           [{"iso_639_1": "en", "name": "English"}]
# 4784           0     85.0                                                 []
# 4785           0     60.0  [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...
# 4786           0     88.0           [{"iso_639_1": "en", "name": "English"}]
# 4787           0     78.0           [{"iso_639_1": "en", "name": "English"}]
# 4788     6000000     93.0           [{"iso_639_1": "en", "name": "English"}]
# 4789           0    111.0  [{"iso_639_1": "cn", "name": "\u5e7f\u5dde\u8b...
# 4790           0     90.0  [{"iso_639_1": "fa", "name": "\u0641\u0627\u06...
# 4791           0     84.0           [{"iso_639_1": "en", "name": "English"}]
# 4792       99000    111.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...
# 4793           0     90.0                                                 []
# 4794           0     82.0           [{"iso_639_1": "en", "name": "English"}]
# 4795           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4796      424760     77.0           [{"iso_639_1": "en", "name": "English"}]
# 4797           0     80.0                                                 []
# 4798     2040920     81.0      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799           0     85.0                                                 []
# 4800           0    120.0           [{"iso_639_1": "en", "name": "English"}]
# 4801           0     98.0           [{"iso_639_1": "en", "name": "English"}]
# 4802           0     90.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 0     Released                        Enter the World of Pandora.
# 1     Released     At the end of the world, the adventure begins.
# 2     Released                              A Plan No One Escapes
# 3     Released                                    The Legend Ends
# 4     Released               Lost in our world, found in another.
# 5     Released                                 The battle within.
# 6     Released           They're taking adventure to new lengths.
# 7     Released                                A New Age Has Come.
# 8     Released                              Dark Secrets Revealed
# 9     Released                                 Justice or revenge
# 10    Released                                                NaN
# 11    Released      For love, for hate, for justice, for revenge.
# 12    Released                                      Jack is back!
# 13    Released                            Never Take Off the Mask
# 14    Released               You will believe that a man can fly.
# 15    Released                               Hope has a new face.
# 16    Released                            Some assembly required.
# 17    Released                        Live Forever Or Die Trying.
# 18    Released                          They are back... in time.
# 19    Released  Witness the defining chapter of the Middle-Ear...
# 20    Released                           The untold story begins.
# 21    Released     Rise and rise again, until lambs become lions.
# 22    Released  Beyond darkness... beyond desolation... lies t...
# 23    Released  There are worlds beyond our own - the compass ...
# 24    Released                    The eighth wonder of the world.
# 25    Released          Nothing on Earth could come between them.
# 26    Released                                    Divided We Fall
# 27    Released                 The Battle for Earth Begins at Sea
# 28    Released                                  The park is open.
# 29    Released                                Think on your sins.
# ...        ...                                                ...
# 4773  Released  Just because they serve you doesn't mean they ...
# 4774  Released             A unique experience in visual fantasy!
# 4775  Released                                                NaN
# 4776  Released      Are all men bastards...or just misunderstood?
# 4777  Released                                                NaN
# 4778  Released                             Vengeance is ruthless.
# 4779  Released                                                NaN
# 4780  Released                                                NaN
# 4781  Released       Getting divorced does funny things to a girl
# 4782  Released                                                NaN
# 4783  Released                                         nederlands
# 4784  Released                                                NaN
# 4785  Released                                                NaN
# 4786  Released                                                NaN
# 4787  Released                               May The Best Man Win
# 4788  Released                         An exercise in poor taste.
# 4789  Released          When you don't have a choice, you change.
# 4790  Released                                                NaN
# 4791  Released                    Everything You've Heard is True
# 4792  Released                           Madness. Terror. Murder.
# 4793  Released              Two gangs. One secret. One crossroad.
# 4794  Released                                                NaN
# 4795  Released            Sometimes you've got to break the rules
# 4796  Released                 What happens if it actually works?
# 4797  Released                                                NaN
# 4798  Released  He didn't come looking for trouble, but troubl...
# 4799  Released  A newlywed couple's honeymoon is upended by th...
# 4800  Released                                                NaN
# 4801  Released                           A New Yorker in Shanghai
# 4802  Released                                                NaN
#
#                                             title  vote_average  vote_count
# 0                                          Avatar           7.2       11800
# 1        Pirates of the Caribbean: At World's End           6.9        4500
# 2                                         Spectre           6.3        4466
# 3                           The Dark Knight Rises           7.6        9106
# 4                                     John Carter           6.1        2124
# 5                                    Spider-Man 3           5.9        3576
# 6                                         Tangled           7.4        3330
# 7                         Avengers: Age of Ultron           7.3        6767
# 8          Harry Potter and the Half-Blood Prince           7.4        5293
# 9              Batman v Superman: Dawn of Justice           5.7        7004
# 10                               Superman Returns           5.4        1400
# 11                              Quantum of Solace           6.1        2965
# 12     Pirates of the Caribbean: Dead Man's Chest           7.0        5246
# 13                                The Lone Ranger           5.9        2311
# 14                                   Man of Steel           6.5        6359
# 15       The Chronicles of Narnia: Prince Caspian           6.3        1630
# 16                                   The Avengers           7.4       11776
# 17    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 18                                 Men in Black 3           6.2        4160
# 19      The Hobbit: The Battle of the Five Armies           7.1        4760
# 20                         The Amazing Spider-Man           6.5        6586
# 21                                     Robin Hood           6.2        1398
# 22            The Hobbit: The Desolation of Smaug           7.6        4524
# 23                             The Golden Compass           5.8        1303
# 24                                      King Kong           6.6        2337
# 25                                        Titanic           7.5        7562
# 26                     Captain America: Civil War           7.1        7241
# 27                                     Battleship           5.5        2114
# 28                                 Jurassic World           6.5        8662
# 29                                        Skyfall           6.9        7604
# ...                                           ...           ...         ...
# 4773                                       Clerks           7.4         755
# 4774                               Pink Narcissus           6.0           9
# 4775                                  Funny Ha Ha           6.3           8
# 4776                        In the Company of Men           6.8          44
# 4777                                       Manito           5.5           2
# 4778                                      Rampage           6.0         131
# 4779                                      Slacker           6.4          77
# 4780                                  Dutch Kills           0.0           0
# 4781                                    Dry Spell           6.0           1
# 4782                                     Flywheel           6.8          19
# 4783                                     Backmask           4.7          79
# 4784                              The Puffy Chair           6.2          15
# 4785                         Stories of Our Lives           0.0           0
# 4786                             Breaking Upwards           5.6          12
# 4787                     All Superheroes Must Die           4.2          13
# 4788                               Pink Flamingos           6.2         110
# 4789                                        Clean           6.7          17
# 4790                                   The Circle           6.6          17
# 4791                                  Tin Can Man           2.0           1
# 4792                                         Cure           7.4          63
# 4793                               On The Downlow           6.0           2
# 4794                 Sanctuary: Quite a Conundrum           0.0           0
# 4795                                         Bang           6.0           1
# 4796                                       Primer           6.9         658
# 4797                                       Cavite           7.5           2
# 4798                                  El Mariachi           6.6         238
# 4799                                    Newlyweds           5.9           5
# 4800                    Signed, Sealed, Delivered           7.0           6
# 4801                             Shanghai Calling           5.7           7
# 4802                            My Date with Drew           6.3          16
#
# [4803 rows x 20 columns]

# %%
#run a vader on the df
compund = []
for index, row in string_lists.iterrows():

    try:
        results = analyzer.polarity_scores(string_lists["overview"][index])
        comp = results["compound"]  
#         compound.append(comp)  
    except:
        comp= results["compound"]
#         print(comp)
    compund.append(comp)

# %%
#add the results to the data frame
string_lists["compound_score"] = compund
string_lists
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13    255000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14    225000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15    225000000  [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17    380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 18    225000000  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 19    250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20    215000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 21    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 22    250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 23    180000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 24    207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26    250000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 27    209000000  [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29    200000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4774      27000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 4775          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4776          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4777          0                      [{"id": 18, "name": "Drama"}]
# 4778          0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 4779          0                     [{"id": 35, "name": "Comedy"}]
# 4780          0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4781      22000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4782          0  [{"id": 18, "name": "Drama"}, {"id": 10751, "n...
# 4783          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4784          0  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 4785          0                      [{"id": 18, "name": "Drama"}]
# 4786          0  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4787          0  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4789          0                      [{"id": 18, "name": "Drama"}]
# 4790          0  [{"id": 18, "name": "Drama"}, {"id": 10769, "n...
# 4791         13                     [{"id": 27, "name": "Horror"}]
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4793          0                      [{"id": 18, "name": "Drama"}]
# 4794          0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
# 4795          0                      [{"id": 18, "name": "Drama"}]
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4797          0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# 1          http://disney.go.com/disneypictures/pirates/     285
# 2           http://www.sonypictures.com/movies/spectre/  206647
# 3                    http://www.thedarkknightrises.com/   49026
# 4                  http://movies.disney.com/john-carter   49529
# 5       http://www.sonypictures.com/movies/spider-man3/     559
# 6          http://disney.go.com/disneypictures/tangled/   38757
# 7     http://marvel.com/movies/movie/193/avengers_ag...   99861
# 8     http://harrypotter.warnerbros.com/harrypottera...     767
# 9          http://www.batmanvsupermandawnofjustice.com/  209112
# 10                              http://www.superman.com    1452
# 11    http://www.mgm.com/view/movie/234/Quantum-of-S...   10764
# 12         http://disney.go.com/disneypictures/pirates/      58
# 13                http://disney.go.com/the-lone-ranger/   57201
# 14                           http://www.manofsteel.com/   49521
# 15                                                  NaN    2454
# 16                    http://marvel.com/avengers_movie/   24428
# 17    http://disney.go.com/pirates/index-on-stranger...    1865
# 18      http://www.sonypictures.com/movies/meninblack3/   41154
# 19                            http://www.thehobbit.com/  122917
# 20                   http://www.theamazingspiderman.com    1930
# 21                    http://www.robinhoodthemovie.com/   20662
# 22                            http://www.thehobbit.com/   57158
# 23    http://www.goldencompassmovie.com/index_german...    2268
# 24                                                  NaN     254
# 25                          http://www.titanicmovie.com     597
# 26             http://marvel.com/captainamericapremiere  271110
# 27                                                  NaN   44833
# 28                        http://www.jurassicworld.com/  135397
# 29                         http://www.skyfall-movie.com   37724
# ...                                                 ...     ...
# 4773               http://www.miramax.com/movie/clerks/    2292
# 4774                                                NaN   42497
# 4775                                                NaN   33693
# 4776                                                NaN   14585
# 4777                                                NaN  185465
# 4778                                                NaN   38780
# 4779                                                NaN   14022
# 4780                                                NaN  366967
# 4781             https://www.facebook.com/DrySpellMovie  255266
# 4782                                                NaN   17345
# 4783                                                NaN  226458
# 4784                  http://www.thepuffychairmovie.com   24055
# 4785                                                NaN  287625
# 4786                                                NaN   44990
# 4787                                                NaN   86304
# 4788                                                NaN     692
# 4789                                                NaN   39851
# 4790                                                NaN   13898
# 4791                      http://tincanmanthemovie.com/  157185
# 4792                                                NaN   36095
# 4793                                                NaN  182291
# 4794                                                NaN  286939
# 4795                                                NaN  124606
# 4796                         http://www.primermovie.com   14337
# 4797                                                NaN   67238
# 4798                                                NaN    9367
# 4799                                                NaN   72766
# 4800  http://www.hallmarkchannel.com/signedsealeddel...  231617
# 4801                        http://shanghaicalling.com/  126186
# 4802                                                NaN   25975
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5     [{"id": 851, "name": "dual identity"}, {"id": ...                en
# 6     [{"id": 1562, "name": "hostage"}, {"id": 2343,...                en
# 7     [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8     [{"id": 616, "name": "witch"}, {"id": 2343, "n...                en
# 9     [{"id": 849, "name": "dc comics"}, {"id": 7002...                en
# 10    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 11    [{"id": 627, "name": "killing"}, {"id": 1568, ...                en
# 12    [{"id": 616, "name": "witch"}, {"id": 663, "na...                en
# 13    [{"id": 1556, "name": "texas"}, {"id": 2673, "...                en
# 14    [{"id": 83, "name": "saving the world"}, {"id"...                en
# 15    [{"id": 818, "name": "based on novel"}, {"id":...                en
# 16    [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 17    [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
# 18    [{"id": 4379, "name": "time travel"}, {"id": 5...                en
# 19    [{"id": 417, "name": "corruption"}, {"id": 603...                en
# 20    [{"id": 1872, "name": "loss of father"}, {"id"...                en
# 21    [{"id": 4147, "name": "robin hood"}, {"id": 43...                en
# 22    [{"id": 603, "name": "elves"}, {"id": 604, "na...                en
# 23    [{"id": 392, "name": "england"}, {"id": 1461, ...                en
# 24    [{"id": 774, "name": "film business"}, {"id": ...                en
# 25    [{"id": 2580, "name": "shipwreck"}, {"id": 298...                en
# 26    [{"id": 393, "name": "civil war"}, {"id": 6091...                en
# 27    [{"id": 1721, "name": "fight"}, {"id": 4410, "...                en
# 28    [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 29    [{"id": 470, "name": "spy"}, {"id": 4289, "nam...                en
# ...                                                 ...               ...
# 4773  [{"id": 1361, "name": "salesclerk"}, {"id": 30...                en
# 4774  [{"id": 1566, "name": "dream"}, {"id": 13059, ...                en
# 4775             [{"id": 171993, "name": "mumblecore"}]                en
# 4776  [{"id": 1438, "name": "office"}, {"id": 9673, ...                en
# 4777                                                 []                en
# 4778  [{"id": 10022, "name": "rampage"}, {"id": 1454...                en
# 4779  [{"id": 305, "name": "moon"}, {"id": 490, "nam...                en
# 4780                                                 []                en
# 4781  [{"id": 13043, "name": "dating"}, {"id": 15160...                en
# 4782  [{"id": 186, "name": "christianity"}, {"id": 4...                en
# 4783               [{"id": 9712, "name": "possession"}]                en
# 4784             [{"id": 171993, "name": "mumblecore"}]                en
# 4785                                                 []                en
# 4786        [{"id": 10183, "name": "independent film"}]                en
# 4787                [{"id": 9715, "name": "superhero"}]                en
# 4788  [{"id": 237, "name": "gay"}, {"id": 900, "name...                en
# 4789  [{"id": 6782, "name": "addiction"}, {"id": 155...                en
# 4790                                                 []                fa
# 4791           [{"id": 14903, "name": "home invasion"}]                en
# 4792  [{"id": 233, "name": "japan"}, {"id": 549, "na...                ja
# 4793  [{"id": 718, "name": "confession"}, {"id": 100...                en
# 4794                                                 []                en
# 4795  [{"id": 10726, "name": "gang"}, {"id": 33928, ...                en
# 4796  [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 4797                                                 []                en
# 4798  [{"id": 5616, "name": "united states\u2013mexi...                es
# 4799                                                 []                en
# 4800  [{"id": 248, "name": "date"}, {"id": 699, "nam...                en
# 4801                                                 []                en
# 4802  [{"id": 1523, "name": "obsession"}, {"id": 224...                en
#
#                                    original_title  \
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# 11                              Quantum of Solace
# 12     Pirates of the Caribbean: Dead Man's Chest
# 13                                The Lone Ranger
# 14                                   Man of Steel
# 15       The Chronicles of Narnia: Prince Caspian
# 16                                   The Avengers
# 17    Pirates of the Caribbean: On Stranger Tides
# 18                                 Men in Black 3
# 19      The Hobbit: The Battle of the Five Armies
# 20                         The Amazing Spider-Man
# 21                                     Robin Hood
# 22            The Hobbit: The Desolation of Smaug
# 23                             The Golden Compass
# 24                                      King Kong
# 25                                        Titanic
# 26                     Captain America: Civil War
# 27                                     Battleship
# 28                                 Jurassic World
# 29                                        Skyfall
# ...                                           ...
# 4773                                       Clerks
# 4774                               Pink Narcissus
# 4775                                  Funny Ha Ha
# 4776                        In the Company of Men
# 4777                                       Manito
# 4778                                      Rampage
# 4779                                      Slacker
# 4780                                  Dutch Kills
# 4781                                    Dry Spell
# 4782                                     Flywheel
# 4783                                     Backmask
# 4784                              The Puffy Chair
# 4785                         Stories of Our Lives
# 4786                             Breaking Upwards
# 4787                     All Superheroes Must Die
# 4788                               Pink Flamingos
# 4789                                        Clean
# 4790                                        دایره
# 4791                                  Tin Can Man
# 4792                                          キュア
# 4793                               On The Downlow
# 4794                 Sanctuary: Quite a Conundrum
# 4795                                         Bang
# 4796                                       Primer
# 4797                                       Cavite
# 4798                                  El Mariachi
# 4799                                    Newlyweds
# 4800                    Signed, Sealed, Delivered
# 4801                             Shanghai Calling
# 4802                            My Date with Drew
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# 5     The seemingly invincible Spider-Man goes up ag...  115.699814
# 6     When the kingdom's most wanted-and most charmi...   48.681969
# 7     When Tony Stark tries to jumpstart a dormant p...  134.279229
# 8     As Harry begins his sixth year at Hogwarts, he...   98.885637
# 9     Fearing the actions of a god-like Super Hero l...  155.790452
# 10    Superman returns to discover his 5-year absenc...   57.925623
# 11    Quantum of Solace continues the adventures of ...  107.928811
# 12    Captain Jack Sparrow works his way out of a bl...  145.847379
# 13    The Texas Rangers chase down a gang of outlaws...   49.046956
# 14    A young boy learns that he has extraordinary p...   99.398009
# 15    One year after their incredible adventures in ...   53.978602
# 16    When an unexpected enemy emerges and threatens...  144.448633
# 17    Captain Jack Sparrow crosses paths with a woma...  135.413856
# 18    Agents J (Will Smith) and K (Tommy Lee Jones) ...   52.035179
# 19    Immediately after the events of The Desolation...  120.965743
# 20    Peter Parker is an outcast high schooler aband...   89.866276
# 21    When soldier Robin happens upon the dying Robe...   37.668301
# 22    The Dwarves, Bilbo and Gandalf have successful...   94.370564
# 23    After overhearing a shocking secret, precociou...   42.990906
# 24    In 1933 New York, an overly ambitious movie pr...   61.226010
# 25    84 years later, a 101-year-old woman named Ros...  100.025899
# 26    Following the events of Age of Ultron, the col...  198.372395
# 27    When mankind beams a radio signal into space, ...   64.928382
# 28    Twenty-two years after the events of Jurassic ...  418.708552
# 29    When Bond's latest assignment goes gravely wro...   93.004993
# ...                                                 ...         ...
# 4773  Convenience and video store clerks Dante and R...   19.748658
# 4774  An erotic poem set in the fantasies of a young...    0.027811
# 4775  Unsure of what to do next, 23-year-old Marnie ...    0.362633
# 4776  Two business executives--one an avowed misogyn...    2.634007
# 4777  Fifteen years ago, their Washington Heights ne...    0.039264
# 4778  The boredom of small town life is eating Bill ...    7.101197
# 4779  Presents a day in the life in Austin, Texas am...    3.320622
# 4780  A desperate ex-con is forced to gather his old...    0.038143
# 4781  Sasha tries to get her soon-to-be ex husband K...    0.048948
# 4782  Jay Austin wants to sell you a used car, but w...    1.048524
# 4783  During an all-night, drug-fueled party at an a...    3.619167
# 4784  Josh's life is pretty much in the toilet. He's...    1.243955
# 4785  Created by the members of a Nairobi-based arts...    0.327794
# 4786  'Breaking Upwards' explores a young, real-life...    0.674570
# 4787  Masked vigilantes Charge (Jason Trost), Cutthr...    3.545991
# 4788  Notorious Baltimore criminal and underground f...    4.553644
# 4789  After losing her husband to a heroin overdose,...    1.464566
# 4790  Various women struggle to function in the oppr...    1.193779
# 4791  Recently dumped by his girlfirend for another ...    0.332679
# 4792  A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 4793  Isaac and Angel are two young Latinos involved...    0.029757
# 4794  It should have been just a normal day of sex, ...    0.166513
# 4795  A young woman in L.A. is having a bad day: she...    0.918116
# 4796  Friends/fledgling entrepreneurs invent a devic...   23.307949
# 4797  Adam, a security guard, travels from Californi...    0.022173
# 4798  El Mariachi just wants to play his guitar and ...   14.269792
# 4799  A newlywed couple's honeymoon is upended by th...    0.642552
# 4800  "Signed, Sealed, Delivered" introduces a dedic...    1.444476
# 4801  When ambitious New York attorney Sam is sent t...    0.857008
# 4802  Ever since the second grade when he first saw ...    1.929883
#
#                                    production_companies       ...        \
# 0     [{"name": "Ingenious Film Partners", "id": 289...       ...
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...       ...
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...       ...
# 4           [{"name": "Walt Disney Pictures", "id": 2}]       ...
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...       ...
# 6     [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...       ...
# 8     [{"name": "Warner Bros.", "id": 6194}, {"name"...       ...
# 9     [{"name": "DC Comics", "id": 429}, {"name": "A...       ...
# 10    [{"name": "DC Comics", "id": 429}, {"name": "L...       ...
# 11            [{"name": "Eon Productions", "id": 7576}]       ...
# 12    [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
# 13    [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
# 14    [{"name": "Legendary Pictures", "id": 923}, {"...       ...
# 15    [{"name": "Walt Disney", "id": 5888}, {"name":...       ...
# 16    [{"name": "Paramount Pictures", "id": 4}, {"na...       ...
# 17    [{"name": "Walt Disney Pictures", "id": 2}, {"...       ...
# 18    [{"name": "Amblin Entertainment", "id": 56}, {...       ...
# 19    [{"name": "WingNut Films", "id": 11}, {"name":...       ...
# 20    [{"name": "Columbia Pictures", "id": 5}, {"nam...       ...
# 21    [{"name": "Imagine Entertainment", "id": 23}, ...       ...
# 22    [{"name": "WingNut Films", "id": 11}, {"name":...       ...
# 23    [{"name": "New Line Cinema", "id": 12}, {"name...       ...
# 24    [{"name": "WingNut Films", "id": 11}, {"name":...       ...
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...       ...
# 26    [{"name": "Studio Babelsberg", "id": 264}, {"n...       ...
# 27    [{"name": "Universal Pictures", "id": 33}, {"n...       ...
# 28    [{"name": "Universal Studios", "id": 13}, {"na...       ...
# 29             [{"name": "Columbia Pictures", "id": 5}]       ...
# ...                                                 ...       ...
# 4773  [{"name": "Miramax Films", "id": 14}, {"name":...       ...
# 4774         [{"name": "Strand Releasing", "id": 3923}]       ...
# 4775                                                 []       ...
# 4776  [{"name": "Alliance Atlantis Communications", ...       ...
# 4777                                                 []       ...
# 4778  [{"name": "Boll Kino Beteiligungs GmbH & Co. K...       ...
# 4779                                                 []       ...
# 4780                                                 []       ...
# 4781                                                 []       ...
# 4782                                                 []       ...
# 4783  [{"name": "GO Productions", "id": 2943}, {"nam...       ...
# 4784                                                 []       ...
# 4785                                                 []       ...
# 4786                                                 []       ...
# 4787               [{"name": "Grindfest", "id": 18818}]       ...
# 4788     [{"name": "Dreamland Productions", "id": 407}]       ...
# 4789                                                 []       ...
# 4790  [{"name": "Jafar Panahi Film Productions", "id...       ...
# 4791  [{"name": "Park Films", "id": 21871}, {"name":...       ...
# 4792             [{"name": "Daiei Studios", "id": 881}]       ...
# 4793        [{"name": "Iconoclast Films", "id": 26677}]       ...
# 4794  [{"name": "Gold Lion Films", "id": 37870}, {"n...       ...
# 4795  [{"name": "Asylum Films", "id": 10571}, {"name...       ...
# 4796                 [{"name": "Thinkfilm", "id": 446}]       ...
# 4797                                                 []       ...
# 4798           [{"name": "Columbia Pictures", "id": 5}]       ...
# 4799                                                 []       ...
# 4800  [{"name": "Front Street Pictures", "id": 3958}...       ...
# 4801                                                 []       ...
# 4802  [{"name": "rusty bear entertainment", "id": 87...       ...
#
#      release_date     revenue  runtime  \
# 0      2009-12-10  2787965087    162.0
# 1      2007-05-19   961000000    169.0
# 2      2015-10-26   880674609    148.0
# 3      2012-07-16  1084939099    165.0
# 4      2012-03-07   284139100    132.0
# 5      2007-05-01   890871626    139.0
# 6      2010-11-24   591794936    100.0
# 7      2015-04-22  1405403694    141.0
# 8      2009-07-07   933959197    153.0
# 9      2016-03-23   873260194    151.0
# 10     2006-06-28   391081192    154.0
# 11     2008-10-30   586090727    106.0
# 12     2006-06-20  1065659812    151.0
# 13     2013-07-03    89289910    149.0
# 14     2013-06-12   662845518    143.0
# 15     2008-05-15   419651413    150.0
# 16     2012-04-25  1519557910    143.0
# 17     2011-05-14  1045713802    136.0
# 18     2012-05-23   624026776    106.0
# 19     2014-12-10   956019788    144.0
# 20     2012-06-27   752215857    136.0
# 21     2010-05-12   310669540    140.0
# 22     2013-12-11   958400000    161.0
# 23     2007-12-04   372234864    113.0
# 24     2005-12-14   550000000    187.0
# 25     1997-11-18  1845034188    194.0
# 26     2016-04-27  1153304495    147.0
# 27     2012-04-11   303025485    131.0
# 28     2015-06-09  1513528810    124.0
# 29     2012-10-25  1108561013    143.0
# ...           ...         ...      ...
# 4773   1994-09-13     3151130     92.0
# 4774   1971-01-01           0     64.0
# 4775   2002-09-20       76901     85.0
# 4776   1997-01-19           0     97.0
# 4777   2002-01-15           0     78.0
# 4778   2009-08-14           0     85.0
# 4779   1990-07-27           0     97.0
# 4780   2015-10-02           0     90.0
# 4781   2013-02-14           0     90.0
# 4782   2003-01-01           0    120.0
# 4783   2015-01-16           0     91.0
# 4784   2005-01-17           0     85.0
# 4785   2014-09-05           0     60.0
# 4786   2009-03-14           0     88.0
# 4787   2011-10-26           0     78.0
# 4788   1972-03-12     6000000     93.0
# 4789   2004-09-01           0    111.0
# 4790   2000-09-08           0     90.0
# 4791   2007-01-01           0     84.0
# 4792   1997-11-06       99000    111.0
# 4793   2004-04-11           0     90.0
# 4794   2012-01-20           0     82.0
# 4795   1995-09-09           0     98.0
# 4796   2004-10-08      424760     77.0
# 4797   2005-03-12           0     80.0
# 4798   1992-09-04     2040920     81.0
# 4799   2011-12-26           0     85.0
# 4800   2013-10-13           0    120.0
# 4801   2012-05-03           0     98.0
# 4802   2005-08-05           0     90.0
#
#                                        spoken_languages    status  \
# 0     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1              [{"iso_639_1": "en", "name": "English"}]  Released
# 2     [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...  Released
# 3              [{"iso_639_1": "en", "name": "English"}]  Released
# 4              [{"iso_639_1": "en", "name": "English"}]  Released
# 5     [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 6              [{"iso_639_1": "en", "name": "English"}]  Released
# 7              [{"iso_639_1": "en", "name": "English"}]  Released
# 8              [{"iso_639_1": "en", "name": "English"}]  Released
# 9              [{"iso_639_1": "en", "name": "English"}]  Released
# 10    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 11    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 12    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 13             [{"iso_639_1": "en", "name": "English"}]  Released
# 14             [{"iso_639_1": "en", "name": "English"}]  Released
# 15             [{"iso_639_1": "en", "name": "English"}]  Released
# 16             [{"iso_639_1": "en", "name": "English"}]  Released
# 17    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 18             [{"iso_639_1": "en", "name": "English"}]  Released
# 19             [{"iso_639_1": "en", "name": "English"}]  Released
# 20             [{"iso_639_1": "en", "name": "English"}]  Released
# 21    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 22             [{"iso_639_1": "en", "name": "English"}]  Released
# 23    [{"iso_639_1": "is", "name": "\u00cdslenska"},...  Released
# 24             [{"iso_639_1": "en", "name": "English"}]  Released
# 25    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 26    [{"iso_639_1": "ro", "name": "Rom\u00e2n\u0103...  Released
# 27    [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 28             [{"iso_639_1": "en", "name": "English"}]  Released
# 29             [{"iso_639_1": "en", "name": "English"}]  Released
# ...                                                 ...       ...
# 4773           [{"iso_639_1": "en", "name": "English"}]  Released
# 4774  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 4775           [{"iso_639_1": "en", "name": "English"}]  Released
# 4776           [{"iso_639_1": "en", "name": "English"}]  Released
# 4777  [{"iso_639_1": "es", "name": "Espa\u00f1ol"}, ...  Released
# 4778           [{"iso_639_1": "en", "name": "English"}]  Released
# 4779           [{"iso_639_1": "en", "name": "English"}]  Released
# 4780                                                 []  Released
# 4781           [{"iso_639_1": "en", "name": "English"}]  Released
# 4782           [{"iso_639_1": "en", "name": "English"}]  Released
# 4783           [{"iso_639_1": "en", "name": "English"}]  Released
# 4784                                                 []  Released
# 4785  [{"iso_639_1": "sw", "name": "Kiswahili"}, {"i...  Released
# 4786           [{"iso_639_1": "en", "name": "English"}]  Released
# 4787           [{"iso_639_1": "en", "name": "English"}]  Released
# 4788           [{"iso_639_1": "en", "name": "English"}]  Released
# 4789  [{"iso_639_1": "cn", "name": "\u5e7f\u5dde\u8b...  Released
# 4790  [{"iso_639_1": "fa", "name": "\u0641\u0627\u06...  Released
# 4791           [{"iso_639_1": "en", "name": "English"}]  Released
# 4792  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...  Released
# 4793                                                 []  Released
# 4794           [{"iso_639_1": "en", "name": "English"}]  Released
# 4795           [{"iso_639_1": "en", "name": "English"}]  Released
# 4796           [{"iso_639_1": "en", "name": "English"}]  Released
# 4797                                                 []  Released
# 4798      [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]  Released
# 4799                                                 []  Released
# 4800           [{"iso_639_1": "en", "name": "English"}]  Released
# 4801           [{"iso_639_1": "en", "name": "English"}]  Released
# 4802           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# 5                                    The battle within.
# 6              They're taking adventure to new lengths.
# 7                                   A New Age Has Come.
# 8                                 Dark Secrets Revealed
# 9                                    Justice or revenge
# 10                                                  NaN
# 11        For love, for hate, for justice, for revenge.
# 12                                        Jack is back!
# 13                              Never Take Off the Mask
# 14                 You will believe that a man can fly.
# 15                                 Hope has a new face.
# 16                              Some assembly required.
# 17                          Live Forever Or Die Trying.
# 18                            They are back... in time.
# 19    Witness the defining chapter of the Middle-Ear...
# 20                             The untold story begins.
# 21       Rise and rise again, until lambs become lions.
# 22    Beyond darkness... beyond desolation... lies t...
# 23    There are worlds beyond our own - the compass ...
# 24                      The eighth wonder of the world.
# 25            Nothing on Earth could come between them.
# 26                                      Divided We Fall
# 27                   The Battle for Earth Begins at Sea
# 28                                    The park is open.
# 29                                  Think on your sins.
# ...                                                 ...
# 4773  Just because they serve you doesn't mean they ...
# 4774             A unique experience in visual fantasy!
# 4775                                                NaN
# 4776      Are all men bastards...or just misunderstood?
# 4777                                                NaN
# 4778                             Vengeance is ruthless.
# 4779                                                NaN
# 4780                                                NaN
# 4781       Getting divorced does funny things to a girl
# 4782                                                NaN
# 4783                                         nederlands
# 4784                                                NaN
# 4785                                                NaN
# 4786                                                NaN
# 4787                               May The Best Man Win
# 4788                         An exercise in poor taste.
# 4789          When you don't have a choice, you change.
# 4790                                                NaN
# 4791                    Everything You've Heard is True
# 4792                           Madness. Terror. Murder.
# 4793              Two gangs. One secret. One crossroad.
# 4794                                                NaN
# 4795            Sometimes you've got to break the rules
# 4796                 What happens if it actually works?
# 4797                                                NaN
# 4798  He didn't come looking for trouble, but troubl...
# 4799  A newlywed couple's honeymoon is upended by th...
# 4800                                                NaN
# 4801                           A New Yorker in Shanghai
# 4802                                                NaN
#
#                                             title vote_average  vote_count  \
# 0                                          Avatar          7.2       11800
# 1        Pirates of the Caribbean: At World's End          6.9        4500
# 2                                         Spectre          6.3        4466
# 3                           The Dark Knight Rises          7.6        9106
# 4                                     John Carter          6.1        2124
# 5                                    Spider-Man 3          5.9        3576
# 6                                         Tangled          7.4        3330
# 7                         Avengers: Age of Ultron          7.3        6767
# 8          Harry Potter and the Half-Blood Prince          7.4        5293
# 9              Batman v Superman: Dawn of Justice          5.7        7004
# 10                               Superman Returns          5.4        1400
# 11                              Quantum of Solace          6.1        2965
# 12     Pirates of the Caribbean: Dead Man's Chest          7.0        5246
# 13                                The Lone Ranger          5.9        2311
# 14                                   Man of Steel          6.5        6359
# 15       The Chronicles of Narnia: Prince Caspian          6.3        1630
# 16                                   The Avengers          7.4       11776
# 17    Pirates of the Caribbean: On Stranger Tides          6.4        4948
# 18                                 Men in Black 3          6.2        4160
# 19      The Hobbit: The Battle of the Five Armies          7.1        4760
# 20                         The Amazing Spider-Man          6.5        6586
# 21                                     Robin Hood          6.2        1398
# 22            The Hobbit: The Desolation of Smaug          7.6        4524
# 23                             The Golden Compass          5.8        1303
# 24                                      King Kong          6.6        2337
# 25                                        Titanic          7.5        7562
# 26                     Captain America: Civil War          7.1        7241
# 27                                     Battleship          5.5        2114
# 28                                 Jurassic World          6.5        8662
# 29                                        Skyfall          6.9        7604
# ...                                           ...          ...         ...
# 4773                                       Clerks          7.4         755
# 4774                               Pink Narcissus          6.0           9
# 4775                                  Funny Ha Ha          6.3           8
# 4776                        In the Company of Men          6.8          44
# 4777                                       Manito          5.5           2
# 4778                                      Rampage          6.0         131
# 4779                                      Slacker          6.4          77
# 4780                                  Dutch Kills          0.0           0
# 4781                                    Dry Spell          6.0           1
# 4782                                     Flywheel          6.8          19
# 4783                                     Backmask          4.7          79
# 4784                              The Puffy Chair          6.2          15
# 4785                         Stories of Our Lives          0.0           0
# 4786                             Breaking Upwards          5.6          12
# 4787                     All Superheroes Must Die          4.2          13
# 4788                               Pink Flamingos          6.2         110
# 4789                                        Clean          6.7          17
# 4790                                   The Circle          6.6          17
# 4791                                  Tin Can Man          2.0           1
# 4792                                         Cure          7.4          63
# 4793                               On The Downlow          6.0           2
# 4794                 Sanctuary: Quite a Conundrum          0.0           0
# 4795                                         Bang          6.0           1
# 4796                                       Primer          6.9         658
# 4797                                       Cavite          7.5           2
# 4798                                  El Mariachi          6.6         238
# 4799                                    Newlyweds          5.9           5
# 4800                    Signed, Sealed, Delivered          7.0           6
# 4801                             Shanghai Calling          5.7           7
# 4802                            My Date with Drew          6.3          16
#
#       compound_score
# 0            -0.3612
# 1            -0.3919
# 2            -0.8271
# 3            -0.9136
# 4            -0.7096
# 5             0.5859
# 6             0.4215
# 7            -0.3182
# 8             0.0000
# 9             0.3612
# 10           -0.7579
# 11            0.0609
# 12           -0.8074
# 13            0.1901
# 14            0.9331
# 15           -0.4939
# 16           -0.6696
# 17           -0.2411
# 18            0.6486
# 19            0.2500
# 20            0.1531
# 21            0.5994
# 22            0.7003
# 23            0.1280
# 24            0.4767
# 25            0.8074
# 26           -0.3818
# 27            0.6486
# 28            0.0000
# 29           -0.0516
# ...              ...
# 4773          0.4588
# 4774          0.0000
# 4775          0.9006
# 4776          0.3597
# 4777          0.6946
# 4778         -0.9287
# 4779         -0.2755
# 4780         -0.9287
# 4781          0.0000
# 4782         -0.8122
# 4783         -0.4951
# 4784         -0.4569
# 4785          0.3612
# 4786          0.6597
# 4787         -0.8495
# 4788         -0.4215
# 4789         -0.8176
# 4790         -0.3182
# 4791         -0.5719
# 4792         -0.7597
# 4793         -0.4215
# 4794         -0.3071
# 4795         -0.9567
# 4796          0.6124
# 4797         -0.8957
# 4798         -0.9493
# 4799          0.4215
# 4800          0.6187
# 4801          0.9764
# 4802         -0.0258
#
# [4803 rows x 21 columns]

# %%
#append the api data frame to the inital data
merged_df = string_lists.append(api_df)

#reset the index and remove unwanted columns
merged_df = merged_df.reset_index()
merged_df = merged_df[["budget", "compound_score", "genres", "original_title", "production_companies", "release_date", "revenue",
                      "runtime", "vote_average", "vote_count"]]
merged_df
# Out:
#          budget  compound_score  \
# 0     237000000         -0.3612
# 1     300000000         -0.3919
# 2     245000000         -0.8271
# 3     250000000         -0.9136
# 4     260000000         -0.7096
# 5     258000000          0.5859
# 6     260000000          0.4215
# 7     280000000         -0.3182
# 8     250000000          0.0000
# 9     250000000          0.3612
# 10    270000000         -0.7579
# 11    200000000          0.0609
# 12    200000000         -0.8074
# 13    255000000          0.1901
# 14    225000000          0.9331
# 15    225000000         -0.4939
# 16    220000000         -0.6696
# 17    380000000         -0.2411
# 18    225000000          0.6486
# 19    250000000          0.2500
# 20    215000000          0.1531
# 21    200000000          0.5994
# 22    250000000          0.7003
# 23    180000000          0.1280
# 24    207000000          0.4767
# 25    200000000          0.8074
# 26    250000000         -0.3818
# 27    209000000          0.6486
# 28    150000000          0.0000
# 29    200000000         -0.0516
# ...         ...             ...
# 5114          0          0.8225
# 5115          0         -0.7096
# 5116          0          0.6369
# 5117          0         -0.1531
# 5118          0          0.4404
# 5119          0          0.4019
# 5120          0         -0.9366
# 5121    1050000          0.4404
# 5122          0         -0.4588
# 5123          0         -0.2500
# 5124          0         -0.8519
# 5125          0          0.3818
# 5126          0          0.7964
# 5127          0         -0.7750
# 5128          0         -0.2263
# 5129          0         -0.1195
# 5130          0         -0.4404
# 5131          0          0.6369
# 5132    1000000          0.7351
# 5133          0          0.6124
# 5134          0          0.0621
# 5135          0         -0.7906
# 5136          0         -0.7717
# 5137          0          0.0772
# 5138          0          0.8225
# 5139          0          0.5719
# 5140          0          0.6767
# 5141          0         -0.1027
# 5142          0          0.4678
# 5143          0          0.8555
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 15    [{"id": 12, "name": "Adventure"}, {"id": 10751...
# 16    [{"id": 878, "name": "Science Fiction"}, {"id"...
# 17    [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 18    [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 19    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 20    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 21    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 22    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 23    [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 24    [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 25    [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 26    [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 27    [{"id": 53, "name": "Thriller"}, {"id": 28, "n...
# 28    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 29    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 5114  [{"id": 35, "name": "Comedy"}, {"id": 10402, "...
# 5115  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 5116  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 5117                     [{"id": 35, "name": "Comedy"}]
# 5118                 [{"id": 10749, "name": "Romance"}]
# 5119                     [{"id": 35, "name": "Comedy"}]
# 5120  [{"id": 35, "name": "Comedy"}, {"id": 80, "nam...
# 5121                      [{"id": 18, "name": "Drama"}]
# 5122           [{"id": 878, "name": "Science Fiction"}]
# 5123                     [{"id": 35, "name": "Comedy"}]
# 5124                     [{"id": 35, "name": "Comedy"}]
# 5125                [{"id": 99, "name": "Documentary"}]
# 5126                      [{"id": 18, "name": "Drama"}]
# 5127  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 5128  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 5129                     [{"id": 35, "name": "Comedy"}]
# 5130                     [{"id": 35, "name": "Comedy"}]
# 5131                      [{"id": 18, "name": "Drama"}]
# 5132                [{"id": 99, "name": "Documentary"}]
# 5133  [{"id": 28, "name": "Action"}, {"id": 35, "nam...
# 5134                     [{"id": 35, "name": "Comedy"}]
# 5135                     [{"id": 35, "name": "Comedy"}]
# 5136  [{"id": 18, "name": "Drama"}, {"id": 53, "name...
# 5137  [{"id": 10749, "name": "Romance"}, {"id": 35, ...
# 5138                [{"id": 99, "name": "Documentary"}]
# 5139  [{"id": 10402, "name": "Music"}, {"id": 18, "n...
# 5140  [{"id": 10749, "name": "Romance"}, {"id": 18, ...
# 5141  [{"id": 18, "name": "Drama"}, {"id": 35, "name...
# 5142  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 5143                 [{"id": 10749, "name": "Romance"}]
#
#                                    original_title  \
# 0                                          Avatar
# 1        Pirates of the Caribbean: At World's End
# 2                                         Spectre
# 3                           The Dark Knight Rises
# 4                                     John Carter
# 5                                    Spider-Man 3
# 6                                         Tangled
# 7                         Avengers: Age of Ultron
# 8          Harry Potter and the Half-Blood Prince
# 9              Batman v Superman: Dawn of Justice
# 10                               Superman Returns
# 11                              Quantum of Solace
# 12     Pirates of the Caribbean: Dead Man's Chest
# 13                                The Lone Ranger
# 14                                   Man of Steel
# 15       The Chronicles of Narnia: Prince Caspian
# 16                                   The Avengers
# 17    Pirates of the Caribbean: On Stranger Tides
# 18                                 Men in Black 3
# 19      The Hobbit: The Battle of the Five Armies
# 20                         The Amazing Spider-Man
# 21                                     Robin Hood
# 22            The Hobbit: The Desolation of Smaug
# 23                             The Golden Compass
# 24                                      King Kong
# 25                                        Titanic
# 26                     Captain America: Civil War
# 27                                     Battleship
# 28                                 Jurassic World
# 29                                        Skyfall
# ...                                           ...
# 5114                                   La llamada
# 5115                                The Discovery
# 5116                                The Last Word
# 5117                                    Coexister
# 5118                           A Christmas Prince
# 5119                                 The Outcasts
# 5120   I Don't Feel at Home in This World Anymore
# 5121                               Handsome Devil
# 5122                                   The Recall
# 5123                                 Carrie Pilby
# 5124                  Goon: Last of the Enforcers
# 5125                 Jim & Andy: The Great Beyond
# 5126                        La Promesse de l'aube
# 5127            Smetto quando voglio - Ad honorem
# 5128                                        Seuls
# 5129                            Sous le même toit
# 5130                                Mamma o papà?
# 5131                                    The Place
# 5132                          I Am Not Your Negro
# 5133           Smetto quando voglio - Masterclass
# 5134                                 L'ora legale
# 5135                              Moglie e marito
# 5136                                     Monolith
# 5137                              Mister Felicità
# 5138              Chris Brown: Welcome to My Life
# 5139                                Dirty Dancing
# 5140                    Monsieur & Madame Adelman
# 5141                                       Pieles
# 5142                                    Le Manoir
# 5143                                         Amar
#
#                                    production_companies release_date  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...   2007-05-19
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...   2015-10-26
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...   2012-07-16
# 4           [{"name": "Walt Disney Pictures", "id": 2}]   2012-03-07
# 5     [{"name": "Columbia Pictures", "id": 5}, {"nam...   2007-05-01
# 6     [{"name": "Walt Disney Pictures", "id": 2}, {"...   2010-11-24
# 7     [{"name": "Marvel Studios", "id": 420}, {"name...   2015-04-22
# 8     [{"name": "Warner Bros.", "id": 6194}, {"name"...   2009-07-07
# 9     [{"name": "DC Comics", "id": 429}, {"name": "A...   2016-03-23
# 10    [{"name": "DC Comics", "id": 429}, {"name": "L...   2006-06-28
# 11            [{"name": "Eon Productions", "id": 7576}]   2008-10-30
# 12    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2006-06-20
# 13    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2013-07-03
# 14    [{"name": "Legendary Pictures", "id": 923}, {"...   2013-06-12
# 15    [{"name": "Walt Disney", "id": 5888}, {"name":...   2008-05-15
# 16    [{"name": "Paramount Pictures", "id": 4}, {"na...   2012-04-25
# 17    [{"name": "Walt Disney Pictures", "id": 2}, {"...   2011-05-14
# 18    [{"name": "Amblin Entertainment", "id": 56}, {...   2012-05-23
# 19    [{"name": "WingNut Films", "id": 11}, {"name":...   2014-12-10
# 20    [{"name": "Columbia Pictures", "id": 5}, {"nam...   2012-06-27
# 21    [{"name": "Imagine Entertainment", "id": 23}, ...   2010-05-12
# 22    [{"name": "WingNut Films", "id": 11}, {"name":...   2013-12-11
# 23    [{"name": "New Line Cinema", "id": 12}, {"name...   2007-12-04
# 24    [{"name": "WingNut Films", "id": 11}, {"name":...   2005-12-14
# 25    [{"name": "Paramount Pictures", "id": 4}, {"na...   1997-11-18
# 26    [{"name": "Studio Babelsberg", "id": 264}, {"n...   2016-04-27
# 27    [{"name": "Universal Pictures", "id": 33}, {"n...   2012-04-11
# 28    [{"name": "Universal Studios", "id": 13}, {"na...   2015-06-09
# 29             [{"name": "Columbia Pictures", "id": 5}]   2012-10-25
# ...                                                 ...          ...
# 5114  [{"id": 103, "logo_path": None, "name": "TVE",...   2017-09-29
# 5115  [{"id": 20277, "logo_path": None, "name": "Pro...   2017-03-31
# 5116  [{"id": 90445, "logo_path": None, "name": "Fra...   2017-03-03
# 5117  [{"id": 85026, "logo_path": None, "name": "che...   2017-10-11
# 5118  [{"id": 2090, "logo_path": "/iEFWMfcmFSyCYJCnH...   2017-11-17
# 5119  [{"id": 10290, "logo_path": None, "name": "BCD...   2017-04-14
# 5120  [{"id": 12142, "logo_path": "/rPnEeMwxjI6rYMGq...   2017-01-19
# 5121  [{"id": 21872, "logo_path": None, "name": "Tre...   2017-02-15
# 5122  [{"id": 23688, "logo_path": None, "name": "VMI...   2017-06-02
# 5123  [{"id": 53002, "logo_path": None, "name": "Bra...   2017-03-31
# 5124  [{"id": 6623, "logo_path": "/qvtEf5tM9IAEJUUhX...   2017-03-17
# 5125  [{"id": 17209, "logo_path": None, "name": "Vic...   2017-09-05
# 5126  [{"id": 7561, "logo_path": None, "name": "Nexu...   2017-12-20
# 5127  [{"id": 86177, "logo_path": None, "name": "Gro...   2017-11-30
# 5128  [{"id": 694, "logo_path": "/5LEHONGkZBIoWvp1yg...   2017-02-08
# 5129  [{"id": 356, "logo_path": "/9tW5wZEGotn1Ei5pEr...   2017-04-19
# 5130                                                 []   2017-02-14
# 5131  [{"id": 32434, "logo_path": None, "name": "Lot...   2017-11-04
# 5132  [{"id": 1030, "logo_path": None, "name": "Magn...   2017-02-03
# 5133  [{"id": 2683, "logo_path": "/mOL2WcHtox2urbUf1...   2017-02-02
# 5134  [{"id": 6246, "logo_path": None, "name": "Medu...   2017-01-19
# 5135  [{"id": 86177, "logo_path": None, "name": "Gro...   2017-04-13
# 5136  [{"id": 53597, "logo_path": None, "name": "Sky...   2017-04-20
# 5137  [{"id": 10102, "logo_path": None, "name": "Cat...   2017-01-01
# 5138  [{"id": 90025, "logo_path": None, "name": "RIV...   2017-06-08
# 5139  [{"id": 28523, "logo_path": None, "name": "Lio...   2017-05-24
# 5140  [{"id": 5125, "logo_path": "/t3oWTsVukmEzrZzvf...   2017-03-08
# 5141  [{"id": 32485, "logo_path": None, "name": "Pok...   2017-04-15
# 5142  [{"id": 13800, "logo_path": None, "name": "Gau...   2017-06-21
# 5143  [{"id": 103, "logo_path": None, "name": "TVE",...   2017-04-21
#
#          revenue  runtime  vote_average  vote_count
# 0     2787965087    162.0           7.2       11800
# 1      961000000    169.0           6.9        4500
# 2      880674609    148.0           6.3        4466
# 3     1084939099    165.0           7.6        9106
# 4      284139100    132.0           6.1        2124
# 5      890871626    139.0           5.9        3576
# 6      591794936    100.0           7.4        3330
# 7     1405403694    141.0           7.3        6767
# 8      933959197    153.0           7.4        5293
# 9      873260194    151.0           5.7        7004
# 10     391081192    154.0           5.4        1400
# 11     586090727    106.0           6.1        2965
# 12    1065659812    151.0           7.0        5246
# 13      89289910    149.0           5.9        2311
# 14     662845518    143.0           6.5        6359
# 15     419651413    150.0           6.3        1630
# 16    1519557910    143.0           7.4       11776
# 17    1045713802    136.0           6.4        4948
# 18     624026776    106.0           6.2        4160
# 19     956019788    144.0           7.1        4760
# 20     752215857    136.0           6.5        6586
# 21     310669540    140.0           6.2        1398
# 22     958400000    161.0           7.6        4524
# 23     372234864    113.0           5.8        1303
# 24     550000000    187.0           6.6        2337
# 25    1845034188    194.0           7.5        7562
# 26    1153304495    147.0           7.1        7241
# 27     303025485    131.0           5.5        2114
# 28    1513528810    124.0           6.5        8662
# 29    1108561013    143.0           6.9        7604
# ...          ...      ...           ...         ...
# 5114           0    108.0           7.2         147
# 5115           0    102.0           6.2         514
# 5116     1783421    108.0           6.4         120
# 5117           0     90.0           6.1         123
# 5118           0     92.0           6.5         361
# 5119           0     95.0           6.5         243
# 5120           0     96.0           6.6         403
# 5121           0     95.0           7.2         193
# 5122     1319566     91.0           4.0         121
# 5123       18957     98.0           7.3         120
# 5124           0    101.0           5.9         106
# 5125           0     94.0           7.7         183
# 5126           0    130.0           7.7         122
# 5127           0     96.0           7.7         240
# 5128           0     90.0           5.5         191
# 5129           0     97.0           5.2         126
# 5130           0    103.0           5.8         200
# 5131           0    105.0           7.1         194
# 5132     7123919     95.0           8.1         155
# 5133           0    118.0           7.5         434
# 5134           0     92.0           6.6         317
# 5135      687505    100.0           6.7         112
# 5136           0     81.0           5.1         164
# 5137           0     94.0           6.3         147
# 5138           0    110.0           6.3         216
# 5139           0    130.0           5.2         152
# 5140           0    120.0           7.6         119
# 5141           0     78.0           6.7         147
# 5142           0      NaN           5.2         131
# 5143           0    105.0           4.5         193
#
# [5144 rows x 10 columns]

# %%
#create a list of unique genres by starting wiht an empty list
unique_genres = []

#then go through each row in the genres column and
for row in merged_df["genres"]:
    #load it into a varable using json.loads
    jdata = json.loads(row)
    #go through each dictionary in in the variable and
    for d in jdata:
        #check to see if the name has been placed into the unique_genres list yet
        if d["name"] not in unique_genres:
            #if not, append it to the list
            unique_genres.append(d['name'])
#Remove spaces from the genres            
unique_genres  = [w.replace(" ", "_") for w in unique_genres]  
#display the list so each genre can be seen
unique_genres
# Out:
# ['Action',
#  'Adventure',
#  'Fantasy',
#  'Science_Fiction',
#  'Crime',
#  'Drama',
#  'Thriller',
#  'Animation',
#  'Family',
#  'Western',
#  'Comedy',
#  'Romance',
#  'Horror',
#  'Mystery',
#  'History',
#  'War',
#  'Music',
#  'Documentary',
#  'Foreign',
#  'TV_Movie']

# %%
#Create a data frame for each genre to compare with each other

#Createan empty list for each genre programmatically
for n in unique_genres:
    globals()[n] = []


#go through each row in the cleaned dataframe and
for index,row in merged_df.iterrows():
    #use json.loads on the genres column at the position of the current index 
    jdata = json.loads(merged_df["genres"][index])
    
    #for each dictionary in the created variable, check which genres appear and append to the proper list
    #DO NOT USE elif, to check if a row belongs in multiple lists use a seperate if statement for each list
    for d in jdata:

        if d["name"] == "Action":
            Action.append(row)
            
        if d["name"] == "Adventure":
            Adventure.append(row) 
        
        if d["name"] == "Fantasy":
            Fantasy.append(row)  
            
        if d["name"] == "Science Fiction":
            Science_Fiction.append(row)  
            
        if d["name"] == "Crime":
            Crime.append(row)  
            
        if d["name"] == "Drama":
            Drama.append(row)  
            
        if d["name"] == "Thriller":
            Thriller.append(row)  
            
        if d["name"] == "Animation":
            Animation.append(row)  
        
        if d["name"] == "Family":
            Family.append(row)  
        
        if d["name"] == "Western":
            Western.append(row)  
            
        if d["name"] == "Comedy":
            Comedy.append(row)  
            
        if d["name"] == "Romance":
            Romance.append(row)  
            
        if d["name"] == "Horror":
            Horror.append(row)  
         
        if d["name"] == "Mystery":
            Mystery.append(row)  
            
        if d["name"] == "History":
            History.append(row)  
            
        if d["name"] == "War":
            War.append(row)  
            
        if d["name"] == "Music":
            Music.append(row)  
            
        if d["name"] == "Documentary":
            Documentary.append(row)  
            
        if d["name"] == "TV Movie":
            TV_Movie.append(row)      
        
#convert them all to dataframes
Action_df = pd.DataFrame(Action)
Adventure_df = pd.DataFrame(Adventure)
Fantasy_df = pd.DataFrame(Fantasy)
Science_Fiction_df = pd.DataFrame(Science_Fiction)
Crime_df = pd.DataFrame(Crime)
Drama_df = pd.DataFrame(Drama)
Thriller_df = pd.DataFrame(Thriller)
Animation_df = pd.DataFrame(Animation)
Family_df = pd.DataFrame(Family)
Western_df = pd.DataFrame(Western)
Comedy_df = pd.DataFrame(Comedy)
Romance_df = pd.DataFrame(Romance)
Horror_df = pd.DataFrame(Horror)
Mystery_df = pd.DataFrame(Mystery)
History_df = pd.DataFrame(History)
War_df = pd.DataFrame(War)
Music_df = pd.DataFrame(Music)
Documentary_df = pd.DataFrame(Documentary)
TV_Movie_df = pd.DataFrame(TV_Movie)


##The code under here works to be used elsewhere
# sums = []
# for index,row in Adventure_df.iterrows():
#     sums.append(Adventure_df["vote_average"][index])
# averages = (sum(sums)/len(sums)).round(2)    
# averages
##The code above works to be used elsewhere

# %%
#create a list to find each unique company
unique_companies = []
unique_companies_to_list=[]

#then go through each row in the production_companies column and
for row in merged_df["production_companies"]:
    
    #if it can't be loaded put in a value to be removed later
    try:
        jdata2 = json.loads(row)
    except:
        jdata2 = [{"name": "Not"}]

    #go through each dictionary in in the variable and
    for d in jdata2:

        #check to see if the name has been placed into the unique_companies list yet
        if d["name"] not in unique_companies:
            #if not, append it to the list        
            unique_companies.append(d['name'])
#             unique_companies_to_list.append(d['name']) 

#remove unwated characters from the names so that the names can be used as variables, store the edited stings in a different list         
unique_companies_to_list  = [w.replace(" ", "_") for w in unique_companies]
unique_companies_to_list  = [w.replace(".", "") for w in unique_companies_to_list]
unique_companies_to_list = [w.replace("-", "_") for w in unique_companies_to_list]
unique_companies_to_list = [w.replace("(MGM)", "MGM") for w in unique_companies_to_list]
#display the list so each company can be seen
unique_companies_to_list
# Out:
# ['Ingenious_Film_Partners',
#  'Twentieth_Century_Fox_Film_Corporation',
#  'Dune_Entertainment',
#  'Lightstorm_Entertainment',
#  'Walt_Disney_Pictures',
#  'Jerry_Bruckheimer_Films',
#  'Second_Mate_Productions',
#  'Columbia_Pictures',
#  'Danjaq',
#  'B24',
#  'Legendary_Pictures',
#  'Warner_Bros',
#  'DC_Entertainment',
#  'Syncopy',
#  'Laura_Ziskin_Productions',
#  'Marvel_Enterprises',
#  'Walt_Disney_Animation_Studios',
#  'Marvel_Studios',
#  'Prime_Focus',
#  'Revolution_Sun_Studios',
#  'Heyday_Films',
#  'DC_Comics',
#  'Atlas_Entertainment',
#  'Cruel_&_Unusual_Films',
#  'RatPac_Dune_Entertainment',
#  'Bad_Hat_Harry_Productions',
#  'Eon_Productions',
#  'Infinitum_Nihil',
#  'Silver_Bullet_Productions_(II)',
#  'Blind_Wink_Productions',
#  'Classic_Media',
#  'Cruel_and_Unusual_Films',
#  'Walt_Disney',
#  'Walden_Media',
#  'Stillking_Films',
#  'Ozumi_Films',
#  'Propeler',
#  'Silverbell_Films',
#  'Paramount_Pictures',
#  'Moving_Picture_Company_(MPC)',
#  'Amblin_Entertainment',
#  'Media_Magik_Entertainment',
#  'Imagenation_Abu_Dhabi_FZ',
#  'Hemisphere_Media_Capital',
#  'Parkes/MacDonald_Productions',
#  'WingNut_Films',
#  'New_Line_Cinema',
#  'Warner_Bros_Pictures',
#  '3Foot7',
#  'Metro_Goldwyn_Mayer_MGM',
#  'Marvel_Entertainment',
#  'Imagine_Entertainment',
#  'Universal_Pictures',
#  'Scott_Free_Productions',
#  'Relativity_Media',
#  'Depth_of_Field',
#  'Scholastic_Productions',
#  'Big_Primate_Pictures',
#  'MFPV_Film',
#  'Studio_Babelsberg',
#  'Walt_Disney_Studios_Motion_Pictures',
#  'Vita_Ray_Dutch_Productions_(III)',
#  'Deluxe_Digital_Studios',
#  'Hasbro',
#  'Bluegrass_Films',
#  'Film_44',
#  'Universal_Studios',
#  'Fuji_Television_Network',
#  'Dentsu',
#  'Team_Todd',
#  'Tim_Burton_Productions',
#  'Roth_Films',
#  'Zanuck_Company,_The',
#  "Donners'_Company",
#  'Major_Studio_Partners',
#  'thinkfilm',
#  'X3_Canada_Productions',
#  'X3US_Productions',
#  'XM3_Service',
#  'Pixar_Animation_Studios',
#  'DreamWorks_SKG',
#  'Di_Bonaventura_Pictures',
#  'Platinum_Dunes',
#  'Hasbro_Studios',
#  'China_Movie_Channel',
#  'Ian_Bryce_Productions',
#  'Avi_Arad_Productions',
#  'Matt_Tolmach_Productions',
#  'LivePlanet',
#  'Prana_Studios',
#  'Sean_Bailey_Productions',
#  'Kontsept_Film_Company',
#  'De_Line_Pictures',
#  'The_Halcyon_Company',
#  'Wonderland_Sound_and_Vision',
#  'Original_Film',
#  'One_Race_Films',
#  'China_Film_Co',
#  'Québec_Production_Services_Tax_Credit',
#  'Media_Rights_Capital_(MRC)',
#  'Abu_Dhabi_Film_Commission',
#  'Colorado_Office_of_Film,_Television_&_Media',
#  'GK_Films',
#  'Skydance_Productions',
#  'Apparatus_Productions',
#  'Latina_Pictures',
#  '2DUX²',
#  'TSG_Entertainment',
#  'Down_Productions',
#  'Bad_Robot',
#  'Kurtzman/Orci',
#  'Big_Kid_Pictures',
#  'Village_Roadshow_Pictures',
#  'Bazmark_Films',
#  'A&E_Television_Networks',
#  'Red_Wagon_Entertainment',
#  'Spectrum_Films',
#  'Disney_Double_Dare_You_(DDY)',
#  'Indochina_Productions',
#  'Lucasfilm',
#  'Perfect_Storm_Entertainment',
#  'Alibaba_Pictures_Group',
#  'Skydance_Media',
#  'Sneaky_Shark',
#  'Huahua_Media',
#  'FortyFour_Studios',
#  'Centropolis_Entertainment',
#  'The_Mark_Gordon_Company',
#  'Farewell_Productions',
#  'ImageMovers',
#  'Anarchos_Productions',
#  'Dark_Horse_Entertainment',
#  'Jerry_Weintraub_Productions',
#  'Beagle_Pug_Films',
#  'Riche_Productions',
#  'Village_Roadshow_Films_North_America',
#  'Kinberg_Genre',
#  'DreamWorks_Animation',
#  'Todman,_Simon,_LeMasters_Productions',
#  'Peters_Entertainment',
#  'Sonnenfeld_Josephson_Worldwide_Entertainment',
#  'China_Film_Co_Production_Corporation',
#  'Alphaville_Films',
#  'Sommers_Company,_The',
#  'Spyglass_Entertainment',
#  'Shady_Acres_Entertainment',
#  'Playtone',
#  'Viz_Media',
#  'Province_of_British_Columbia_Production_Services_Tax_Credit',
#  '3_Arts_Entertainment',
#  'Gordon_Company',
#  'Davis_Entertainment',
#  'Licht/Mueller_Film_Corporation',
#  'Fairview_Entertainment',
#  'Ingenious_Media',
#  'Chernin_Entertainment',
#  'Corsan',
#  'Bliss_Media',
#  'Limelight_International_Media_Entertainment',
#  'Neelmudra_Entertainment',
#  'Aristos_Films',
#  'Singularity_Productions',
#  'Wildkite',
#  'Mid_Atlantic_Films',
#  'Stuber_Productions',
#  'Universal',
#  'H2F_Entertainment',
#  'Babieka',
#  'A113',
#  'Golden_Mean',
#  'Stereo_D',
#  'Vertigo_Entertainment',
#  'Mad_Hatter_Entertainment',
#  'Intermedia_Films',
#  'C_2_Pictures',
#  'IMF_Internationale_Medien_und_Film_GmbH_&_Co_3_Produktions_KG',
#  'Mostow/Lieberman_Productions',
#  'Bulletproof_Cupid',
#  'Lynda_Obst_Productions',
#  'Cine_Bazar',
#  'Toho_Pictures',
#  'Ardustry_Entertainment',
#  'Mediastream_Film_GmbH_&_Co_Productions_KG',
#  'Kennedy/Marshall_Company,_The',
#  'Dune_Entertainment_III',
#  'Big_Screen_Productions',
#  'Lionsgate',
#  'Color_Force',
#  'Saturn_Films',
#  'Broken_Road_Productions',
#  'Junction_Entertainment',
#  'Virtual_Studios',
#  'Next_Entertainment',
#  'Irwin_Allen_Productions',
#  'Radiant_Productions',
#  'Synthesis_Entertainment',
#  'Legend3D',
#  'Blizzard_Entertainment',
#  'Annapurna_Pictures',
#  'Fox_2000_Pictures',
#  'Touchstone_Pictures',
#  'SprocketHeads',
#  'France_3_Cinéma',
#  'Pathé_Renn_Productions',
#  'Egmond_Film_&_Television',
#  'Pacifica_Film',
#  'WR_Universal_Group',
#  'Patalex_IV_Productions_Limited',
#  'Weed_Road_Pictures',
#  'Forward_Pass',
#  'Overbrook_Entertainment',
#  'Blue_Light',
#  'GH_Three',
#  'The_Zanuck_Company',
#  'Plan_B_Entertainment',
#  'Theobald_Film_Productions',
#  'Patalex_III_Productions_Limited',
#  '1492_Pictures',
#  '21_Laps_Entertainment',
#  'Museum_Canada_Productions',
#  'Seed_Productions',
#  'NPV_Entertainment',
#  'Silver_Pictures',
#  'Heineken_Branded_Entertainment',
#  'Kennedy_Miller_Productions',
#  'Panorama_Films',
#  'Skylark_Productions',
#  'Whamaphram_Productions',
#  'Thunder_Road_Pictures',
#  'Cott_Productions',
#  'Furia_de_Titanes_II,_AIE',
#  'Dan_Curtis_Productions',
#  'TC_Productions',
#  'Odin',
#  'Pacific_Data_Images_(PDI)',
#  'Columbus_81_Productions',
#  'Nickelodeon_Movies',
#  'Industrial_Light_&_Magic_(ILM)',
#  'Blinding_Edge_Pictures',
#  'Cruise/Wagner_Productions',
#  'MI_3_Film',
#  'China_Film_Group_Corporation_(CFGC)',
#  'The_Fourth_Production_Company_Film_Group',
#  'Iron_Horse_Entertainment_(II)',
#  'Mythology_Entertainment_(II)',
#  'Aardman_Animations',
#  'Berlanti_Productions',
#  'Classic_Media_Productions',
#  'Bullwinkle_Studios',
#  'Nimar_Studios',
#  'Helena_Productions',
#  'Montecito_Picture_Company,_The',
#  'LStar_Capital',
#  'Feigco_Entertainment',
#  'Pascal_Pictures',
#  'Ghostcorps',
#  'Valhalla_Motion_Pictures',
#  'Columbia_Pictures_Corporation',
#  'Parkes+MacDonald_Image_Nation',
#  'Shangri_La_Entertainment',
#  'Paramount_Animation',
#  'Oriental_DreamWorks',
#  'JC_23_Entertainment',
#  'Radar_Pictures',
#  'Bedford_Falls_Company,_The',
#  'Volcano_Films',
#  'MavroCine_Pictures_GmbH_&_Co_KG',
#  'Summit_Entertainment',
#  'Mystery_Clock_Cinema',
#  'TIK_Films',
#  'Pyramania',
#  'Phoenix_Pictures',
#  'AFG_Talons_Productions',
#  'Lawrence_Gordon_Productions',
#  'Donner/Shuler_Donner_Productions',
#  'Good_Machine',
#  'Saints_LA',
#  'Bristol_Bay_Productions',
#  'Baldwin_Entertainment_Group',
#  'Desertlands_Entertainment',
#  'Mace_Neufeld_Productions',
#  'Kanzaman',
#  'JK_Livin_Productions',
#  'Moguletta',
#  'Sahara_Productions',
#  'Babelsberg_Film',
#  'Square_USA',
#  'Chris_Lee_Productions',
#  'Samuel_Goldwyn_Films',
#  'Miramax',
#  'Sunswept_Entertainment',
#  'Temple_Hill_Entertainment',
#  'Dr_D_Studios',
#  'Kennedy_Miller_Mitchell',
#  'MVL_Incredible_Productions',
#  'Reliance_Entertainment',
#  'Regency_Enterprises',
#  'Appian_Way',
#  'CatchPlay',
#  'Anonymous_Content',
#  'New_Regency_Pictures',
#  'Hong_Kong_Alpha_Motion_Pictures_Co',
#  'RatPac_Entertainment',
#  'M_Productions',
#  'Monarchy_Enterprises_Sarl',
#  'Blind_Wink',
#  'The_Kennedy/Marshall_Company',
#  'Ludlum_Entertainment',
#  'Motion_Picture_BETA_Produktionsgesellschaft',
#  'Bourne_Again',
#  'Don_Simpson/Jerry_Bruckheimer_Films',
#  'DreamWorks',
#  'Wintergreen_Productions',
#  'Protozoa_Pictures',
#  'Disruption_Entertainment',
#  'Heyday_films',
#  'ScreenWest',
#  'Walt_Disney_Feature_Animation',
#  'Government_of_Malta',
#  'Blue_Sky_Studios',
#  'Twentieth_Century_Fox_Animation',
#  'XM2_Productions',
#  'XF2_Canada_Productions',
#  'One_Race_Productions',
#  'Lin_Pictures',
#  'Wigram_Productions',
#  'TriStar_Pictures',
#  'Carolco_Pictures',
#  'Carolco_International_NV',
#  'Captivate_Entertainment',
#  'PolyGram_Filmed_Entertainment',
#  'Lions_Gate_Films',
#  'Mark_Gordon_Productions',
#  "Mel's_Cite_du_Cinema",
#  'Munich_Film_Partners_&_Company_(MFP)_MI2_Productions',
#  'Baltimore_Spring_Creek_Productions',
#  'Constantin_Film_Produktion',
#  'Bernd_Eichinger_Productions',
#  'Haishang_Films',
#  'Michael_De_Luca_Productions',
#  'Crystal_Sky_Pictures',
#  'GH_One',
#  'Vengeance_Productions_Pty_Ltd',
#  'Pearl_Street_Films',
#  'Double_Negative',
#  'Perfect_World_(Beijing)_Pictures_Co',
#  'Tall_Trees_Productions',
#  'Flower_Films_(II)',
#  'Brandywine_Productions',
#  'Sony_Pictures_Entertainment',
#  'Media_Rights_Capital',
#  'Sony_Pictures_Entertainment_(SPE)',
#  'QED_International',
#  'Alpha_Core',
#  'Genre_Films',
#  'Simon_Kinberg_Productions',
#  'Strike_Entertainment',
#  'Velocity_Productions',
#  'Gracie_Films',
#  'Road_Rebel',
#  'Tree_Line_Films',
#  'Pink_Machine',
#  'Monolith_Pictures_(III)',
#  'Radical_Studios',
#  'Constantin_Film',
#  'TF1_Films_Productions',
#  'La_Petite_Reine',
#  'Tri_Pictures',
#  'Sorolla_Films',
#  'Novo_RPI',
#  'Canal+',
#  'uFilm',
#  'Canal+_España',
#  'Le_Tax_Shelter_du_Gouvernement_Fédéral_de_Belgique',
#  'Les_Editions_Albert_René',
#  'Lion_Rock_Productions',
#  'Perfect_World_Pictures',
#  'Esperanto_Filmoj',
#  'Pacific_Western',
#  '5150_Action',
#  'Gama_Entertainment_Partners',
#  'Marv_Films',
#  'Constantin_Film',
#  'Flynn_Picture_Company',
#  'Mutual_Film_Company',
#  'Global_Entertainment_Productions_GmbH_&_Company_Medien_KG',
#  'Section_Eight',
#  'WV_Films_III',
#  'Epsilon_Motion_Pictures',
#  'Mandeville_Films',
#  'NeoReel',
#  'Miramax_Films',
#  'Cappa_Productions',
#  'Initial_Entertainment_Group_(IEG)',
#  'Reliance_BIG_Entertainment',
#  'Hollywood_Gang_Productions',
#  'Atmosphere_Entertainment_MM',
#  'Sony_Pictures_Animation',
#  'Kerner_Entertainment_Company',
#  'Angry_Films',
#  'Wardour_Street_Pictures',
#  'Blue_Tulip_Productions',
#  'Chartoff_Productions',
#  'Odd_Lot_Entertainment',
#  'K/O_Paper_Products',
#  'Digital_Domain',
#  'Taleswapper',
#  'Cheyenne_Enterprises',
#  'The_Saul_Zaentz_Company',
#  '80_Days_Productions',
#  'Spanknyce_Films',
#  'Fitzwilliam_Productions',
#  'Laurence_Mark_Productions',
#  'Mediastream_Vierte_Film_GmbH_&_Co_Vermarktungs_KG',
#  'Canlaws_Productions',
#  'Dune_Films',
#  'BK',
#  'KOH',
#  'Reino_del_Cielo',
#  'Inside_Track_3',
#  'Calle_Cruzada',
#  'Global_Medien_KG',
#  'Franklin/Waterman_Productions',
#  'International_Traders',
#  'Mill_Film',
#  'C_&_L',
#  'Dawliz',
#  'Ronald_Shusett/Gary_Goldman',
#  'Digital_Image_Associates',
#  'T2_Productions',
#  'Tribeca_Productions',
#  'Misher_Films',
#  'Film_Rites',
#  'Escape_Artists',
#  'Everyman_Pictures',
#  'Dreamworks_Pictures',
#  'Gary_Sanchez_Productions',
#  'Kopelson_Entertainment',
#  'The_Weinstein_Company',
#  'Nu_Image_Films',
#  'Millennium_Films',
#  'Wild_Things_Productions',
#  'Peninsula_Films',
#  'StudioCanal',
#  'Sony_Pictures_Releasing',
#  'Sony_Pictures_Worldwide_Acquisitions_(SPWA)',
#  'Italian_Tax_Credit',
#  'Birnbaum/Barber',
#  'Cineroma_SRL',
#  'French_Tax_Credit',
#  'Beacon_Communications',
#  'Bedford_Falls_Productions',
#  'Lonely_Film_Productions_GmbH_&_Co_KG',
#  'Spring_Creek_Productions',
#  'Liberty_Pictures',
#  'EMJAG_Productions',
#  'Red_Granite_Pictures',
#  'Sikelia_Productions',
#  'Polygram_Filmed_Entertainment',
#  'Big_Bug_Pictures',
#  'X_Filme_Creative_Pool',
#  'Ascension_Pictures',
#  'ARD_Degeto_Film',
#  'Cloud_Atlas_Productions',
#  'Five_Drops',
#  'Media_Asia_Group',
#  'Dreams_of_Dragon_Picture',
#  'Animal_Logic',
#  'DiNovi_Pictures',
#  'Frantic_Films',
#  'Maple_Shade_Films',
#  'Catwoman_Films',
#  'Mosaic_Media_Group',
#  'Sid_&_Marty_Krofft_Pictures',
#  'Davis_Films',
#  'LionsGate',
#  'Ex3_Productions',
#  'Fipex_Holding',
#  'Alcon_Entertainment',
#  'DMG_Entertainment',
#  'Ehman_Productions',
#  'Pathé_Distribution',
#  'K_JAM_Media',
#  'Surf_Film',
#  'Enelmar_Productions,_AIE',
#  'Castle_Rock_Entertainment',
#  'Working_Title_Films',
#  'Jean_Doumanian_Productions',
#  'Sweetland_Films',
#  'Magnolia_Films',
#  'Jasmine_Productions_Inc',
#  'Imhotep_Productions',
#  'Alberto_Grimaldi_Productions',
#  'Beijing_New_Picture_Film_Co_Ltd',
#  'EDKO_Film',
#  'New_Picture_Company',
#  'DreamWorks_Pictures',
#  'Revolution_Studios',
#  'Location_Gourmet',
#  'Gaumont',
#  'Home_Box_Office_(HBO)',
#  'HBO_Films',
#  'Allison_Shearmur_Productions',
#  'Key_Creatives',
#  'Film4',
#  'Goldcrest_Pictures',
#  'New_Zealand_Large_Budget_Screen_Production_Grant',
#  'Outlaw_Sinema',
#  'Pendle_Mountain_Productions',
#  'Toho_Towa',
#  'British_Broadcasting_Corporation_(BBC)',
#  'Marubeni',
#  'Eidos_Interactive',
#  'Straight_Up_Films',
#  'Giant_Pictures',
#  'Origo_Film_Group',
#  'Le_Studio_Canal+',
#  'TCF_Vancouver_Productions',
#  'Firm_Films',
#  'Prospect_Park',
#  'Millbrook_Farm_Productions',
#  'Red_Hour_Films',
#  'Media_Asia_Films',
#  'Internationale_Filmproduktion_Stella_del_Sud_Second',
#  'Scott_Rudin_Productions',
#  'Yellow_Bird',
#  'Ground_Control',
#  'Cinergi_Pictures_Entertainment',
#  'Internationale_Filmproduktion_Blackbird_Dritte',
#  'Sean_Daniel_Company',
#  'LightWorkers_Media',
#  'Bagdasarian_Productions',
#  'United_Artists',
#  'Achte_Babelsberg_Film',
#  'Happy_Madison_Productions',
#  'Stanley_Kubrick_Productions',
#  'Gunn_Films',
#  'Doom_Buggy_Productions',
#  'South_Side_Amusement_Company',
#  'Mirage_Enterprises',
#  'Motion_Picture_JOTA_Produktions',
#  'October_Pictures',
#  'Rysher_Entertainment',
#  'Metropolitan_Filmexport',
#  'Red_Wagon_Productions',
#  'Kalima_Productions_GmbH_&_Co_KG',
#  'The_Jacobson_Company',
#  'Red_Horizon_Productions',
#  'National_Geographic_Society',
#  'Palomar_Pictures_(II)',
#  'First_Light_Production',
#  'Dino_De_Laurentiis_Company',
#  'Parkway_Pictures_(I)',
#  'Vnesheconombank',
#  'Nutcracker_Holdings',
#  'HCC_Media_Group',
#  'Russian_Roulette_Ltd',
#  'Constant_c_Productions',
#  'Hypnotic',
#  'Motion_Picture_THETA_Produktionsgesellschaft',
#  'WV_Films_II',
#  'Impact_Pictures',
#  'Nouvelles_Éditions_de_Films_(NEF)',
#  'New_Legacy',
#  'Josephson_Entertainment',
#  'Andalasia_Productions',
#  'Right_Coast_Productions',
#  'Cruella_Productions',
#  'Image_Entertainment',
#  'Rat_Entertainment',
#  'Waverly_Films',
#  'No_Such_Productions',
#  'Swanford_Films',
#  'Mandalay_Pictures',
#  'Little_Bird',
#  'KC_Medien',
#  'Reperage',
#  'DOS',
#  'MP_Film_Management',
#  'WWE_Studios',
#  'IM3_Entertainment',
#  'Oak_Productions',
#  'City_Light_Films',
#  'David_Foster_Productions',
#  'Bel_Air_Entertainment',
#  'Hacienda_Productions',
#  'Yucaipa_Films',
#  'Goldmann_Pictures',
#  'Misha_Films',
#  'Marc_Platt_Productions',
#  'Horsepower_Films',
#  'Core_Productions',
#  'Munich_Film_Partners_New_Century_&_Company_(MFP)_Core_Productions',
#  'DNA_Films',
#  'IM_Global',
#  'Rena_Film',
#  'Peach_Trees',
#  'Creepshow_Films_Inc',
#  'Laurel_Entertainment_Inc',
#  'Internationale_Filmproduktion_Eagle',
#  'Pit_Bull_Productions',
#  'Living_Films',
#  'Green_Hat_Films',
#  'Zanuck/Brown_Productions',
#  'Manhattan_Project',
#  'MTV_Films',
#  'Callahan_Filmworks',
#  'Mad_Chance',
#  'WV_Films_IV',
#  'Type_A_Films',
#  'Ott_Medien',
#  'Wild_West_Picture_Show_Productions',
#  'Permut_Presentations',
#  'WCG_Entertainment_Productions',
#  'Douglas/Reuther_Productions',
#  'Krane_Entertainment',
#  'Kouf/Bigelow_Productions',
#  'Hiett_Designs_of_Las_Vegas',
#  'Runway_Pictures_Inc',
#  'KMP_Film_Invest',
#  'Castel_Film_Romania',
#  'Bona_Fide_Productions',
#  'Cattleya',
#  'Great_Oaks_Entertainment',
#  'Roth_Arnold_Productions',
#  'Warner_Bros_Family_Entertainment',
#  'Northern_Lights_Entertainment',
#  'Courtside_Seats_Productions',
#  'International_Production_Company',
#  'The_Montecito_Picture_Company',
#  'Robert_Simonds_Productions',
#  'Earth_Canada_Productions',
#  'Hammerhead_Productions',
#  'Crave_Films',
#  'Huayi_Brothers_Media',
#  'Le_Grisbi_Productions',
#  'Caravan_Pictures',
#  'Roger_Birnbaum_Productions',
#  'Warner_Bros_Animation',
#  'Rhythm_and_Hues',
#  'Picnic_Basket',
#  'Zookeeper_Productions',
#  'Hey_Eddie',
#  'Prelude_Pictures',
#  'Saltire_Entertainment',
#  'Clinica_Estetico',
#  'Rainbow_Film_Company,_The',
#  'Revere_Entertainment',
#  'Jagtoria_Films',
#  'RKO_Pictures',
#  'Jonathan_Krane_Group',
#  'Avery_Pix',
#  'Reforma_Films',
#  'Dimension_Films',
#  'Ex_Nihilo',
#  'Les_films_du_Worso',
#  'Noodles_Production',
#  'Ciné+',
#  'Scope_Pictures',
#  'Centre_National_de_la_Cinématographie_(CNC)',
#  'Ministère_de_la_Culture_et_de_la_Communication',
#  'Left_Field_Ventures',
#  'Evo_Films_AIE',
#  'Indéfilms_3',
#  'Palatine_Étoile_12',
#  'Cinéfeel_Prod',
#  'Art_Linson_Productions',
#  'Top_Shelf_Productions',
#  'Tig_Productions',
#  'BBC_Worldwide',
#  'BBC_Earth',
#  'Evergreen_Films',
#  'BBC_Earth_MD_(WWD)',
#  'Evergreen_MD',
#  'Franchise_Pictures',
#  'JTP_Films',
#  'Morgan_Creek_Productions',
#  'Battlefield_Productions',
#  'Warner_Bros_Feature_Animation',
#  'Cobalt_Media_Group',
#  'Artists_Production_Group_(APG)',
#  'Aperture_Entertainment',
#  'The_Canton_Company',
#  'Mars_Production_Pty_Ltd',
#  'Canal_Plus',
#  'Sofica_Europacorp',
#  'Avalanche_Productions',
#  'EuropaCorp',
#  'Pathé_Films',
#  'TPS_Star',
#  'Participant_Media',
#  'France_Télévision',
#  'France_2_Cinéma',
#  'France_3_Cinema',
#  'Conseil_Régional_du_Calvados',
#  'Région_Bretagne',
#  'Ministère_du_Développement_Durable_et_de_la_Mer',
#  'JMH_TSR',
#  'HH_Sheikha_Salama_bint_Hamdan_Al_Nahyan',
#  "Conseil_Général_des_Côtes_d'Armor",
#  'Conseil_Général_du_Morbihan',
#  'Région_Basse_Normandie',
#  'Dante_Entertainment',
#  'Crusader_Entertainment',
#  'ETIC_Films',
#  'Forge',
#  'QI_Quality_International_GmbH_Co_KG',
#  'Signature_Pictures',
#  'ApolloMedia_Distribution',
#  'Coco',
#  'Film_111',
#  'Jericho_Productions_Ltd',
#  'MFF_(Sound_of_Thunder)',
#  'Matrix_Film_Finance',
#  'Scenario_Lane_Productions',
#  'Don_Carmody_Productions',
#  'FilmDistrict',
#  'Constantin_Film_International',
#  'Anima_Estudios',
#  'Discreet_Art_Productions',
#  'Contrafilm',
#  'Sony',
#  'Casey_Silver_Productions',
#  'Mikona_Productions_GmbH_&_Co_KG',
#  'Onyx_Films',
#  'NetFlix',
#  'Orange_Studios',
#  'CityMation',
#  'On_Entertainment',
#  'Zippcast_Films',
#  'Capella_International',
#  'KC_Medien_AG',
#  'Illumination_Entertainment',
#  'JD_Productions',
#  'Mediastream_Dritte_Film_GmbH_&_Co_Beteiligungs_KG',
#  'Hit_&_Run_Productions',
#  'Springwood_Productions',
#  'Genetics_Productions',
#  'Bazelevs_Production',
#  'Kickstart_Productions',
#  'Top_Cow_Productions',
#  'Ringerike_Zweite_Filmproduktion',
#  'Hollywood_Pictures',
#  'Offspring_Entertainment',
#  'Zadan_/_Meron_Productions',
#  'Dominion_Productions',
#  'DiC_Entertainment',
#  'SOIXAN7E_QUIN5E',
#  'See_Me_Louisiana',
#  'Participant_Productions',
#  'Playtone_Production',
#  'Double_Feature_Films',
#  'Jersey_Films',
#  'Nina_Saxon_Film_Design',
#  'Alliance_Atlantis_Communications',
#  'Barry_Mendel_Productions',
#  'Michael_Lobell_Productions',
#  'Katalyst_Films',
#  'Aversano_Films',
#  'Empire_Pictures',
#  'Hyde_Park_Entertainment',
#  'Lotus_Pictures',
#  'First_Knight_Productions',
#  'Virgin_Produced',
#  'Mark_Canton_Productions',
#  'Yari_Film_Group',
#  'Stratus_Film_Co',
#  'Syndicate_Films_International',
#  'Equity_Pictures_Medienfonds_GmbH_&_Co_KG_II',
#  'Hostage_GmbH',
#  'David_Kirschner_Productions',
#  'Fox_Animation_Studios',
#  'Paramount_Vantage',
#  'Likely_Story',
#  'Ivy_Boy_Productions',
#  'This_Is_That_Productions',
#  'Twitching_Image_Studio',
#  'Aldrich_Group',
#  'Optional_Pictures',
#  'Limited_Edition_Productions_Inc',
#  'Lennox_House_Films',
#  'DeBart',
#  'Punch_Productions',
#  'Baltimore_Pictures',
#  'Rovio_Entertainment',
#  'Sony_Pictures_Imageworks_(SPI)',
#  'Rovio_Mobile',
#  'Rovio_Animation',
#  'Apatow_Productions',
#  'Madison_23',
#  'FilmWorks',
#  'MDBF_Zweite_Filmgesellschaft',
#  'Joseph_M_Singer_Entertainment',
#  'Icon_Entertainment_International',
#  'The_Ladd_Company',
#  'BH_Finance_CV',
#  'Neal_Street_Productions',
#  'Motion_Picture_KAPPA_Produktionsgesellschaft',
#  'Darkwoods_Productions',
#  'Trackform_Film_Productions',
#  'TF1_Films_Production',
#  'Pathe',
#  'Two_Brothers_Productions',
#  'Lakeshore_Entertainment',
#  'Interscope_Communications',
#  'Nickelodeon_Animation_Studios',
#  'United_Plankton_Pictures',
#  'Brian_Grazer/Scott_Rudin_Productions',
#  'A_Band_Apart',
#  'Zehnte_Babelsberg',
#  'Visiona_Romantica',
#  'Camelot_Pictures',
#  'Illusion_Entertainment',
#  'Cruise_Wagner_Productions',
#  'Vinyl_Films',
#  'Lonlink_Productions',
#  'Kut_Productions',
#  'Inside_Track_Films',
#  'Charenton_Productions_Limited',
#  'Wheelhouse_Entertainment',
#  'Motion_Picture_Production_GmbH_&_Co_Erste_KG',
#  'Jinks/Cohen_Company',
#  'Smokehouse_Pictures',
#  'Obelisk_Productions',
#  'Edward_R_Pressman_Film',
#  'Vaughn_Productions',
#  'Mandalay_Entertainment',
#  'Applecross',
#  'Reperage_&_Vanguard_Films',
#  'John_Wells_Productions',
#  'Reaper_Productions',
#  'Doom_Productions',
#  'Distant_Planet_Productions',
#  'Screen_Gems',
#  'Sketch_Films',
#  'UW4_Productions',
#  'Corner_Store_Entertainment',
#  'Material_Pictures',
#  'David_Ladd_Films',
#  'Current_Entertainment',
#  'Omnilab_Media',
#  'Ambience_Entertainment',
#  'Open_Road_Films',
#  'Sighvatsson_Films',
#  'Film_Victoria',
#  'Wales_Creative_IP_Fund',
#  'Yorktown_Productions',
#  'Helkon_Media_AG',
#  'SuperMega',
#  'MHF_Erste_Academy_Film_GmbH_&_Co_Produktions_KG',
#  'Tele_München_Fernseh_Produktionsgesellschaft_(TMG)',
#  'UGC_PH',
#  'British_Broadcasting_Corporation_(BBC)_Television',
#  'Stargate_Studios',
#  'Conundrum_Entertainment',
#  'Prana_Animation_Studios',
#  'Summertime_Entertainment',
#  'Natural_Nylon_Entertainment',
#  'Riff_Raff_Film_Productions',
#  'Filmauro',
#  'Blue_Flower_Productions',
#  'Brooklyn_Films_II',
#  'Emmett/Furla_Films',
#  'Envision_Entertainment',
#  'Boies_/_Schiller_Film_Group',
#  'Knightsbridge_Entertainment',
#  'MFP_Munich_Film_Partners_GmbH_&_Company_I_Produktions_KG',
#  'SOAF_Productions',
#  'Maverick_Films',
#  'Imprint_Entertainment',
#  'Horseshoe_Bay_Productions',
#  'Fuzzy_Door_Productions',
#  'Smart_Entertainment',
#  'Himenóptero',
#  'Telecinco_Cinema',
#  'Mod_Producciones',
#  'Instituto_de_la_Cinematografía_y_de_las_Artes_Audiovisuales_(ICAA)',
#  'Golar_Productions',
#  'Kaitz_Productions',
#  'Mann/Roth_Productions',
#  'Whitaker_Entertainment',
#  'Bergsten_Music',
#  'Red_Hawk_Entertainment',
#  'Abraham_Productions',
#  'Fountainbridge_Films',
#  'Ten_Thirteen_Productions',
#  'Quinta_Communications',
#  'Zephyr_Films',
#  'Bandito_Brothers',
#  'Electronic_Arts',
#  'Wind_Dancer_Productions',
#  'Kasdan_Pictures',
#  'Groucho_II_Film_Partnership',
#  'Outlaw_Productions',
#  'Boxing_Cat_Films',
#  'CAMERON_MACKINTOSH',
#  'Jolie_Pas',
#  'Malpaso_Productions',
#  'Clipsal_Films',
#  'RCS_Video',
#  'Cliffhanger_Productions',
#  'Pioneer',
#  'Kernos_Filmproduktionsgesellschaft_&_Company',
#  'Hobby_Films',
#  'Pole_Star',
#  'Olive_Bridge_Entertainment',
#  'Marcy_Media',
#  'Kramer_&_Sigman_Films',
#  'Zaftig_Films',
#  'Overbrook_Films',
#  'Amen_Ra_Films',
#  'Shawn_Danielle_Productions_Ltd',
#  'Imaginary_Forces',
#  'Peter_Frankfurt_Productions',
#  'Valkyrie_Films',
#  'Scion_Films',
#  'H2S2_Filmproduktionsgesellschaft',
#  'The_Steve_Tisch_Company',
#  'Teitler_Film',
#  'Taurus_Film',
#  'Linson_Films',
#  'Atman_Entertainment',
#  'Knickerbocker_Films',
#  'Sidney_Kimmel_Entertainment',
#  'Hopscotch_Films',
#  'RP_Productions',
#  'Runteam_III_Ltd',
#  'Elektra_Productions',
#  'SAI_Productions',
#  'Troublemaker_Studios',
#  'AR_Films',
#  'Aldamisa_Entertainment',
#  'Demarest_Films',
#  'Solipsist_Film',
#  'Residaco',
#  'Cross_Creek_Pictures',
#  'Free_State_Pictures',
#  'RVK_Studios',
#  'Rising_Star',
#  'VIP_Medienfonds_4',
#  'Ikiru_Films',
#  'Castelao_Producciones',
#  "Eric's_Boy",
#  'Moving_Pictures',
#  'Gratitude_International',
#  'Tezuka_Production_Company_Ltd',
#  'Imagi_Animation_Studios',
#  'Paragon_Entertainment_Corp',
#  'Shanghai_Film_Group',
#  'Jackie_&_JJ_Production',
#  'Sparkle_Roll_Media',
#  'Home_Media_&_Entertainment_Fund',
#  'Tencent_Video',
#  'China_Film_&_TV_Capital',
#  'Visualizer_Film_Company',
#  'Wayans_Bros_Entertainment',
#  'Internationale_Filmproduktion',
#  'FilmColony',
#  'Wild_Hogs_Productions',
#  'Pacific_Standard',
#  'Artemple___Hollywood',
#  'Neufeld_Rehme_Productions',
#  'Envision_Entertainment_Corporation',
#  'Zide_Perry_Productions',
#  'BenderSpink',
#  'Fortis_Films',
#  'Dozen_Canada_Productions',
#  'Gotham_Group',
#  'Red_Om_Films',
#  'Ixtlan',
#  'Wildwood_Enterprises',
#  'Edge_City',
#  'World_Wrestling_Entertainment_(WWE)',
#  'Beacon_Pictures',
#  'Fantail_Films_Inc',
#  'Riche_Ludwig_Productions',
#  'Groucho_III_Film_Partnership',
#  'Focus_Features',
#  'Laika_Entertainment',
#  'UTV_Motion_Pictures',
#  'AR_TL',
#  'Starlite_Films',
#  'Province_of_British_Columbia_Film_Incentive_BC',
#  'Solomon/Hackett_Productions',
#  'Larger_Than_Life_Productions',
#  'Blue_Train_Productions',
#  'Seagal/Nasso_Productions',
#  'Victor_Company_of_Japan_(JVC)',
#  'Cutting_Edge_Films',
#  'Etalon_film',
#  'Buckaroo_Entertainment',
#  'LHF_Film',
#  'Gerard_Butler_Alan_Siegel_Entertainment',
#  'Nu_Boyana_Film_Studios',
#  'Grosvenor_Park_Impact_Productions',
#  'LEGO',
#  'Warner_Animation_Group',
#  'World_2000_Entertainment',
#  'Tripod_Entertainment',
#  'Langley_Park_Production',
#  ...]

# %%
#create a list to use to count how many times a company appears
comp_counter = []
#for each company in the unique_companies list, set a value of 0
for comp in range(len(unique_companies)):
    comp_counter.append(0)

#go through each row in the merged_df to count the occurance of each company by
for row in merged_df["production_companies"]:
    #load it into a varable using json.loads
    #if it can't be loaded put in a value to be removed later
    try:
        jdata2 = json.loads(row)
    except:
        jdata2 = [{"name": "Not"}]

    #go through each dictionary in in the variable and
    for d in jdata2:
        #also go through each element in unique_companies
        for compa in range(len(unique_companies)):
            #check when the names match and
            if d['name'] == unique_companies[compa]:
                #increment the counter at the location corresponding to the matching names
                comp_counter[compa] +=1

# %%
#create a zipped object with the unique_companies_to_list and the comp_counter
zipped_look = zip(unique_companies_to_list, comp_counter)
#store it in a variable
companies_dict = dict(zipped_look)

# %%
#display the variable to check if there is an obvious error
companies_dict
# Out:
# {'Ingenious_Film_Partners': 29,
#  'Twentieth_Century_Fox_Film_Corporation': 222,
#  'Dune_Entertainment': 59,
#  'Lightstorm_Entertainment': 5,
#  'Walt_Disney_Pictures': 118,
#  'Jerry_Bruckheimer_Films': 21,
#  'Second_Mate_Productions': 2,
#  'Columbia_Pictures': 203,
#  'Danjaq': 8,
#  'B24': 1,
#  'Legendary_Pictures': 34,
#  'Warner_Bros': 319,
#  'DC_Entertainment': 15,
#  'Syncopy': 8,
#  'Laura_Ziskin_Productions': 5,
#  'Marvel_Enterprises': 16,
#  'Walt_Disney_Animation_Studios': 8,
#  'Marvel_Studios': 15,
#  'Prime_Focus': 1,
#  'Revolution_Sun_Studios': 16,
#  'Heyday_Films': 10,
#  'DC_Comics': 17,
#  'Atlas_Entertainment': 13,
#  'Cruel_&_Unusual_Films': 1,
#  'RatPac_Dune_Entertainment': 13,
#  'Bad_Hat_Harry_Productions': 12,
#  'Eon_Productions': 22,
#  'Infinitum_Nihil': 4,
#  'Silver_Bullet_Productions_(II)': 1,
#  'Blind_Wink_Productions': 1,
#  'Classic_Media': 1,
#  'Cruel_and_Unusual_Films': 7,
#  'Walt_Disney': 7,
#  'Walden_Media': 19,
#  'Stillking_Films': 9,
#  'Ozumi_Films': 1,
#  'Propeler': 1,
#  'Silverbell_Films': 1,
#  'Paramount_Pictures': 285,
#  'Moving_Picture_Company_(MPC)': 12,
#  'Amblin_Entertainment': 49,
#  'Media_Magik_Entertainment': 2,
#  'Imagenation_Abu_Dhabi_FZ': 13,
#  'Hemisphere_Media_Capital': 4,
#  'Parkes/MacDonald_Productions': 7,
#  'WingNut_Films': 11,
#  'New_Line_Cinema': 167,
#  'Warner_Bros_Pictures': 10,
#  '3Foot7': 1,
#  'Metro_Goldwyn_Mayer_MGM': 122,
#  'Marvel_Entertainment': 8,
#  'Imagine_Entertainment': 36,
#  'Universal_Pictures': 312,
#  'Scott_Free_Productions': 29,
#  'Relativity_Media': 102,
#  'Depth_of_Field': 6,
#  'Scholastic_Productions': 1,
#  'Big_Primate_Pictures': 1,
#  'MFPV_Film': 2,
#  'Studio_Babelsberg': 26,
#  'Walt_Disney_Studios_Motion_Pictures': 6,
#  'Vita_Ray_Dutch_Productions_(III)': 1,
#  'Deluxe_Digital_Studios': 1,
#  'Hasbro': 3,
#  'Bluegrass_Films': 7,
#  'Film_44': 2,
#  'Universal_Studios': 7,
#  'Fuji_Television_Network': 6,
#  'Dentsu': 12,
#  'Team_Todd': 8,
#  'Tim_Burton_Productions': 12,
#  'Roth_Films': 9,
#  'Zanuck_Company,_The': 4,
#  "Donners'_Company": 14,
#  'Major_Studio_Partners': 5,
#  'thinkfilm': 2,
#  'X3_Canada_Productions': 1,
#  'X3US_Productions': 1,
#  'XM3_Service': 1,
#  'Pixar_Animation_Studios': 16,
#  'DreamWorks_SKG': 79,
#  'Di_Bonaventura_Pictures': 19,
#  'Platinum_Dunes': 13,
#  'Hasbro_Studios': 5,
#  'China_Movie_Channel': 2,
#  'Ian_Bryce_Productions': 1,
#  'Avi_Arad_Productions': 1,
#  'Matt_Tolmach_Productions': 1,
#  'LivePlanet': 5,
#  'Prana_Studios': 1,
#  'Sean_Bailey_Productions': 1,
#  'Kontsept_Film_Company': 4,
#  'De_Line_Pictures': 11,
#  'The_Halcyon_Company': 1,
#  'Wonderland_Sound_and_Vision': 7,
#  'Original_Film': 30,
#  'One_Race_Films': 3,
#  'China_Film_Co': 3,
#  'Québec_Production_Services_Tax_Credit': 1,
#  'Media_Rights_Capital_(MRC)': 2,
#  'Abu_Dhabi_Film_Commission': 1,
#  'Colorado_Office_of_Film,_Television_&_Media': 1,
#  'GK_Films': 10,
#  'Skydance_Productions': 10,
#  'Apparatus_Productions': 2,
#  'Latina_Pictures': 3,
#  '2DUX²': 1,
#  'TSG_Entertainment': 29,
#  'Down_Productions': 3,
#  'Bad_Robot': 10,
#  'Kurtzman/Orci': 2,
#  'Big_Kid_Pictures': 3,
#  'Village_Roadshow_Pictures': 82,
#  'Bazmark_Films': 4,
#  'A&E_Television_Networks': 1,
#  'Red_Wagon_Entertainment': 7,
#  'Spectrum_Films': 1,
#  'Disney_Double_Dare_You_(DDY)': 1,
#  'Indochina_Productions': 2,
#  'Lucasfilm': 16,
#  'Perfect_Storm_Entertainment': 1,
#  'Alibaba_Pictures_Group': 3,
#  'Skydance_Media': 2,
#  'Sneaky_Shark': 1,
#  'Huahua_Media': 1,
#  'FortyFour_Studios': 1,
#  'Centropolis_Entertainment': 10,
#  'The_Mark_Gordon_Company': 7,
#  'Farewell_Productions': 1,
#  'ImageMovers': 9,
#  'Anarchos_Productions': 5,
#  'Dark_Horse_Entertainment': 9,
#  'Jerry_Weintraub_Productions': 8,
#  'Beagle_Pug_Films': 2,
#  'Riche_Productions': 1,
#  'Village_Roadshow_Films_North_America': 1,
#  'Kinberg_Genre': 2,
#  'DreamWorks_Animation': 32,
#  'Todman,_Simon,_LeMasters_Productions': 1,
#  'Peters_Entertainment': 2,
#  'Sonnenfeld_Josephson_Worldwide_Entertainment': 1,
#  'China_Film_Co_Production_Corporation': 7,
#  'Alphaville_Films': 9,
#  'Sommers_Company,_The': 1,
#  'Spyglass_Entertainment': 38,
#  'Shady_Acres_Entertainment': 3,
#  'Playtone': 9,
#  'Viz_Media': 1,
#  'Province_of_British_Columbia_Production_Services_Tax_Credit': 6,
#  '3_Arts_Entertainment': 12,
#  'Gordon_Company': 3,
#  'Davis_Entertainment': 35,
#  'Licht/Mueller_Film_Corporation': 2,
#  'Fairview_Entertainment': 1,
#  'Ingenious_Media': 14,
#  'Chernin_Entertainment': 10,
#  'Corsan': 2,
#  'Bliss_Media': 1,
#  'Limelight_International_Media_Entertainment': 1,
#  'Neelmudra_Entertainment': 1,
#  'Aristos_Films': 1,
#  'Singularity_Productions': 1,
#  'Wildkite': 1,
#  'Mid_Atlantic_Films': 6,
#  'Stuber_Productions': 8,
#  'Universal': 4,
#  'H2F_Entertainment': 2,
#  'Babieka': 2,
#  'A113': 1,
#  'Golden_Mean': 2,
#  'Stereo_D': 1,
#  'Vertigo_Entertainment': 17,
#  'Mad_Hatter_Entertainment': 2,
#  'Intermedia_Films': 22,
#  'C_2_Pictures': 2,
#  'IMF_Internationale_Medien_und_Film_GmbH_&_Co_3_Produktions_KG': 5,
#  'Mostow/Lieberman_Productions': 2,
#  'Bulletproof_Cupid': 1,
#  'Lynda_Obst_Productions': 4,
#  'Cine_Bazar': 1,
#  'Toho_Pictures': 1,
#  'Ardustry_Entertainment': 2,
#  'Mediastream_Film_GmbH_&_Co_Productions_KG': 1,
#  'Kennedy/Marshall_Company,_The': 12,
#  'Dune_Entertainment_III': 26,
#  'Big_Screen_Productions': 13,
#  'Lionsgate': 58,
#  'Color_Force': 8,
#  'Saturn_Films': 12,
#  'Broken_Road_Productions': 5,
#  'Junction_Entertainment': 2,
#  'Virtual_Studios': 7,
#  'Next_Entertainment': 4,
#  'Irwin_Allen_Productions': 2,
#  'Radiant_Productions': 5,
#  'Synthesis_Entertainment': 1,
#  'Legend3D': 1,
#  'Blizzard_Entertainment': 1,
#  'Annapurna_Pictures': 9,
#  'Fox_2000_Pictures': 55,
#  'Touchstone_Pictures': 118,
#  'SprocketHeads': 1,
#  'France_3_Cinéma': 7,
#  'Pathé_Renn_Productions': 9,
#  'Egmond_Film_&_Television': 2,
#  'Pacifica_Film': 1,
#  'WR_Universal_Group': 1,
#  'Patalex_IV_Productions_Limited': 1,
#  'Weed_Road_Pictures': 8,
#  'Forward_Pass': 6,
#  'Overbrook_Entertainment': 10,
#  'Blue_Light': 1,
#  'GH_Three': 1,
#  'The_Zanuck_Company': 7,
#  'Plan_B_Entertainment': 15,
#  'Theobald_Film_Productions': 1,
#  'Patalex_III_Productions_Limited': 1,
#  '1492_Pictures': 17,
#  '21_Laps_Entertainment': 12,
#  'Museum_Canada_Productions': 1,
#  'Seed_Productions': 1,
#  'NPV_Entertainment': 25,
#  'Silver_Pictures': 33,
#  'Heineken_Branded_Entertainment': 1,
#  'Kennedy_Miller_Productions': 7,
#  'Panorama_Films': 1,
#  'Skylark_Productions': 2,
#  'Whamaphram_Productions': 1,
#  'Thunder_Road_Pictures': 9,
#  'Cott_Productions': 2,
#  'Furia_de_Titanes_II,_AIE': 1,
#  'Dan_Curtis_Productions': 1,
#  'TC_Productions': 3,
#  'Odin': 1,
#  'Pacific_Data_Images_(PDI)': 8,
#  'Columbus_81_Productions': 1,
#  'Nickelodeon_Movies': 22,
#  'Industrial_Light_&_Magic_(ILM)': 1,
#  'Blinding_Edge_Pictures': 8,
#  'Cruise/Wagner_Productions': 14,
#  'MI_3_Film': 1,
#  'China_Film_Group_Corporation_(CFGC)': 3,
#  'The_Fourth_Production_Company_Film_Group': 1,
#  'Iron_Horse_Entertainment_(II)': 3,
#  'Mythology_Entertainment_(II)': 1,
#  'Aardman_Animations': 5,
#  'Berlanti_Productions': 1,
#  'Classic_Media_Productions': 1,
#  'Bullwinkle_Studios': 1,
#  'Nimar_Studios': 4,
#  'Helena_Productions': 1,
#  'Montecito_Picture_Company,_The': 4,
#  'LStar_Capital': 12,
#  'Feigco_Entertainment': 1,
#  'Pascal_Pictures': 1,
#  'Ghostcorps': 1,
#  'Valhalla_Motion_Pictures': 7,
#  'Columbia_Pictures_Corporation': 96,
#  'Parkes+MacDonald_Image_Nation': 4,
#  'Shangri_La_Entertainment': 4,
#  'Paramount_Animation': 11,
#  'Oriental_DreamWorks': 1,
#  'JC_23_Entertainment': 1,
#  'Radar_Pictures': 13,
#  'Bedford_Falls_Company,_The': 3,
#  'Volcano_Films': 2,
#  'MavroCine_Pictures_GmbH_&_Co_KG': 1,
#  'Summit_Entertainment': 52,
#  'Mystery_Clock_Cinema': 3,
#  'TIK_Films': 3,
#  'Pyramania': 1,
#  'Phoenix_Pictures': 17,
#  'AFG_Talons_Productions': 1,
#  'Lawrence_Gordon_Productions': 9,
#  'Donner/Shuler_Donner_Productions': 4,
#  'Good_Machine': 11,
#  'Saints_LA': 2,
#  'Bristol_Bay_Productions': 3,
#  'Baldwin_Entertainment_Group': 5,
#  'Desertlands_Entertainment': 1,
#  'Mace_Neufeld_Productions': 10,
#  'Kanzaman': 6,
#  'JK_Livin_Productions': 1,
#  'Moguletta': 1,
#  'Sahara_Productions': 1,
#  'Babelsberg_Film': 4,
#  'Square_USA': 1,
#  'Chris_Lee_Productions': 3,
#  'Samuel_Goldwyn_Films': 6,
#  'Miramax': 11,
#  'Sunswept_Entertainment': 12,
#  'Temple_Hill_Entertainment': 10,
#  'Dr_D_Studios': 1,
#  'Kennedy_Miller_Mitchell': 1,
#  'MVL_Incredible_Productions': 1,
#  'Reliance_Entertainment': 10,
#  'Regency_Enterprises': 69,
#  'Appian_Way': 9,
#  'CatchPlay': 2,
#  'Anonymous_Content': 17,
#  'New_Regency_Pictures': 40,
#  'Hong_Kong_Alpha_Motion_Pictures_Co': 1,
#  'RatPac_Entertainment': 2,
#  'M_Productions': 2,
#  'Monarchy_Enterprises_Sarl': 2,
#  'Blind_Wink': 1,
#  'The_Kennedy/Marshall_Company': 12,
#  'Ludlum_Entertainment': 2,
#  'Motion_Picture_BETA_Produktionsgesellschaft': 1,
#  'Bourne_Again': 1,
#  'Don_Simpson/Jerry_Bruckheimer_Films': 6,
#  'DreamWorks': 7,
#  'Wintergreen_Productions': 7,
#  'Protozoa_Pictures': 6,
#  'Disruption_Entertainment': 2,
#  'Heyday_films': 3,
#  'ScreenWest': 2,
#  'Walt_Disney_Feature_Animation': 9,
#  'Government_of_Malta': 2,
#  'Blue_Sky_Studios': 10,
#  'Twentieth_Century_Fox_Animation': 12,
#  'XM2_Productions': 1,
#  'XF2_Canada_Productions': 1,
#  'One_Race_Productions': 2,
#  'Lin_Pictures': 5,
#  'Wigram_Productions': 3,
#  'TriStar_Pictures': 55,
#  'Carolco_Pictures': 9,
#  'Carolco_International_NV': 1,
#  'Captivate_Entertainment': 2,
#  'PolyGram_Filmed_Entertainment': 16,
#  'Lions_Gate_Films': 34,
#  'Mark_Gordon_Productions': 3,
#  "Mel's_Cite_du_Cinema": 13,
#  'Munich_Film_Partners_&_Company_(MFP)_MI2_Productions': 1,
#  'Baltimore_Spring_Creek_Productions': 5,
#  'Constantin_Film_Produktion': 20,
#  'Bernd_Eichinger_Productions': 1,
#  'Haishang_Films': 1,
#  'Michael_De_Luca_Productions': 9,
#  'Crystal_Sky_Pictures': 3,
#  'GH_One': 1,
#  'Vengeance_Productions_Pty_Ltd': 1,
#  'Pearl_Street_Films': 2,
#  'Double_Negative': 2,
#  'Perfect_World_(Beijing)_Pictures_Co': 1,
#  'Tall_Trees_Productions': 2,
#  'Flower_Films_(II)': 6,
#  'Brandywine_Productions': 7,
#  'Sony_Pictures_Entertainment': 7,
#  'Media_Rights_Capital': 12,
#  'Sony_Pictures_Entertainment_(SPE)': 8,
#  'QED_International': 6,
#  'Alpha_Core': 2,
#  'Genre_Films': 6,
#  'Simon_Kinberg_Productions': 2,
#  'Strike_Entertainment': 7,
#  'Velocity_Productions': 1,
#  'Gracie_Films': 7,
#  'Road_Rebel': 4,
#  'Tree_Line_Films': 3,
#  'Pink_Machine': 1,
#  'Monolith_Pictures_(III)': 1,
#  'Radical_Studios': 2,
#  'Constantin_Film': 1,
#  'TF1_Films_Productions': 5,
#  'La_Petite_Reine': 3,
#  'Tri_Pictures': 1,
#  'Sorolla_Films': 1,
#  'Novo_RPI': 1,
#  'Canal+': 75,
#  'uFilm': 6,
#  'Canal+_España': 9,
#  'Le_Tax_Shelter_du_Gouvernement_Fédéral_de_Belgique': 5,
#  'Les_Editions_Albert_René': 1,
#  'Lion_Rock_Productions': 4,
#  'Perfect_World_Pictures': 2,
#  'Esperanto_Filmoj': 2,
#  'Pacific_Western': 7,
#  '5150_Action': 4,
#  'Gama_Entertainment_Partners': 1,
#  'Marv_Films': 8,
#  'Flynn_Picture_Company': 2,
#  'Mutual_Film_Company': 14,
#  'Global_Entertainment_Productions_GmbH_&_Company_Medien_KG': 7,
#  'Section_Eight': 8,
#  'WV_Films_III': 3,
#  'Epsilon_Motion_Pictures': 32,
#  'Mandeville_Films': 13,
#  'NeoReel': 3,
#  'Miramax_Films': 95,
#  'Cappa_Productions': 3,
#  'Initial_Entertainment_Group_(IEG)': 10,
#  'Reliance_BIG_Entertainment': 5,
#  'Hollywood_Gang_Productions': 3,
#  'Atmosphere_Entertainment_MM': 6,
#  'Sony_Pictures_Animation': 13,
#  'Kerner_Entertainment_Company': 3,
#  'Angry_Films': 2,
#  'Wardour_Street_Pictures': 1,
#  'Blue_Tulip_Productions': 3,
#  'Chartoff_Productions': 1,
#  'Odd_Lot_Entertainment': 5,
#  'K/O_Paper_Products': 4,
#  'Digital_Domain': 1,
#  'Taleswapper': 1,
#  'Cheyenne_Enterprises': 9,
#  'The_Saul_Zaentz_Company': 2,
#  '80_Days_Productions': 1,
#  'Spanknyce_Films': 1,
#  'Fitzwilliam_Productions': 1,
#  'Laurence_Mark_Productions': 8,
#  'Mediastream_Vierte_Film_GmbH_&_Co_Vermarktungs_KG': 3,
#  'Canlaws_Productions': 1,
#  'Dune_Films': 6,
#  'BK': 1,
#  'KOH': 1,
#  'Reino_del_Cielo': 1,
#  'Inside_Track_3': 1,
#  'Calle_Cruzada': 1,
#  'Global_Medien_KG': 1,
#  'Franklin/Waterman_Productions': 1,
#  'International_Traders': 3,
#  'Mill_Film': 1,
#  'C_&_L': 1,
#  'Dawliz': 1,
#  'Ronald_Shusett/Gary_Goldman': 1,
#  'Digital_Image_Associates': 3,
#  'T2_Productions': 1,
#  'Tribeca_Productions': 14,
#  'Misher_Films': 6,
#  'Film_Rites': 4,
#  'Escape_Artists': 13,
#  'Everyman_Pictures': 5,
#  'Dreamworks_Pictures': 1,
#  'Gary_Sanchez_Productions': 13,
#  'Kopelson_Entertainment': 5,
#  'The_Weinstein_Company': 42,
#  'Nu_Image_Films': 1,
#  'Millennium_Films': 29,
#  'Wild_Things_Productions': 1,
#  'Peninsula_Films': 3,
#  'StudioCanal': 43,
#  'Sony_Pictures_Releasing': 5,
#  'Sony_Pictures_Worldwide_Acquisitions_(SPWA)': 2,
#  'Italian_Tax_Credit': 2,
#  'Birnbaum/Barber': 1,
#  'Cineroma_SRL': 1,
#  'French_Tax_Credit': 1,
#  'Beacon_Communications': 9,
#  'Bedford_Falls_Productions': 5,
#  'Lonely_Film_Productions_GmbH_&_Co_KG': 3,
#  'Spring_Creek_Productions': 5,
#  'Liberty_Pictures': 1,
#  'EMJAG_Productions': 2,
#  'Red_Granite_Pictures': 4,
#  'Sikelia_Productions': 2,
#  'Polygram_Filmed_Entertainment': 5,
#  'Big_Bug_Pictures': 1,
#  'X_Filme_Creative_Pool': 9,
#  'Ascension_Pictures': 1,
#  'ARD_Degeto_Film': 3,
#  'Cloud_Atlas_Productions': 1,
#  'Five_Drops': 1,
#  'Media_Asia_Group': 1,
#  'Dreams_of_Dragon_Picture': 1,
#  'Animal_Logic': 4,
#  'DiNovi_Pictures': 11,
#  'Frantic_Films': 1,
#  'Maple_Shade_Films': 1,
#  'Catwoman_Films': 1,
#  'Mosaic_Media_Group': 14,
#  'Sid_&_Marty_Krofft_Pictures': 1,
#  'Davis_Films': 2,
#  'LionsGate': 4,
#  'Ex3_Productions': 1,
#  'Fipex_Holding': 2,
#  'Alcon_Entertainment': 23,
#  'DMG_Entertainment': 3,
#  'Ehman_Productions': 1,
#  'Pathé_Distribution': 2,
#  'K_JAM_Media': 2,
#  'Surf_Film': 1,
#  'Enelmar_Productions,_AIE': 1,
#  'Castle_Rock_Entertainment': 40,
#  'Working_Title_Films': 53,
#  'Jean_Doumanian_Productions': 2,
#  'Sweetland_Films': 3,
#  'Magnolia_Films': 1,
#  'Jasmine_Productions_Inc': 1,
#  'Imhotep_Productions': 1,
#  'Alberto_Grimaldi_Productions': 1,
#  'Beijing_New_Picture_Film_Co_Ltd': 5,
#  'EDKO_Film': 2,
#  'New_Picture_Company': 1,
#  'DreamWorks_Pictures': 8,
#  'Revolution_Studios': 34,
#  'Location_Gourmet': 2,
#  'Gaumont': 10,
#  'Home_Box_Office_(HBO)': 2,
#  'HBO_Films': 5,
#  'Allison_Shearmur_Productions': 2,
#  'Key_Creatives': 2,
#  'Film4': 36,
#  'Goldcrest_Pictures': 12,
#  'New_Zealand_Large_Budget_Screen_Production_Grant': 1,
#  'Outlaw_Sinema': 2,
#  'Pendle_Mountain_Productions': 1,
#  'Toho_Towa': 9,
#  'British_Broadcasting_Corporation_(BBC)': 11,
#  'Marubeni': 6,
#  'Eidos_Interactive': 2,
#  'Straight_Up_Films': 2,
#  'Giant_Pictures': 1,
#  'Origo_Film_Group': 1,
#  'Le_Studio_Canal+': 3,
#  'TCF_Vancouver_Productions': 1,
#  'Firm_Films': 10,
#  'Prospect_Park': 1,
#  'Millbrook_Farm_Productions': 1,
#  'Red_Hour_Films': 10,
#  'Media_Asia_Films': 6,
#  'Internationale_Filmproduktion_Stella_del_Sud_Second': 1,
#  'Scott_Rudin_Productions': 37,
#  'Yellow_Bird': 1,
#  'Ground_Control': 1,
#  'Cinergi_Pictures_Entertainment': 12,
#  'Internationale_Filmproduktion_Blackbird_Dritte': 3,
#  'Sean_Daniel_Company': 1,
#  'LightWorkers_Media': 2,
#  'Bagdasarian_Productions': 3,
#  'United_Artists': 75,
#  'Achte_Babelsberg_Film': 1,
#  'Happy_Madison_Productions': 33,
#  'Stanley_Kubrick_Productions': 3,
#  'Gunn_Films': 5,
#  'Doom_Buggy_Productions': 1,
#  'South_Side_Amusement_Company': 1,
#  'Mirage_Enterprises': 16,
#  'Motion_Picture_JOTA_Produktions': 1,
#  'October_Pictures': 1,
#  'Rysher_Entertainment': 5,
#  'Metropolitan_Filmexport': 4,
#  'Red_Wagon_Productions': 2,
#  'Kalima_Productions_GmbH_&_Co_KG': 4,
#  'The_Jacobson_Company': 4,
#  'Red_Horizon_Productions': 1,
#  'National_Geographic_Society': 1,
#  'Palomar_Pictures_(II)': 3,
#  'First_Light_Production': 3,
#  'Dino_De_Laurentiis_Company': 15,
#  'Parkway_Pictures_(I)': 1,
#  'Vnesheconombank': 1,
#  'Nutcracker_Holdings': 1,
#  'HCC_Media_Group': 1,
#  'Russian_Roulette_Ltd': 1,
#  'Constant_c_Productions': 2,
#  'Hypnotic': 3,
#  'Motion_Picture_THETA_Produktionsgesellschaft': 1,
#  'WV_Films_II': 3,
#  'Impact_Pictures': 12,
#  'Nouvelles_Éditions_de_Films_(NEF)': 3,
#  'New_Legacy': 2,
#  'Josephson_Entertainment': 5,
#  'Andalasia_Productions': 1,
#  'Right_Coast_Productions': 1,
#  'Cruella_Productions': 1,
#  'Image_Entertainment': 2,
#  'Rat_Entertainment': 4,
#  'Waverly_Films': 4,
#  'No_Such_Productions': 1,
#  'Swanford_Films': 1,
#  'Mandalay_Pictures': 9,
#  'Little_Bird': 3,
#  'KC_Medien': 2,
#  'Reperage': 1,
#  'DOS': 1,
#  'MP_Film_Management': 1,
#  'WWE_Studios': 8,
#  'IM3_Entertainment': 1,
#  'Oak_Productions': 1,
#  'City_Light_Films': 4,
#  'David_Foster_Productions': 4,
#  'Bel_Air_Entertainment': 7,
#  'Hacienda_Productions': 1,
#  'Yucaipa_Films': 2,
#  'Goldmann_Pictures': 3,
#  'Misha_Films': 1,
#  'Marc_Platt_Productions': 11,
#  'Horsepower_Films': 1,
#  'Core_Productions': 1,
#  'Munich_Film_Partners_New_Century_&_Company_(MFP)_Core_Productions': 1,
#  'DNA_Films': 10,
#  'IM_Global': 11,
#  'Rena_Film': 1,
#  'Peach_Trees': 1,
#  'Creepshow_Films_Inc': 1,
#  'Laurel_Entertainment_Inc': 2,
#  'Internationale_Filmproduktion_Eagle': 1,
#  'Pit_Bull_Productions': 1,
#  'Living_Films': 4,
#  'Green_Hat_Films': 4,
#  'Zanuck/Brown_Productions': 2,
#  'Manhattan_Project': 1,
#  'MTV_Films': 23,
#  'Callahan_Filmworks': 2,
#  'Mad_Chance': 9,
#  'WV_Films_IV': 2,
#  'Type_A_Films': 2,
#  'Ott_Medien': 1,
#  'Wild_West_Picture_Show_Productions': 5,
#  'Permut_Presentations': 1,
#  'WCG_Entertainment_Productions': 2,
#  'Douglas/Reuther_Productions': 1,
#  'Krane_Entertainment': 3,
#  'Kouf/Bigelow_Productions': 1,
#  'Hiett_Designs_of_Las_Vegas': 1,
#  'Runway_Pictures_Inc': 1,
#  'KMP_Film_Invest': 2,
#  'Castel_Film_Romania': 2,
#  'Bona_Fide_Productions': 6,
#  'Cattleya': 4,
#  'Great_Oaks_Entertainment': 1,
#  'Roth_Arnold_Productions': 2,
#  'Warner_Bros_Family_Entertainment': 2,
#  'Northern_Lights_Entertainment': 3,
#  'Courtside_Seats_Productions': 1,
#  'International_Production_Company': 5,
#  'The_Montecito_Picture_Company': 7,
#  'Robert_Simonds_Productions': 13,
#  'Earth_Canada_Productions': 1,
#  'Hammerhead_Productions': 2,
#  'Crave_Films': 3,
#  'Huayi_Brothers_Media': 4,
#  'Le_Grisbi_Productions': 4,
#  'Caravan_Pictures': 8,
#  'Roger_Birnbaum_Productions': 3,
#  'Warner_Bros_Animation': 9,
#  'Rhythm_and_Hues': 1,
#  'Picnic_Basket': 1,
#  'Zookeeper_Productions': 1,
#  'Hey_Eddie': 3,
#  'Prelude_Pictures': 2,
#  'Saltire_Entertainment': 1,
#  'Clinica_Estetico': 6,
#  'Rainbow_Film_Company,_The': 1,
#  'Revere_Entertainment': 1,
#  'Jagtoria_Films': 1,
#  'RKO_Pictures': 2,
#  'Jonathan_Krane_Group': 1,
#  'Avery_Pix': 5,
#  'Reforma_Films': 1,
#  'Dimension_Films': 55,
#  'Ex_Nihilo': 1,
#  'Les_films_du_Worso': 1,
#  'Noodles_Production': 2,
#  'Ciné+': 12,
#  'Scope_Pictures': 3,
#  'Centre_National_de_la_Cinématographie_(CNC)': 13,
#  'Ministère_de_la_Culture_et_de_la_Communication': 2,
#  'Left_Field_Ventures': 1,
#  'Evo_Films_AIE': 1,
#  'Indéfilms_3': 1,
#  'Palatine_Étoile_12': 1,
#  'Cinéfeel_Prod': 1,
#  'Art_Linson_Productions': 6,
#  'Top_Shelf_Productions': 1,
#  'Tig_Productions': 7,
#  'BBC_Worldwide': 1,
#  'BBC_Earth': 1,
#  'Evergreen_Films': 1,
#  'BBC_Earth_MD_(WWD)': 1,
#  'Evergreen_MD': 1,
#  'Franchise_Pictures': 16,
#  'JTP_Films': 1,
#  'Morgan_Creek_Productions': 23,
#  'Battlefield_Productions': 1,
#  'Warner_Bros_Feature_Animation': 1,
#  'Cobalt_Media_Group': 5,
#  'Artists_Production_Group_(APG)': 3,
#  'Aperture_Entertainment': 2,
#  'The_Canton_Company': 3,
#  'Mars_Production_Pty_Ltd': 1,
#  'Canal_Plus': 10,
#  'Sofica_Europacorp': 2,
#  'Avalanche_Productions': 1,
#  'EuropaCorp': 25,
#  'Pathé_Films': 2,
#  'TPS_Star': 9,
#  'Participant_Media': 25,
#  'France_Télévision': 5,
#  'France_2_Cinéma': 20,
#  'France_3_Cinema': 7,
#  'Conseil_Régional_du_Calvados': 1,
#  'Région_Bretagne': 2,
#  'Ministère_du_Développement_Durable_et_de_la_Mer': 1,
#  'JMH_TSR': 1,
#  'HH_Sheikha_Salama_bint_Hamdan_Al_Nahyan': 1,
#  "Conseil_Général_des_Côtes_d'Armor": 1,
#  'Conseil_Général_du_Morbihan': 1,
#  'Région_Basse_Normandie': 1,
#  'Dante_Entertainment': 2,
#  'Crusader_Entertainment': 2,
#  'ETIC_Films': 5,
#  'Forge': 3,
#  'QI_Quality_International_GmbH_Co_KG': 1,
#  'Signature_Pictures': 8,
#  'ApolloMedia_Distribution': 5,
#  'Coco': 1,
#  'Film_111': 1,
#  'Jericho_Productions_Ltd': 1,
#  'MFF_(Sound_of_Thunder)': 1,
#  'Matrix_Film_Finance': 1,
#  'Scenario_Lane_Productions': 1,
#  'Don_Carmody_Productions': 4,
#  'FilmDistrict': 8,
#  'Constantin_Film_International': 1,
#  'Anima_Estudios': 1,
#  'Discreet_Art_Productions': 1,
#  'Contrafilm': 6,
#  'Sony': 1,
#  'Casey_Silver_Productions': 5,
#  'Mikona_Productions_GmbH_&_Co_KG': 4,
#  'Onyx_Films': 2,
#  'NetFlix': 1,
#  'Orange_Studios': 1,
#  'CityMation': 1,
#  'On_Entertainment': 1,
#  'Zippcast_Films': 1,
#  'Capella_International': 3,
#  'KC_Medien_AG': 2,
#  'Illumination_Entertainment': 6,
#  'JD_Productions': 1,
#  'Mediastream_Dritte_Film_GmbH_&_Co_Beteiligungs_KG': 3,
#  'Hit_&_Run_Productions': 1,
#  'Springwood_Productions': 1,
#  'Genetics_Productions': 1,
#  'Bazelevs_Production': 7,
#  'Kickstart_Productions': 1,
#  'Top_Cow_Productions': 1,
#  'Ringerike_Zweite_Filmproduktion': 1,
#  'Hollywood_Pictures': 29,
#  'Offspring_Entertainment': 7,
#  'Zadan_/_Meron_Productions': 2,
#  'Dominion_Productions': 1,
#  'DiC_Entertainment': 1,
#  'SOIXAN7E_QUIN5E': 1,
#  'See_Me_Louisiana': 1,
#  'Participant_Productions': 3,
#  'Playtone_Production': 1,
#  'Double_Feature_Films': 15,
#  'Jersey_Films': 15,
#  'Nina_Saxon_Film_Design': 2,
#  'Alliance_Atlantis_Communications': 11,
#  'Barry_Mendel_Productions': 5,
#  'Michael_Lobell_Productions': 1,
#  'Katalyst_Films': 3,
#  'Aversano_Films': 1,
#  'Empire_Pictures': 2,
#  'Hyde_Park_Entertainment': 7,
#  'Lotus_Pictures': 1,
#  'First_Knight_Productions': 1,
#  'Virgin_Produced': 4,
#  'Mark_Canton_Productions': 2,
#  'Yari_Film_Group': 8,
#  'Stratus_Film_Co': 3,
#  'Syndicate_Films_International': 1,
#  'Equity_Pictures_Medienfonds_GmbH_&_Co_KG_II': 1,
#  'Hostage_GmbH': 1,
#  'David_Kirschner_Productions': 3,
#  'Fox_Animation_Studios': 2,
#  'Paramount_Vantage': 13,
#  'Likely_Story': 8,
#  'Ivy_Boy_Productions': 1,
#  'This_Is_That_Productions': 8,
#  'Twitching_Image_Studio': 1,
#  'Aldrich_Group': 1,
#  'Optional_Pictures': 1,
#  'Limited_Edition_Productions_Inc': 1,
#  'Lennox_House_Films': 1,
#  'DeBart': 1,
#  'Punch_Productions': 4,
#  'Baltimore_Pictures': 7,
#  'Rovio_Entertainment': 1,
#  'Sony_Pictures_Imageworks_(SPI)': 1,
#  'Rovio_Mobile': 1,
#  'Rovio_Animation': 1,
#  'Apatow_Productions': 21,
#  'Madison_23': 2,
#  'FilmWorks': 2,
#  'MDBF_Zweite_Filmgesellschaft': 1,
#  'Joseph_M_Singer_Entertainment': 3,
#  'Icon_Entertainment_International': 12,
#  'The_Ladd_Company': 8,
#  'BH_Finance_CV': 1,
#  'Neal_Street_Productions': 5,
#  'Motion_Picture_KAPPA_Produktionsgesellschaft': 1,
#  'Darkwoods_Productions': 4,
#  'Trackform_Film_Productions': 1,
#  'TF1_Films_Production': 19,
#  'Pathe': 4,
#  'Two_Brothers_Productions': 1,
#  'Lakeshore_Entertainment': 34,
#  'Interscope_Communications': 7,
#  'Nickelodeon_Animation_Studios': 2,
#  'United_Plankton_Pictures': 2,
#  'Brian_Grazer/Scott_Rudin_Productions': 1,
#  'A_Band_Apart': 6,
#  'Zehnte_Babelsberg': 1,
#  'Visiona_Romantica': 1,
#  'Camelot_Pictures': 4,
#  'Illusion_Entertainment': 1,
#  'Cruise_Wagner_Productions': 1,
#  'Vinyl_Films': 5,
#  'Lonlink_Productions': 1,
#  'Kut_Productions': 1,
#  'Inside_Track_Films': 2,
#  'Charenton_Productions_Limited': 1,
#  'Wheelhouse_Entertainment': 1,
#  'Motion_Picture_Production_GmbH_&_Co_Erste_KG': 1,
#  'Jinks/Cohen_Company': 2,
#  'Smokehouse_Pictures': 8,
#  'Obelisk_Productions': 1,
#  'Edward_R_Pressman_Film': 5,
#  'Vaughn_Productions': 1,
#  'Mandalay_Entertainment': 6,
#  'Applecross': 1,
#  'Reperage_&_Vanguard_Films': 1,
#  'John_Wells_Productions': 6,
#  'Reaper_Productions': 1,
#  'Doom_Productions': 1,
#  'Distant_Planet_Productions': 1,
#  'Screen_Gems': 39,
#  'Sketch_Films': 2,
#  'UW4_Productions': 1,
#  'Corner_Store_Entertainment': 3,
#  'Material_Pictures': 2,
#  'David_Ladd_Films': 2,
#  'Current_Entertainment': 7,
#  'Omnilab_Media': 3,
#  'Ambience_Entertainment': 2,
#  'Open_Road_Films': 11,
#  'Sighvatsson_Films': 2,
#  'Film_Victoria': 3,
#  'Wales_Creative_IP_Fund': 2,
#  'Yorktown_Productions': 2,
#  'Helkon_Media_AG': 1,
#  'SuperMega': 1,
#  'MHF_Erste_Academy_Film_GmbH_&_Co_Produktions_KG': 1,
#  'Tele_München_Fernseh_Produktionsgesellschaft_(TMG)': 4,
#  'UGC_PH': 2,
#  'British_Broadcasting_Corporation_(BBC)_Television': 1,
#  'Stargate_Studios': 2,
#  'Conundrum_Entertainment': 6,
#  'Prana_Animation_Studios': 2,
#  'Summertime_Entertainment': 1,
#  'Natural_Nylon_Entertainment': 3,
#  'Riff_Raff_Film_Productions': 1,
#  'Filmauro': 1,
#  'Blue_Flower_Productions': 1,
#  'Brooklyn_Films_II': 1,
#  'Emmett/Furla_Films': 12,
#  'Envision_Entertainment': 3,
#  'Boies_/_Schiller_Film_Group': 1,
#  'Knightsbridge_Entertainment': 2,
#  'MFP_Munich_Film_Partners_GmbH_&_Company_I_Produktions_KG': 4,
#  'SOAF_Productions': 1,
#  'Maverick_Films': 5,
#  'Imprint_Entertainment': 3,
#  'Horseshoe_Bay_Productions': 2,
#  'Fuzzy_Door_Productions': 3,
#  'Smart_Entertainment': 2,
#  'Himenóptero': 3,
#  'Telecinco_Cinema': 5,
#  'Mod_Producciones': 3,
#  'Instituto_de_la_Cinematografía_y_de_las_Artes_Audiovisuales_(ICAA)': 7,
#  'Golar_Productions': 2,
#  'Kaitz_Productions': 1,
#  'Mann/Roth_Productions': 1,
#  'Whitaker_Entertainment': 1,
#  'Bergsten_Music': 1,
#  'Red_Hawk_Entertainment': 1,
#  'Abraham_Productions': 1,
#  'Fountainbridge_Films': 2,
#  'Ten_Thirteen_Productions': 2,
#  'Quinta_Communications': 4,
#  'Zephyr_Films': 4,
#  'Bandito_Brothers': 2,
#  'Electronic_Arts': 1,
#  'Wind_Dancer_Productions': 2,
#  'Kasdan_Pictures': 5,
#  'Groucho_II_Film_Partnership': 2,
#  'Outlaw_Productions': 2,
#  'Boxing_Cat_Films': 3,
#  'CAMERON_MACKINTOSH': 1,
#  'Jolie_Pas': 2,
#  'Malpaso_Productions': 19,
#  'Clipsal_Films': 1,
#  'RCS_Video': 1,
#  'Cliffhanger_Productions': 1,
#  'Pioneer': 1,
#  'Kernos_Filmproduktionsgesellschaft_&_Company': 2,
#  'Hobby_Films': 1,
#  'Pole_Star': 1,
#  'Olive_Bridge_Entertainment': 4,
#  'Marcy_Media': 1,
#  'Kramer_&_Sigman_Films': 2,
#  'Zaftig_Films': 1,
#  'Overbrook_Films': 1,
#  'Amen_Ra_Films': 5,
#  'Shawn_Danielle_Productions_Ltd': 1,
#  'Imaginary_Forces': 3,
#  'Peter_Frankfurt_Productions': 1,
#  'Valkyrie_Films': 1,
#  'Scion_Films': 12,
#  'H2S2_Filmproduktionsgesellschaft': 1,
#  'The_Steve_Tisch_Company': 2,
#  'Teitler_Film': 1,
#  'Taurus_Film': 5,
#  'Linson_Films': 1,
#  'Atman_Entertainment': 1,
#  'Knickerbocker_Films': 1,
#  'Sidney_Kimmel_Entertainment': 16,
#  'Hopscotch_Films': 1,
#  'RP_Productions': 4,
#  'Runteam_III_Ltd': 1,
#  'Elektra_Productions': 1,
#  'SAI_Productions': 1,
#  'Troublemaker_Studios': 8,
#  'AR_Films': 2,
#  'Aldamisa_Entertainment': 3,
#  'Demarest_Films': 4,
#  'Solipsist_Film': 1,
#  'Residaco': 1,
#  'Cross_Creek_Pictures': 10,
#  'Free_State_Pictures': 3,
#  'RVK_Studios': 1,
#  'Rising_Star': 7,
#  'VIP_Medienfonds_4': 2,
#  'Ikiru_Films': 2,
#  'Castelao_Producciones': 5,
#  "Eric's_Boy": 3,
#  'Moving_Pictures': 1,
#  'Gratitude_International': 1,
#  'Tezuka_Production_Company_Ltd': 1,
#  'Imagi_Animation_Studios': 2,
#  'Paragon_Entertainment_Corp': 1,
#  'Shanghai_Film_Group': 2,
#  'Jackie_&_JJ_Production': 1,
#  'Sparkle_Roll_Media': 1,
#  'Home_Media_&_Entertainment_Fund': 1,
#  'Tencent_Video': 1,
#  'China_Film_&_TV_Capital': 1,
#  'Visualizer_Film_Company': 1,
#  'Wayans_Bros_Entertainment': 5,
#  'Internationale_Filmproduktion': 1,
#  'FilmColony': 3,
#  'Wild_Hogs_Productions': 1,
#  'Pacific_Standard': 3,
#  'Artemple___Hollywood': 1,
#  'Neufeld_Rehme_Productions': 1,
#  'Envision_Entertainment_Corporation': 3,
#  'Zide_Perry_Productions': 7,
#  'BenderSpink': 12,
#  'Fortis_Films': 7,
#  'Dozen_Canada_Productions': 1,
#  'Gotham_Group': 3,
#  'Red_Om_Films': 3,
#  'Ixtlan': 3,
#  'Wildwood_Enterprises': 6,
#  'Edge_City': 2,
#  'World_Wrestling_Entertainment_(WWE)': 1,
#  'Beacon_Pictures': 8,
#  'Fantail_Films_Inc': 1,
#  'Riche_Ludwig_Productions': 2,
#  'Groucho_III_Film_Partnership': 1,
#  'Focus_Features': 36,
#  'Laika_Entertainment': 4,
#  'UTV_Motion_Pictures': 4,
#  'AR_TL': 1,
#  'Starlite_Films': 1,
#  'Province_of_British_Columbia_Film_Incentive_BC': 4,
#  'Solomon/Hackett_Productions': 1,
#  'Larger_Than_Life_Productions': 2,
#  'Blue_Train_Productions': 1,
#  'Seagal/Nasso_Productions': 2,
#  'Victor_Company_of_Japan_(JVC)': 1,
#  'Cutting_Edge_Films': 1,
#  'Etalon_film': 1,
#  'Buckaroo_Entertainment': 4,
#  'LHF_Film': 1,
#  'Gerard_Butler_Alan_Siegel_Entertainment': 1,
#  'Nu_Boyana_Film_Studios': 1,
#  'Grosvenor_Park_Impact_Productions': 1,
#  'LEGO': 1,
#  'Warner_Animation_Group': 1,
#  'World_2000_Entertainment': 3,
#  'Tripod_Entertainment': 1,
#  'Langley_Park_Production': 2,
#  'Ocean_Pictures': 1,
#  ...}

# %%
#turn the dictionary into a dataframe
find_most_occuring = pd.DataFrame([companies_dict])
#transpose the row and column
find_most_occuring = find_most_occuring.transpose()
#rename the column
find_most_occuring = find_most_occuring.rename(columns={0:"Count"})
#sort the data frame to find the compainies that appear the most
find_most_occuring = find_most_occuring.sort_values("Count", ascending=False)
#display the 10 most occuring companies
find_most_occuring.head(11)
# Out:
#                                         Count
# Warner_Bros                               319
# Universal_Pictures                        312
# Paramount_Pictures                        285
# Not                                       282
# Twentieth_Century_Fox_Film_Corporation    222
# Columbia_Pictures                         203
# New_Line_Cinema                           167
# Metro_Goldwyn_Mayer_MGM                   122
# Walt_Disney_Pictures                      118
# Touchstone_Pictures                       118
# Relativity_Media                          102

# %%
#Create dataframes for each of the top ten companies
#first by createing an empty list to holf them
create_comp_dfs = []

#reset the index on the dataframe so the company names will be a normal column
find_most_occuring1 = find_most_occuring.reset_index()

#create a counter variable
limit_rows_to_11 = 0
#run the loop while the counter variable is below the wanted threshold
while limit_rows_to_11 < 11:

    #set the name of each company to a variable
    take_value = find_most_occuring1["index"][limit_rows_to_11]
    #and append the variable to ta list
    create_comp_dfs.append(take_value)
    #increment the counter
    limit_rows_to_11 += 1
#after the list is completed, find and delete the 'Not" entry as it is not a production company    
del create_comp_dfs[3]
#display the list
create_comp_dfs
# Out:
# ['Warner_Bros',
#  'Universal_Pictures',
#  'Paramount_Pictures',
#  'Twentieth_Century_Fox_Film_Corporation',
#  'Columbia_Pictures',
#  'New_Line_Cinema',
#  'Metro_Goldwyn_Mayer_MGM',
#  'Walt_Disney_Pictures',
#  'Touchstone_Pictures',
#  'Relativity_Media']

# %%
#use the list and a loop to create 
for n in create_comp_dfs:
    globals()[n] = []
    
#go through each row in the cleaned dataframe and
for index,row in merged_df.iterrows():
    # try to use json.loads on the genres column at the position of the current index
    #if there would be an issue use excpet to give the entry a deafult value to throw away
    try:
        jdata = json.loads(merged_df["production_companies"][index])
    except:
        jdata = [{"name": "Not"}]
    
    #for each dictionary in the created variable, check which genres appear and append to the proper list
    #DO NOT USE elif, to check if a row belongs in multiple lists use a seperate if statement for each list
    for d in jdata:

        if d["name"] == "Warner Bros.":
            Warner_Bros.append(row)
         
        if d["name"] == "Universal Pictures":
            Universal_Pictures.append(row)
            
        if d["name"] == "Paramount Pictures":
            Paramount_Pictures.append(row)
           
        if d["name"] == "Twentieth Century Fox Film Corporation":
            Twentieth_Century_Fox_Film_Corporation.append(row)
            
        if d["name"] == "Columbia Pictures":
            Columbia_Pictures.append(row)
           
        if d["name"] == "New Line Cinema":
            New_Line_Cinema.append(row)
           
        if d["name"] == "Metro-Goldwyn-Mayer (MGM)":
            Metro_Goldwyn_Mayer_MGM.append(row)
           
        if d["name"] == "Walt Disney Pictures":
            Walt_Disney_Pictures.append(row)
           
        if d["name"] == "Touchstone Pictures":
            Touchstone_Pictures.append(row)
           
        if d["name"] == "Relativity Media":
            Relativity_Media.append(row)
            
#convert them all to dataframes            
Warner_Bros_df = pd.DataFrame(Warner_Bros)   
Universal_Pictures_df = pd.DataFrame(Universal_Pictures)
Paramount_Pictures_df = pd.DataFrame(Paramount_Pictures)
Twentieth_Century_Fox_Film_Corporation_df = pd.DataFrame(Twentieth_Century_Fox_Film_Corporation)
Columbia_Pictures_df = pd.DataFrame(Columbia_Pictures)
New_Line_Cinema_df = pd.DataFrame(New_Line_Cinema)
Metro_Goldwyn_Mayer_MGM_df = pd.DataFrame(Metro_Goldwyn_Mayer_MGM)
Walt_Disney_Pictures_df = pd.DataFrame(Walt_Disney_Pictures)
Touchstone_Pictures_df = pd.DataFrame(Touchstone_Pictures)
Relativity_Media_df = pd.DataFrame(Relativity_Media)

# %%
#find the average of the voter_score for each company and append each to a list to use in a plot
to_plot_comp_by_AVGscore = []
#use np.mean and round the result to 2 decimal places
Warner_Bros_score_avg = round(np.mean(Warner_Bros_df["vote_average"]), 2)
to_plot_comp_by_AVGscore.append(Warner_Bros_score_avg)

Universal_Pictures_score_avg = round(np.mean(Universal_Pictures_df["vote_average"]), 2)
to_plot_comp_by_AVGscore.append(Universal_Pictures_score_avg)

Paramount_Pictures_score_avg = round(np.mean(Paramount_Pictures_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Paramount_Pictures_score_avg)

Twentieth_Century_Fox_Film_Corporation_score_avg = round(np.mean(Twentieth_Century_Fox_Film_Corporation_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Twentieth_Century_Fox_Film_Corporation_score_avg)

Columbia_Pictures_score_avg = round(np.mean(Columbia_Pictures_df["vote_average"]), 2)
to_plot_comp_by_AVGscore.append(Columbia_Pictures_score_avg)

New_Line_Cinema_score_avg = round(np.mean(New_Line_Cinema_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(New_Line_Cinema_score_avg)

Metro_Goldwyn_Mayer_MGM_score_average = round(np.mean(Metro_Goldwyn_Mayer_MGM_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Metro_Goldwyn_Mayer_MGM_score_average)

Walt_Disney_Pictures_score_avg = round(np.mean(Walt_Disney_Pictures_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Walt_Disney_Pictures_score_avg)

Touchstone_Pictures_score_avg = round(np.mean(Touchstone_Pictures_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Touchstone_Pictures_score_avg)

Relativity_Media_score_avg =round( np.mean(Relativity_Media_df['vote_average']), 2)
to_plot_comp_by_AVGscore.append(Relativity_Media_score_avg)

to_plot_comp_by_AVGscore
# Out:
# [6.35, 6.27, 6.25, 6.2, 6.17, 6.15, 6.08, 6.34, 6.27, 6.12]

# %%
#create a plot to see which which production company produces the most liked movies
plt.bar()

# %%
rating_params = merged_df.loc[merged_df["vote_average"] > 0 ]
rating_params = rating_params.loc[rating_params['vote_count'] > 100]
find_lowest_over_rating = rating_params.loc[rating_params['vote_average'] == min(rating_params["vote_average"])]
find_higest_over_rating = rating_params.loc[rating_params['vote_average'] == max(rating_params['vote_average'])]
find_higest_over_rating
# Out:
#         budget  compound_score  \
# 1881  25000000         -0.7003
#
#                                                  genres  \
# 1881  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                 original_title  \
# 1881  The Shawshank Redemption
#
#                                    production_companies release_date  \
# 1881  [{"name": "Castle Rock Entertainment", "id": 97}]   1994-09-23
#
#        revenue  runtime  vote_average  vote_count
# 1881  28341469    142.0           8.5        8205
