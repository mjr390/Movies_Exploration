# %%
import json
import requests
from pprint import pprint

url = "https://api.themoviedb.org/3/discover/movie?api_key=947778a6875678206b391f256e04d8a7&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page=1&primary_release_year=2017&vote_count.gte=100"
response = requests.get(url)
json = response.json()
pprint(json)
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#               'backdrop_path': '/kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg',
#               'genre_ids': [28, 12, 14, 878, 35],
#               'id': 284053,
#               'original_language': 'en',
#               'original_title': 'Thor: Ragnarok',
#               'overview': 'Thor is on the other side of the universe and finds '
#                           'himself in a race against time to get back to '
#                           'Asgard to stop Ragnarok, the prophecy of '
#                           'destruction to his homeworld and the end of '
#                           'Asgardian civilization, at the hands of an '
#                           'all-powerful new threat, the ruthless Hela.',
#               'popularity': 99.677274,
#               'poster_path': '/rzRwTcFvttcN1ZpX2xv4j3tSdJu.jpg',
#               'release_date': '2017-10-25',
#               'title': 'Thor: Ragnarok',
#               'video': False,
# ...
